# %%
import pandas as pd
from statistics import mode
data=pd.read_csv("weather.csv")
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
print(data.Sunshine.mean())
print(data.WindGustDir.mode())
print(data.WindGustSpeed.mean())
print(data.WindDir9am.mode())
print(data.WindDir3pm.mode())
print(data.WindSpeed9am.mean())
# Out:
# 7.909366391184575
# 0    NW
# dtype: object
# 39.84065934065934
# 0    SE
# dtype: object
# 0     NW
# 1    WNW
# dtype: object
# 9.651810584958218

# %%
#filling null values by mean(for numerical data) and mode (for categorical data)
data1=data.fillna({
    'Sunshine':7.909366391184575,
    'WindGustDir':'NW',
    'WindGustSpeed':39.84065934065934,
    'WindDir9am':'SE',
    'WindDir3pm':'NW',
    'WindSpeed9am':9.651810584958218
})
data1
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       366 non-null    float64
#  5   WindGustDir    366 non-null    object
#  6   WindGustSpeed  366 non-null    float64
#  7   WindDir9am     366 non-null    object
#  8   WindDir3pm     366 non-null    object
#  9   WindSpeed9am   366 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
#forward fill -->fills null value by its previous value
data2=data.fillna(method='ffill');data2
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
#backrward fill -->fills null value by its next value
data3=data.fillna(method='bfill')
data3
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
#dropping rows that contains null values
data4=data.dropna()
data4
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data4.shape #number of rows reduced to 328 from 366
# Out:
# (328, 22)

# %%
#if row contain only one null value and we wish to retain that row instead of deleting the records
data5=data.dropna(thresh=1)
data5
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data5.shape #since no row  contain more than one null records
# Out:
# (366, 22)

# %%
#Handling Missing Data Using Replace Function

# %%
import numpy as np

# %%
data=pd.read_excel("weather_data.xlsx")
data   #1000 showing error values
# Out:
#          day  temp  windspeed     event
# 0 2017-01-01    32          6      rain
# 1 2017-02-01  1000          7     sunny
# 2 2017-03-01    28       1000      snow
# 3 2017-04-01  1000          7  no event
# 4 2017-05-01    32       1000      rain
# 5 2017-06-01    31          2     sunny
# 6 2017-07-01    34          5  no event

# %%
#we want to replace null value by NaN
data1=data.replace(1000,np.NaN)
data1
# Out:
#          day  temp  windspeed     event
# 0 2017-01-01  32.0        6.0      rain
# 1 2017-02-01   NaN        7.0     sunny
# 2 2017-03-01  28.0        NaN      snow
# 3 2017-04-01   NaN        7.0  no event
# 4 2017-05-01  32.0        NaN      rain
# 5 2017-06-01  31.0        2.0     sunny
# 6 2017-07-01  34.0        5.0  no event

# %%
#here consider no event means null then replace it to NaN 
data2=data.replace([1000,'no event'],np.NaN)
data2
# Out:
#          day  temp  windspeed  event
# 0 2017-01-01  32.0        6.0   rain
# 1 2017-02-01   NaN        7.0  sunny
# 2 2017-03-01  28.0        NaN   snow
# 3 2017-04-01   NaN        7.0    NaN
# 4 2017-05-01  32.0        NaN   rain
# 5 2017-06-01  31.0        2.0  sunny
# 6 2017-07-01  34.0        5.0    NaN

# %%
speed_data={
    'time':['7m','8h','6s'],
    'distance':['10km','1000km','100m']
}
data=pd.DataFrame(speed_data)
data
# Out:
#   time distance
# 0   7m     10km
# 1   8h   1000km
# 2   6s     100m

# %%
# Regular Expression -->used to replace the units(values) to unitless
data1=data.replace('[A-Za-z]','',regex=True)
data1
# Out:
#   time distance
# 0    7       10
# 1    8     1000
# 2    6      100

# %%
import pandas as pd 
data=pd.read_csv("weather.csv");data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data.head()#deafault it takes 1st 5 rows only
data.head(10)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
# 8      8.8     19.5       0.0          4.0       4.1           S
# 9      8.4     22.8      16.2          5.4       7.7           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# ...

# %%
data.tail() #by default it takes last five rows only
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
data.tail(10)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 356      3.4     15.0       0.8          4.8      11.7           S
# 357      3.2     18.0       0.0          7.4      12.2         SSE
# 358      0.9     20.7       0.0          5.4       8.4         NNW
# 359      3.3     25.5       0.0          5.2      10.8           N
# 360      7.9     26.1       0.0          6.8       3.5         NNW
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 356           70.0          S          S          35.0  ...           24
# 357           48.0        SSE          S          26.0  ...           25
# ...

# %%
#for getting columns names
data.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
#to get total number of columns and rows
data.shape
# Out:
# (366, 22)

# %%
# for knowing data types
data.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
#for getting information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
# description like basic aggregation of the data
data.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
#some calculations
print("maximum:",data.max())
print("minimum:",data.min())
print("mean:",data.mean())
print("median:",data.median())
print("variance:",data.var())
print("standard deviation:",data.std())
print("skewness:",data.skew())
print("kurtosis:",data.kurt())
print("count:",data.count())
# Out:
# maximum: MinTemp            20.9
# MaxTemp            35.8
# Rainfall           39.8
# Evaporation        13.8
# Sunshine           13.6
# WindGustSpeed      98.0
# WindSpeed9am       41.0
# WindSpeed3pm         52
# Humidity9am          99
# Humidity3pm          96
# Pressure9am      1035.7
# Pressure3pm      1033.2
# Cloud9am              8
# Cloud3pm              8
# Temp9am            24.7
# Temp3pm            34.5
# RainToday           Yes
# RISK_MM            39.8
# RainTomorrow        Yes
# dtype: object
# minimum: MinTemp           -5.3
# MaxTemp            7.6
# Rainfall           0.0
# Evaporation        0.2
# Sunshine           0.0
# WindGustSpeed     13.0
# WindSpeed9am       0.0
# WindSpeed3pm         0
# Humidity9am         36
# Humidity3pm         13
# Pressure9am      996.5
# Pressure3pm      996.8
# Cloud9am             0
# Cloud3pm             0
# Temp9am            0.1
# Temp3pm            5.1
# RainToday           No
# RISK_MM            0.0
# ...

# %%
print(data['Rainfall'].count())
print(data['Rainfall'].mean())
print(data['Rainfall'].var())
# Out:
# 366
# 1.4284153005464482
# 17.857382139381833

# %%
#to get frequency of the values or records
print(data['Rainfall'].value_counts())
# Out:
# 0.0     263
# 0.2      17
# 0.6       6
# 0.8       5
# 0.4       5
# 1.0       4
# 6.6       3
# 1.8       3
# 5.2       3
# 4.8       3
# 2.0       3
# 4.0       3
# 3.4       3
# 1.2       3
# 3.6       2
# 3.8       2
# 1.4       2
# 3.0       2
# 6.4       2
# 11.0      2
# 17.4      2
# 1.6       2
# 16.2      2
# 2.6       1
# 8.2       1
# 7.2       1
# 7.6       1
# 19.2      1
# 6.2       1
# 9.8       1
# 7.4       1
# 16.8      1
# 19.8      1
# 18.8      1
# 10.4      1
# 4.4       1
# 9.0       1
# 2.2       1
# 12.2      1
# 14.4      1
# 5.4       1
# 4.2       1
# 22.6      1
# 25.8      1
# 2.8       1
# 39.8      1
# 13.2      1
# Name: Rainfall, dtype: int64

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
# to get columns for our convinience
data[['Rainfall','RainTomorrow']]
# Out:
#      Rainfall RainTomorrow
# 0         0.0          Yes
# 1         3.6          Yes
# 2         3.6          Yes
# 3        39.8          Yes
# 4         2.8           No
# ..        ...          ...
# 361       0.0           No
# 362       0.0           No
# 363       0.0           No
# 364       0.0           No
# 365       0.0           No
#
# [366 rows x 2 columns]

# %%
data[['MinTemp','MaxTemp','Rainfall','Evaporation','Sunshine']]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine
# 0        8.0     24.3       0.0          3.4       6.3
# 1       14.0     26.9       3.6          4.4       9.7
# 2       13.7     23.4       3.6          5.8       3.3
# 3       13.3     15.5      39.8          7.2       9.1
# 4        7.6     16.1       2.8          5.6      10.6
# ..       ...      ...       ...          ...       ...
# 361      9.0     30.7       0.0          7.6      12.1
# 362      7.1     28.4       0.0         11.6      12.7
# 363     12.5     19.9       0.0          8.4       5.3
# 364     12.5     26.9       0.0          5.0       7.1
# 365     12.3     30.2       0.0          6.0      12.6
#
# [366 rows x 5 columns]

# %%
data['Rainfall'][data['RainToday']=='Yes']#which gives Rainfall recoreds where RainToday is 'yes'
# Out:
# 1       3.6
# 2       3.6
# 3      39.8
# 4       2.8
# 9      16.2
#        ...
# 327    17.4
# 338     7.6
# 339     3.0
# 341     8.2
# 348    13.2
# Name: Rainfall, Length: 66, dtype: float64

# %%
data[data['RainToday']=='No']# displaying records where rain today is 'no'
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 6        6.1     18.2       0.2          4.2       8.4          SE
# 7        8.3     17.0       0.0          5.6       4.6           E
# 8        8.8     19.5       0.0          4.0       4.1           S
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data[data['Rainfall']>25]  #or data[data.Rainfall>30]
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 3      13.3     15.5      39.8          7.2       9.1          NW
# 22     12.8     18.5      25.8          2.8       0.6         ESE
#
#     WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 3            54.0        WNW          W          30.0  ...           56
# 22           28.0          S         SE          13.0  ...           79
#
#     Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 3        1005.5       1007.0         2         7     13.5     14.1        Yes
# 22       1014.0       1014.9         8         8     14.0     16.8        Yes
#
#     RISK_MM RainTomorrow
# 3       2.8          Yes
# 22      0.4           No
#
# [2 rows x 22 columns]

# %%
data[data.Rainfall<10]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
#for getting data where rainfall is maximum
data[data['Rainfall']==data['Rainfall'].max()]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 3     13.3     15.5      39.8          7.2       9.1          NW
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 3           54.0        WNW          W          30.0  ...           56
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 3       1005.5       1007.0         2         7     13.5     14.1        Yes
#
#    RISK_MM RainTomorrow
# 3      2.8          Yes
#
# [1 rows x 22 columns]

# %%
data[['Rainfall','Sunshine']][data['RainToday']=='No']
# Out:
#      Rainfall  Sunshine
# 0         0.0       6.3
# 5         0.0       8.2
# 6         0.2       8.4
# 7         0.0       4.6
# 8         0.0       4.1
# ..        ...       ...
# 361       0.0      12.1
# 362       0.0      12.7
# 363       0.0       5.3
# 364       0.0       7.1
# 365       0.0      12.6
#
# [300 rows x 2 columns]

# %%
#slicy and dicy of data
data.iloc[:,:]#returns all the records -->indexlocator(from n row:to m row,from n col : to m column)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data.iloc[0:5,0:10]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am
# 0           30.0         SW         NW           6.0
# 1           39.0          E          W           4.0
# 2           85.0          N        NNE           6.0
# 3           54.0        WNW          W          30.0
# 4           50.0        SSE        ESE          20.0

# %%
data.iloc[1:3,]# or data[1:3]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
# 2       1009.5       1007.2         8         7     15.4     20.2        Yes
#
#    RISK_MM RainTomorrow
# 1      3.6          Yes
# 2     39.8          Yes
#
# [2 rows x 22 columns]

# %%
data[1:5]# which gives row 1 to 4
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
# 2       1009.5       1007.2         8         7     15.4     20.2        Yes
# ...

# %%
#gives the inex of the data
data.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
data.set_index('MinTemp')      # for setting column as a index for the data but its not changed in original data so we use inplace function
# Out:
#          MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  WindGustSpeed  \
# MinTemp
# 8.0         24.3       0.0          3.4       6.3          NW           30.0
# 14.0        26.9       3.6          4.4       9.7         ENE           39.0
# 13.7        23.4       3.6          5.8       3.3          NW           85.0
# 13.3        15.5      39.8          7.2       9.1          NW           54.0
# 7.6         16.1       2.8          5.6      10.6         SSE           50.0
# ...          ...       ...          ...       ...         ...            ...
# 9.0         30.7       0.0          7.6      12.1         NNW           76.0
# 7.1         28.4       0.0         11.6      12.7           N           48.0
# 12.5        19.9       0.0          8.4       5.3         ESE           43.0
# 12.5        26.9       0.0          5.0       7.1          NW           46.0
# 12.3        30.2       0.0          6.0      12.6          NW           78.0
#
# ...

# %%
data.set_index('MinTemp',inplace=True)

# %%
data.loc[8.0] # which shows the value corresponding to the MinTemp 8.0
# Out:
# MaxTemp            24.3
# Rainfall            0.0
# Evaporation         3.4
# Sunshine            6.3
# WindGustDir          NW
# WindGustSpeed      30.0
# WindDir9am           SW
# WindDir3pm           NW
# WindSpeed9am        6.0
# WindSpeed3pm         20
# Humidity9am          68
# Humidity3pm          29
# Pressure9am      1019.7
# Pressure3pm      1015.0
# Cloud9am              7
# Cloud3pm              7
# Temp9am            14.4
# Temp3pm            23.6
# RainToday            No
# RISK_MM             3.6
# RainTomorrow        Yes
# Name: 8.0, dtype: object

# %%
data.set_index('WindGustDir',inplace=True)

# %%
data.loc['NW'] #which is similar to data[data.WindGustDir=='NW']
# Out:
#              MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# WindGustDir
# NW              24.3       0.0          3.4       6.3           30.0
# NW              23.4       3.6          5.8       3.3           85.0
# NW              15.5      39.8          7.2       9.1           54.0
# NW              30.9       0.0          6.2      12.4           44.0
# NW              31.2       0.0          8.8      13.1           41.0
# ...              ...       ...          ...       ...            ...
# NW              24.7       0.0          5.4       8.6           43.0
# NW              28.5       0.0          5.8       9.8           46.0
# NW              27.4       0.2          7.6      12.1           52.0
# NW              26.9       0.0          5.0       7.1           46.0
# NW              30.2       0.0          6.0      12.6           78.0
#
#             WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# WindGustDir
# ...

# %%
data[data['WindGustDir']=='NW']   #shows error since we change the data as WindGustDir as index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WindGustDir'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data[data['WindDir3pm']=='NW']  #since wi did not set windDir3pm as index for data
# Out:
#              MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# WindGustDir
# NW              24.3       0.0          3.4       6.3           30.0
# N               25.2       0.0          4.2      11.9           30.0
# E               27.3       0.2          7.2      12.5           41.0
# WNW             27.9       0.0          7.2      13.0           30.0
# WNW             33.4       0.0          8.8       9.5           59.0
# ...              ...       ...          ...       ...            ...
# NW              21.0       0.0          4.2      12.2           28.0
# NW              24.7       0.0          5.4       8.6           43.0
# NW              28.5       0.0          5.8       9.8           46.0
# NW              27.4       0.2          7.6      12.1           52.0
# NNW             30.7       0.0          7.6      12.1           76.0
#
#             WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# WindGustDir
# ...

# %%
data.reset_index(inplace=True) #retrives the original data that means delete the changes that takes place in index of the data,if we run data.loc['NW'] its shows error
data
# Out:
#     WindGustDir  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0            NW     24.3       0.0          3.4       6.3           30.0
# 1           ENE     26.9       3.6          4.4       9.7           39.0
# 2            NW     23.4       3.6          5.8       3.3           85.0
# 3            NW     15.5      39.8          7.2       9.1           54.0
# 4           SSE     16.1       2.8          5.6      10.6           50.0
# ..          ...      ...       ...          ...       ...            ...
# 361         NNW     30.7       0.0          7.6      12.1           76.0
# 362           N     28.4       0.0         11.6      12.7           48.0
# 363         ESE     19.9       0.0          8.4       5.3           43.0
# 364          NW     26.9       0.0          5.0       7.1           46.0
# 365          NW     30.2       0.0          6.0      12.6           78.0
#
#     WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Humidity3pm  \
# ...

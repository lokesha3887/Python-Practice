# %%
# text file
f=open('bm_test.txt','r') # 'r'--read, 'w'--write, 'a'--appending,'+'--for both reading and writing
content=f.read()   #read--reading data,readline--reading data line by line, readlines--reading data in a single list
f.close() # once we close we can't write to this text file
print(content)
# Out:
# BMP is the file extension for a Windows bitmap file.
# Iam learning python

# %%
# writing into the file
f1=open('bm_test.txt','a') # when we appending we should use 'a'
f1.write('\nIam learning python')
f1.close() # we should close the file after writing otherwise it won't gets added if open file with no need of closing
f1=open('bm_test.txt','r')
content=f1.read()
f1.close()
print(content)
# Out:
# BMP is the file extension for a Windows bitmap file.
# Iam learning python

# %%
#reading file using 'with'
with open('bm_test.txt','r') as file:
    content=file.read() # here contest manager close the file itself
print(content)
# Out:
# BMP is the file extension for a Windows bitmap file.
# Iam learning python

# %%
# writing into the existing file
with open('bm_test.txt','a') as file:
    file.write('\npython is a general purpose hugh level language') ## here contest manager close the file itself

# %%
with open('bm_test.txt','r') as file:
    content=file.read()
    print(content)
    file.seek(0) # for setting curser in 1st position
    content=file.read()
    print('hi gm')
    print(content)
# Out:
# BMP is the file extension for a Windows bitmap file.
# Iam learning pythonpython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level language
# hi gm
# BMP is the file extension for a Windows bitmap file.
# Iam learning pythonpython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level language

# %%
with open('bm_test.txt','r') as file:
    content1=file.readline() # which reads only one line
    content2=file.readline()
print(content1)
print(content2) #which gives space line to line to avoid this we use strip
# Out:
# BMP is the file extension for a Windows bitmap file.
#
# Iam learning pythonpython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level language

# %%
with open('bm_test.txt','r') as file:
    content1=file.readline().strip()
    content2=file.readline().strip()  #for removing the space from line to line
print(content1)
print(content2)
# Out:
# BMP is the file extension for a Windows bitmap file.
# Iam learning pythonpython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level language

# %%
with open('bm_test.txt','r') as file:
    content1=file.readlines()# will read all lines and return a list and for readlines strip is not aplicable due to list object
    print(content1)
# Out:
# ['BMP is the file extension for a Windows bitmap file.\n', 'Iam learning pythonpython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level language']

# %%
# reading lines using for loop
with open('bm_test.txt','r') as file:
    for i in file:
        print(i.strip())
# Out:
# BMP is the file extension for a Windows bitmap file.
# Iam learning pythonpython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level languagepython is a general purpose hugh level language

# %%
#reading file for some calculation
with open('LA1.txt','r') as data:
    data=data.read()
    print(data)
# Out:
# 2018-MC-01	Muhammad Usman	4
# 2018-MC-02	Tahir Mehmood	0.5
# 2018-MC-03	Muhammad Bilal	2.5
# 2018-MC-04	Muhammad Nadeem	3.5
# 2018-MC-05	Muhammad Ahmad Iftikhar	4.5
# 2018-MC-06	Syed Faraz Abbas	1
# 2018-MC-07	Muhammad Qasim	A
# 2018-MC-08	Muhammad Ghufran	4
# 2018-MC-09	Taimoor Sikandar	2
# 2018-MC-10	Muhammad Moadib Nasir	3.5
# 2018-MC-11	Sheikh Osama Fazal	2
# 2018-MC-12	Roshaan Sajjad	4
# 2018-MC-13	Muhammad Awais Akhter	3
# 2018-MC-14	Muhammad Kazim Raza	3
# 2018-MC-15	Omar Ashraf	A
# 2018-MC-16	Muhammad Asaad	3.5
# 2018-MC-17	Abdul Majid	3.5
# 2018-MC-18	Muhammad Awais	1.5
# 2018-MC-19	Muhammad Ali Hadir	4
# 2018-MC-20	Jahanzaib Aslam	2.5
# 2018-MC-21	Muhammad Ibtisam Umer	4
# 2018-MC-22	Tufail Hussain	3
# 2018-MC-23	M Atif Riaz	4.5
# 2018-MC-24	Muhammad Abdullah	3.5
# 2018-MC-25	Ahmad Shaukat	3.5
# 2018-MC-26	Muhammad Nauman	5
# 2018-MC-27	Hamza Rizwan	3
# 2018-MC-28	Burhan Azeem	2
# 2018-MC-29	Muhammad Sikander Raheem	3.5
# 2018-MC-30	Muhammad Abdullah	3
# 2018-MC-31	Mian Ali Haider	3.5
# 2018-MC-32	Muhammad Irfan Saleem	1
# 2018-MC-33	Muhammad Hamza Mushtaq	4.5
# 2018-MC-34	Jamshaid Zafar	4.5
# 2018-MC-35	Zamara Batool	1.5
# 2018-MC-36	Noor Ul Ain	4
# 2018-MC-37	Farwa Mehmood	5
# 2018-MC-38	Tanzeela Arif	1
# 2018-MC-39	Samra Yousaf	0
# 2018-MC-40	Ayesha Aslam	2
# 2018-MC-41	Maryum Kainat	3
# 2018-MC-42	Hadiqa	4
# 2018-MC-43	Iram	4
# 2018-MC-44	Rida Fatima	4.5
# 2018-MC-45	Mahesh Sharma	2.5
# 2018-MC-46	Faqeeha Khan	3.5
# 2018-R/2017-MC-29	Abdul Manan	1.5
# 2018-R/2017-MC-36	Hafiz M. Waleed Shoaib	2
# 2018-R/2017-MC-37	Ikram Khan	A
# 2018-MC-51	Danish	4.5
# 2018-MC-52	Hafiz Muhammad Aqib Ali	4.5
# 2018-MC-53	Muhammad Ibrahim	4
# 2018-MC-54	Hamayoun Qamar Qureshi	3
# 2018-MC-55	Muhammad Abdul Wahab	4
# 2018-MC-56	Muhammad Ehtisham Zafar	4
# 2018-MC-58	Muhammad Faisal Shahid	4.5
# 2018-MC-59	Ahmad Hussain	5
# 2018-MC-60	Shahroz Ahmed	5
# 2018-MC-61	M Sannan Arshad	4.5
# 2018-MC-62	Khaqan Ahmed	4.5
# 2018-MC-63	Arbab Khalid	3.5
# 2018-MC-64	Talha Khan	4
# 2018-MC-65	Abdul Rehman Baig	3.5
# 2018-MC-66	Muhammad Ammar	4.5
# 2018-MC-67	Mohammad Hozefa Saleem	2.5
# 2018-MC-68	Muhammad Abdullah	4.5
# 2018-MC-69	Ali Zaman	5
# 2018-MC-70	Syed Waqar Haider Bukhari	2.5
# 2018-MC-72	Mian M.Husnain Akram	5
# 2018-MC-73	Shahzad Niaz	4.5
# 2018-MC-74	Waleed Bin Qaisar	4
# 2018-MC-75	Huzaifa Imtiaz	4
# 2018-MC-76	Ibtisam Ul Hassan	4
# 2018-MC-77	Muhammad Usman Ghani	3.5
# 2018-MC-78	Aurang Zaib Younis Virk	4.5
# 2018-MC-79	Hassan Abdul Basit	4.5
# 2018-MC-80	Taimoor Ahmed Pal	5
# 2018-MC-81	Hafiz Muhammad Usman Ahmed	5
# 2018-MC-82	Tayyab Rasheed	3.5
# 2018-MC-83	Usama Iqbal	5
# 2018-MC-84	Ahtesham Zafar	1.5
# 2018-MC-85	Assad Ali	3.5
# 2018-MC-86	Mazhar Mustafa	2
# 2018-MC-87	Muhammad Muneeb Irfan Mughal	4.5
# 2018-MC-88	Abdul Rehman	4.5
# 2018-MC-89	Syeda Tayyaba Bukhari	5
# 2018-MC-90	Maheen Abdul Ghani	5
# 2018-MC-91	Faryal Nasir	3.5
# 2018-MC-92	Ayesha Nadeem	3
# 2018-MC-93	Aqsa Amjad	5
# 2018-MC-94	Arfa Nisar	4.5
# 2018-MC-95	Iqra Amjad	5
# 2018-MC-96	Noor Fatima	3
# 2018-R/2017-MC-47	Muhammad Abdullah	5
# 2018-R/2017-MC-77	Muhammad Faseeh Bin Naeem	4
# 2018-R/2017-MC-103	Jehanzeb Hussain	A

# %%
# for getting students who secure full marks (5)
with open('LA1.txt','r') as data:
    for i in data:
        i=i.strip()
        l=i.split('\t') # which splits strings into a list
        #print(l)
        if l[2]=='5':
            print(l)
# Out:
# ['2018-MC-26', 'Muhammad Nauman', '5']
# ['2018-MC-37', 'Farwa Mehmood', '5']
# ['2018-MC-59', 'Ahmad Hussain', '5']
# ['2018-MC-60', 'Shahroz Ahmed', '5']
# ['2018-MC-69', 'Ali Zaman', '5']
# ['2018-MC-72', 'Mian M.Husnain Akram', '5']
# ['2018-MC-80', 'Taimoor Ahmed Pal', '5']
# ['2018-MC-81', 'Hafiz Muhammad Usman Ahmed', '5']
# ['2018-MC-83', 'Usama Iqbal', '5']
# ['2018-MC-89', 'Syeda Tayyaba Bukhari', '5']
# ['2018-MC-90', 'Maheen Abdul Ghani', '5']
# ['2018-MC-93', 'Aqsa Amjad', '5']
# ['2018-MC-95', 'Iqra Amjad', '5']
# ['2018-R/2017-MC-47', 'Muhammad Abdullah', '5']

# %%
# writing files using with
a=['\nIam','\tleaning now']
with open('write.txt','w') as f: # if write file doesn't exist then this file will be created
    f.write('python\t')
    f.write('i a\t')
    f.write('programming language\t')
    f.writelines(a) # observe a

# %%
# importing text files
jabber = open('Jabberwocky.txt', 'r')

for line in jabber:
    print(line.rstrip()) # rstrip clears the space from right side 
    # print(len(line))

jabber.close()
# Out:
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# "Beware the Jabberwock, my son!
# The jaws that bite, the claws that catch!
# Beware the Jubjub bird, and shun
# The frumious Bandersnatch!"
#
# He took his vorpal sword in hand:
# Long time the manxome foe he soughtâ€”
# So rested he by the Tumtum tree,
# And stood awhile in thought.
#
# And as in uffish thought he stood,
# The Jabberwock, with eyes of flame,
# Came whiffling through the tulgey wood,
# And burbled as it came!
#
# One two! One two! And through and through
# The vorpal blade went snicker-snack!
# He left it dead, and with its head
# He went galumphing back.
#
# "And hast thou slain the Jabberwock?
# Come to my arms, my beamish boy!"
# "O frabjous day! Callooh! Callay!"
# He chortled in his joy.
#
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# â€“ Lewis Carroll

# %%
jabber = open('Jabberwocky.txt', 'r')

for line in jabber:
    print(line.lstrip()) # put only strip for not modifying string
    #print(len(line))
# Out:
# 'Twas brillig, and the slithy toves
#
# Did gyre and gimble in the wabe;
#
# All mimsy were the borogoves,
#
# And the mome raths outgrabe.
#
#
# "Beware the Jabberwock, my son!
#
# The jaws that bite, the claws that catch!
#
# Beware the Jubjub bird, and shun
#
# The frumious Bandersnatch!"
#
#
# He took his vorpal sword in hand:
#
# Long time the manxome foe he soughtâ€”
#
# So rested he by the Tumtum tree,
#
# And stood awhile in thought.
#
#
# And as in uffish thought he stood,
#
# The Jabberwock, with eyes of flame,
#
# Came whiffling through the tulgey wood,
#
# And burbled as it came!
#
#
# One two! One two! And through and through
#
# The vorpal blade went snicker-snack!
#
# He left it dead, and with its head
#
# He went galumphing back.
#
#
# "And hast thou slain the Jabberwock?
#
# Come to my arms, my beamish boy!"
#
# "O frabjous day! Callooh! Callay!"
#
# He chortled in his joy.
#
#
# 'Twas brillig, and the slithy toves
#
# Did gyre and gimble in the wabe;
#
# All mimsy were the borogoves,
#
# And the mome raths outgrabe.
#
#
# â€“ Lewis Carroll

# %%
with open('Jabberwocky.txt', 'r') as jabber:
    for line in jabber:
        print(line.rstrip())
        lines = jabber.readlines()

print(lines)

for line in reversed(lines): # reversing
    print(line, end='')  # do some processing in reverse order

# with open('Jabberwocky.txt') as jabber:
#     text = jabber.read()
#
# # print(text)
# for character in reversed(text):
#     print(character, end='')
# Out:
# 'Twas brillig, and the slithy toves
# ['Did gyre and gimble in the wabe;\n', 'All mimsy were the borogoves,\n', 'And the mome raths outgrabe.\n', '\n', '"Beware the Jabberwock, my son!\n', 'The jaws that bite, the claws that catch!\n', 'Beware the Jubjub bird, and shun\n', 'The frumious Bandersnatch!"\n', '\n', 'He took his vorpal sword in hand:\n', 'Long time the manxome foe he soughtâ€”\n', 'So rested he by the Tumtum tree,\n', 'And stood awhile in thought.\n', '\n', 'And as in uffish thought he stood,\n', 'The Jabberwock, with eyes of flame,\n', 'Came whiffling through the tulgey wood,\n', 'And burbled as it came!\n', '\n', 'One two! One two! And through and through\n', 'The vorpal blade went snicker-snack!\n', 'He left it dead, and with its head\n', 'He went galumphing back.\n', '\n', '"And hast thou slain the Jabberwock?\n', 'Come to my arms, my beamish boy!"\n', '"O frabjous day! Callooh! Callay!"\n', 'He chortled in his joy.\n', '\n', "'Twas brillig, and the slithy toves\n", 'Did gyre and gimble in the wabe;\n', 'All mimsy were the borogoves,\n', 'And the mome raths outgrabe.\n', '\n', '    â€“ Lewis Carroll\n']
#     â€“ Lewis Carroll
#
# And the mome raths outgrabe.
# All mimsy were the borogoves,
# Did gyre and gimble in the wabe;
# 'Twas brillig, and the slithy toves
#
# He chortled in his joy.
# "O frabjous day! Callooh! Callay!"
# Come to my arms, my beamish boy!"
# "And hast thou slain the Jabberwock?
#
# He went galumphing back.
# He left it dead, and with its head
# The vorpal blade went snicker-snack!
# One two! One two! And through and through
#
# And burbled as it came!
# Came whiffling through the tulgey wood,
# The Jabberwock, with eyes of flame,
# And as in uffish thought he stood,
#
# And stood awhile in thought.
# So rested he by the Tumtum tree,
# Long time the manxome foe he soughtâ€”
# He took his vorpal sword in hand:
#
# The frumious Bandersnatch!"
# Beware the Jubjub bird, and shun
# The jaws that bite, the claws that catch!
# "Beware the Jabberwock, my son!
#
# And the mome raths outgrabe.
# All mimsy were the borogoves,
# Did gyre and gimble in the wabe;

# %%
with open('Jabberwocky.txt') as jabber:
    text = jabber.read()

print(text)
for character in reversed(text):
    print(character, end='')
# Out:
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# "Beware the Jabberwock, my son!
# The jaws that bite, the claws that catch!
# Beware the Jubjub bird, and shun
# The frumious Bandersnatch!"
#
# He took his vorpal sword in hand:
# Long time the manxome foe he soughtâ€”
# So rested he by the Tumtum tree,
# And stood awhile in thought.
#
# And as in uffish thought he stood,
# The Jabberwock, with eyes of flame,
# Came whiffling through the tulgey wood,
# And burbled as it came!
#
# One two! One two! And through and through
# The vorpal blade went snicker-snack!
# He left it dead, and with its head
# He went galumphing back.
#
# "And hast thou slain the Jabberwock?
# Come to my arms, my beamish boy!"
# "O frabjous day! Callooh! Callay!"
# He chortled in his joy.
#
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
#     â€“ Lewis Carroll
#
#
# llorraC siweL “€â
#
# .ebargtuo shtar emom eht dnA
# ,sevogorob eht erew ysmim llA
# ;ebaw eht ni elbmig dna eryg diD
# sevot yhtils eht dna ,gillirb sawT'
#
# .yoj sih ni deltrohc eH
# "!yallaC !hoollaC !yad suojbarf O"
# "!yob hsimaeb ym ,smra ym ot emoC
# ?kcowrebbaJ eht nials uoht tsah dnA"
#
# .kcab gnihpmulag tnew eH
# daeh sti htiw dna ,daed ti tfel eH
# !kcans-rekcins tnew edalb laprov ehT
# hguorht dna hguorht dnA !owt enO !owt enO
#
# !emac ti sa delbrub dnA
# ,doow yeglut eht hguorht gnilffihw emaC
# ,emalf fo seye htiw ,kcowrebbaJ ehT
# ,doots eh thguoht hsiffu ni sa dnA
#
# .thguoht ni elihwa doots dnA
# ,eert mutmuT eht yb eh detser oS
# ”€âthguos eh eof emoxnam eht emit gnoL
# :dnah ni drows laprov sih koot eH
#
# "!hctansrednaB suoimurf ehT
# nuhs dna ,drib bujbuJ eht eraweB
# !hctac taht swalc eht ,etib taht swaj ehT
# !nos ym ,kcowrebbaJ eht eraweB"
#
# .ebargtuo shtar emom eht dnA
# ,sevogorob eht erew ysmim llA
# ;ebaw eht ni elbmig dna eryg diD
# sevot yhtils eht dna ,gillirb sawT'

# %%
with open('Jabberwocky.txt', 'r') as jabber:
    for line in jabber:
        print(line.rstrip())
        lines = jabber.readlines()
print(lines[-1:])
for line in reversed(lines):
    print(line, end='')  # do some processing in reverse order
# Out:
# 'Twas brillig, and the slithy toves
# ['    â€“ Lewis Carroll\n']
#     â€“ Lewis Carroll
#
# And the mome raths outgrabe.
# All mimsy were the borogoves,
# Did gyre and gimble in the wabe;
# 'Twas brillig, and the slithy toves
#
# He chortled in his joy.
# "O frabjous day! Callooh! Callay!"
# Come to my arms, my beamish boy!"
# "And hast thou slain the Jabberwock?
#
# He went galumphing back.
# He left it dead, and with its head
# The vorpal blade went snicker-snack!
# One two! One two! And through and through
#
# And burbled as it came!
# Came whiffling through the tulgey wood,
# The Jabberwock, with eyes of flame,
# And as in uffish thought he stood,
#
# And stood awhile in thought.
# So rested he by the Tumtum tree,
# Long time the manxome foe he soughtâ€”
# He took his vorpal sword in hand:
#
# The frumious Bandersnatch!"
# Beware the Jubjub bird, and shun
# The jaws that bite, the claws that catch!
# "Beware the Jabberwock, my son!
#
# And the mome raths outgrabe.
# All mimsy were the borogoves,
# Did gyre and gimble in the wabe;

# %%
with open('Jabberwocky.txt') as jabber:
    while True:
        line = jabber.readline().rstrip()
        print(line)
        if 'jubjub' in line.casefold():
            break
#or
print('*' * 80)

with open('Jabberwocky.txt') as jabber:
    for line in jabber:
        print(line.rstrip())
        if 'jubjub' in line.casefold():
            break
# Out:
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# "Beware the Jabberwock, my son!
# The jaws that bite, the claws that catch!
# Beware the Jubjub bird, and shun
# ********************************************************************************
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# "Beware the Jabberwock, my son!
# The jaws that bite, the claws that catch!
# Beware the Jubjub bird, and shun

# %%
#strip 
filename = 'Jabberwocky.txt'
with open(filename) as poem:
    first = poem.readline().rstrip() #which gives 1st line i the poem

print(first)

chars = "' Twas"
no_apostrophe = first.strip(chars) #deleting twas from first line
print(no_apostrophe)

print('x'*30)

for character in first:
    if character in chars:
        print(f'removing "{character}"')
    else:
        break

print('*' * 80)

for character in first[::-1]:  # process backwards
    if character in chars:
        print(f'removing "{character}"')
    else:
        break
# Out:
# 'Twas brillig, and the slithy toves
# brillig, and the slithy tove
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# removing "'"
# removing "T"
# removing "w"
# removing "a"
# removing "s"
# removing " "
# ********************************************************************************
# removing "s"

# %%
# parshing text data
input_filename = 'country_info.txt'

with open(input_filename) as country_file:
    for row in country_file:
        print(row.strip())
        data = row.strip('\n').split('|') #here stripping the space line to line and splitting values based on '|' 
        print(data)   # splitting returns a list
        
# first line is original data and 2nd one is parshing data
# Out:
# Country|Capital|CC|CC3|IAC|TimeZone|Currency
# ['Country', 'Capital', 'CC', 'CC3', 'IAC', 'TimeZone', 'Currency']
# Afghanistan|Kabul|AF|AFG|+93|UTC+04:30|Afghan afghani
# ['Afghanistan', 'Kabul', 'AF', 'AFG', '+93', 'UTC+04:30', 'Afghan afghani']
# Aland Islands|Mariehamn|AX|ALA|+358|UTC+02:00|Euro
# ['Aland Islands', 'Mariehamn', 'AX', 'ALA', '+358', 'UTC+02:00', 'Euro']
# Albania|Tirana|AL|ALB|+355|UTC+01:00|Albanian lek
# ['Albania', 'Tirana', 'AL', 'ALB', '+355', 'UTC+01:00', 'Albanian lek']
# Algeria|Algiers|DZ|DZA|+213|UTC|Algerian dinar
# ['Algeria', 'Algiers', 'DZ', 'DZA', '+213', 'UTC', 'Algerian dinar']
# American Samoa|Pago Pago|AS|ASM|+1 684|UTC-11:00|
# ['American Samoa', 'Pago Pago', 'AS', 'ASM', '+1 684', 'UTC-11:00', '']
# Andorra|Andorra la Vella|AD|AND|+376|UTC+01:00|Euro
# ['Andorra', 'Andorra la Vella', 'AD', 'AND', '+376', 'UTC+01:00', 'Euro']
# Angola|Luanda|AO|AGO|+244|UTC+01:00|Angolan kwanza
# ['Angola', 'Luanda', 'AO', 'AGO', '+244', 'UTC+01:00', 'Angolan kwanza']
# Anguilla|The Valley|AI|AIA|+1 264|UTC-04:00|East Caribbean dollar
# ['Anguilla', 'The Valley', 'AI', 'AIA', '+1 264', 'UTC-04:00', 'East Caribbean dollar']
# Antarctica||AQ|ATA|||
# ['Antarctica', '', 'AQ', 'ATA', '', '', '']
# Antigua and Barbuda|St. John's|AG|ATG|+1 268|UTC-04:00|East Caribbean dollar
# ['Antigua and Barbuda', "St. John's", 'AG', 'ATG', '+1 268', 'UTC-04:00', 'East Caribbean dollar']
# Argentina|Buenos Aires|AR|ARG|+54|UTC-03:00|Argentine peso
# ['Argentina', 'Buenos Aires', 'AR', 'ARG', '+54', 'UTC-03:00', 'Argentine peso']
# Armenia|Yerevan|AM|ARM|+374|UTC+04:00|Armenian dram
# ['Armenia', 'Yerevan', 'AM', 'ARM', '+374', 'UTC+04:00', 'Armenian dram']
# Aruba|Oranjestad|AW|ABW|+297|UTC-04:00|Aruban florin
# ['Aruba', 'Oranjestad', 'AW', 'ABW', '+297', 'UTC-04:00', 'Aruban florin']
# Australia|Canberra|AU|AUS|+61|UTC+07:00 - UTC+10:00|Australian dollar
# ['Australia', 'Canberra', 'AU', 'AUS', '+61', 'UTC+07:00 - UTC+10:00', 'Australian dollar']
# Austria|Vienna|AT|AUT|+43|UTC+01:00|Euro
# ['Austria', 'Vienna', 'AT', 'AUT', '+43', 'UTC+01:00', 'Euro']
# Azerbaijan|Baku|AZ|AZE|+994|UTC+04:00|Azerbaijani manat
# ['Azerbaijan', 'Baku', 'AZ', 'AZE', '+994', 'UTC+04:00', 'Azerbaijani manat']
# Bahamas|Nassau|BS|BHS|+1 242|UTC-05:00|Bahamian dollar
# ['Bahamas', 'Nassau', 'BS', 'BHS', '+1 242', 'UTC-05:00', 'Bahamian dollar']
# Bahrain|Manama|BH|BHR|+973|UTC+03:00|Bahraini dinar
# ['Bahrain', 'Manama', 'BH', 'BHR', '+973', 'UTC+03:00', 'Bahraini dinar']
# Bangladesh|Dhaka|BD|BGD|+880|UTC+06:00|Bangladeshi taka
# ['Bangladesh', 'Dhaka', 'BD', 'BGD', '+880', 'UTC+06:00', 'Bangladeshi taka']
# Barbados|Bridgetown|BB|BRB|+1 246|UTC-04:00|Barbadian dollar
# ['Barbados', 'Bridgetown', 'BB', 'BRB', '+1 246', 'UTC-04:00', 'Barbadian dollar']
# Belarus|Minsk|BY|BLR|+375|UTC+03:00|Belarusian ruble
# ['Belarus', 'Minsk', 'BY', 'BLR', '+375', 'UTC+03:00', 'Belarusian ruble']
# Belgium|Brussels|BE|BEL|+32|UTC+01:00|Euro
# ['Belgium', 'Brussels', 'BE', 'BEL', '+32', 'UTC+01:00', 'Euro']
# Belize|Belmopan|BZ|BLZ|+501|UTC-06:00|Belize dollar
# ['Belize', 'Belmopan', 'BZ', 'BLZ', '+501', 'UTC-06:00', 'Belize dollar']
# Benin|Porto-Novo|BJ|BEN|+229|UTC+01:00|West African CFA franc
# ['Benin', 'Porto-Novo', 'BJ', 'BEN', '+229', 'UTC+01:00', 'West African CFA franc']
# Bermuda|Hamilton|BM|BMU|+1 441|UTC-04:00|Bermudian dollar
# ['Bermuda', 'Hamilton', 'BM', 'BMU', '+1 441', 'UTC-04:00', 'Bermudian dollar']
# Bhutan|Thimphu|BT|BTN|+975|UTC+05:30|Bhutanese ngultrum
# ['Bhutan', 'Thimphu', 'BT', 'BTN', '+975', 'UTC+05:30', 'Bhutanese ngultrum']
# Bolivia|Sucre|BO|BOL|+591|UTC-04:00|Bolivian boliviano
# ['Bolivia', 'Sucre', 'BO', 'BOL', '+591', 'UTC-04:00', 'Bolivian boliviano']
# Bonaire|Kralendijk|BQ|BES|+599|UTC-04:00|United States dollar
# ['Bonaire', 'Kralendijk', 'BQ', 'BES', '+599', 'UTC-04:00', 'United States dollar']
# Bosnia and Herzegovina|Sarajevo|BA|BIH|+387|UTC+01:00|Bosnia and Herzegovina convertible mark
# ['Bosnia and Herzegovina', 'Sarajevo', 'BA', 'BIH', '+387', 'UTC+01:00', 'Bosnia and Herzegovina convertible mark']
# Botswana|Gaborone|BW|BWA|+267|UTC+02:00|Botswana pula
# ['Botswana', 'Gaborone', 'BW', 'BWA', '+267', 'UTC+02:00', 'Botswana pula']
# Bouvet Island||BV|BVT||UTC+01:00|
# ['Bouvet Island', '', 'BV', 'BVT', '', 'UTC+01:00', '']
# Brazil|BrasÃ­lia|BR|BRA|+55|UTC-05:00 - UTC-03:00|Brazilian real
# ['Brazil', 'BrasÃ\xadlia', 'BR', 'BRA', '+55', 'UTC-05:00 - UTC-03:00', 'Brazilian real']
# British Indian Ocean Territory|Diego Garcia|IO|IOT|+246|UTC+06|United States dollar
# ['British Indian Ocean Territory', 'Diego Garcia', 'IO', 'IOT', '+246', 'UTC+06', 'United States dollar']
# Brunei|Bandar Seri Begawan|BN|BRN|+673|UTC+08:00|Brunei dollar
# ['Brunei', 'Bandar Seri Begawan', 'BN', 'BRN', '+673', 'UTC+08:00', 'Brunei dollar']
# Bulgaria|Sofia|BG|BGR|+359|UTC+02:00|Bulgarian lev
# ['Bulgaria', 'Sofia', 'BG', 'BGR', '+359', 'UTC+02:00', 'Bulgarian lev']
# Burkina Faso|Ouagadougou|BF|BFA|+226|UTC|West African CFA franc
# ['Burkina Faso', 'Ouagadougou', 'BF', 'BFA', '+226', 'UTC', 'West African CFA franc']
# Burundi|Bujumbura|BI|BDI|+257|UTC+02:00|Burundian franc
# ['Burundi', 'Bujumbura', 'BI', 'BDI', '+257', 'UTC+02:00', 'Burundian franc']
# Cambodia|Phnom Penh|KH|KHM|+855|UTC+07:00|Cambodian riel
# ['Cambodia', 'Phnom Penh', 'KH', 'KHM', '+855', 'UTC+07:00', 'Cambodian riel']
# Cameroon|YaoundÃ©|CM|CMR|+237|UTC+01:00|Central African CFA franc
# ['Cameroon', 'YaoundÃ©', 'CM', 'CMR', '+237', 'UTC+01:00', 'Central African CFA franc']
# Canada|Ottawa|CA|CAN|+1|UTC-08:00 - UTC-04:00|Canadian dollar
# ['Canada', 'Ottawa', 'CA', 'CAN', '+1', 'UTC-08:00 - UTC-04:00', 'Canadian dollar']
# Cape Verde|Praia|CV|CPV|+238|UTC-01:00|Cape Verdean escudo
# ['Cape Verde', 'Praia', 'CV', 'CPV', '+238', 'UTC-01:00', 'Cape Verdean escudo']
# Cayman Islands|George Town|KY|CYM|+1 345|UTC-05:00|Cayman Islands dollar
# ['Cayman Islands', 'George Town', 'KY', 'CYM', '+1 345', 'UTC-05:00', 'Cayman Islands dollar']
# Central African Republic|Bangui|CF|CAF|+236|UTC+01:00|Central African CFA franc
# ['Central African Republic', 'Bangui', 'CF', 'CAF', '+236', 'UTC+01:00', 'Central African CFA franc']
# Chad|N'Djamena|TD|TCD|+235|UTC+01:00|Central African CFA franc
# ['Chad', "N'Djamena", 'TD', 'TCD', '+235', 'UTC+01:00', 'Central African CFA franc']
# Chile|Santiago|CL|CHL|+56|UTC-04:00|Chilean peso
# ['Chile', 'Santiago', 'CL', 'CHL', '+56', 'UTC-04:00', 'Chilean peso']
# China|Beijing|CN|CHN|+86|UTC+08:00|Chinese yuan
# ['China', 'Beijing', 'CN', 'CHN', '+86', 'UTC+08:00', 'Chinese yuan']
# Christmas Island|Flying Fish Cove|CX|CXR|+61 8 9164|UTC+07|Australian dollar
# ['Christmas Island', 'Flying Fish Cove', 'CX', 'CXR', '+61 8 9164', 'UTC+07', 'Australian dollar']
# Cocos (Keeling) Islands|West Island|CC|CCK|+61 8 9162|UTC+06:30|Australian dollar
# ['Cocos (Keeling) Islands', 'West Island', 'CC', 'CCK', '+61 8 9162', 'UTC+06:30', 'Australian dollar']
# Colombia|BogotÃ¡|CO|COL|+57|UTC-05:00|Colombian peso
# ['Colombia', 'BogotÃ¡', 'CO', 'COL', '+57', 'UTC-05:00', 'Colombian peso']
# Comoros|Moroni|KM|COM|+269|UTC+03:00|Comorian franc
# ['Comoros', 'Moroni', 'KM', 'COM', '+269', 'UTC+03:00', 'Comorian franc']
# Congo, Republic of the|Brazzaville|CG|COG|+242|UTC+01:00|Central African CFA franc
# ['Congo, Republic of the', 'Brazzaville', 'CG', 'COG', '+242', 'UTC+01:00', 'Central African CFA franc']
# Congo, Democratic Republic of the|Kinshasa|CD|COD|+243|UTC+01:00 - UTC+02:00|Congolese franc
# ['Congo, Democratic Republic of the', 'Kinshasa', 'CD', 'COD', '+243', 'UTC+01:00 - UTC+02:00', 'Congolese franc']
# Cook Islands|Avarua|CK|COK|+682|UTC-10:00|New Zealand dollar
# ['Cook Islands', 'Avarua', 'CK', 'COK', '+682', 'UTC-10:00', 'New Zealand dollar']
# Costa Rica|San JosÃ©|CR|CRI|+506|UTC-06:00|Costa Rican colÃ³n
# ['Costa Rica', 'San JosÃ©', 'CR', 'CRI', '+506', 'UTC-06:00', 'Costa Rican colÃ³n']
# CÃ´te d'Ivoire|Yamoussoukro|CI|CIV|+225|UTC|West African CFA franc
# ["CÃ´te d'Ivoire", 'Yamoussoukro', 'CI', 'CIV', '+225', 'UTC', 'West African CFA franc']
# Croatia|Zagreb|HR|HRV|+385|UTC+01:00|Croatian kuna
# ['Croatia', 'Zagreb', 'HR', 'HRV', '+385', 'UTC+01:00', 'Croatian kuna']
# Cuba|Havana|CU|CUB|+53|UTC-03:00|Cuban convertible peso
# ['Cuba', 'Havana', 'CU', 'CUB', '+53', 'UTC-03:00', 'Cuban convertible peso']
# Curacao|Willemstad|CW|CUW|+599 9|UTC-04:00|Netherlands Antillean guilder
# ['Curacao', 'Willemstad', 'CW', 'CUW', '+599 9', 'UTC-04:00', 'Netherlands Antillean guilder']
# Cyprus|Nicosia|CY|CYP|+357|UTC+02:00|Euro
# ['Cyprus', 'Nicosia', 'CY', 'CYP', '+357', 'UTC+02:00', 'Euro']
# Czech Republic|Prague|CZ|CZE|+420|UTC+01:00|Czech koruna
# ['Czech Republic', 'Prague', 'CZ', 'CZE', '+420', 'UTC+01:00', 'Czech koruna']
# Denmark|Copenhagen|DK|DNK|+45|UTC+01:00|Danish krone
# ['Denmark', 'Copenhagen', 'DK', 'DNK', '+45', 'UTC+01:00', 'Danish krone']
# Djibouti|Djibouti|DJ|DJI|+253|UTC+03:00|Djiboutian franc
# ['Djibouti', 'Djibouti', 'DJ', 'DJI', '+253', 'UTC+03:00', 'Djiboutian franc']
# Dominica|Roseau|DM|DMA|+1 767|UTC-04:00|East Caribbean dollar
# ['Dominica', 'Roseau', 'DM', 'DMA', '+1 767', 'UTC-04:00', 'East Caribbean dollar']
# Dominican Republic|Santo Domingo|DO|DOM|+1 809/829/849|UTC-04:00|Dominican peso
# ['Dominican Republic', 'Santo Domingo', 'DO', 'DOM', '+1 809/829/849', 'UTC-04:00', 'Dominican peso']
# East Timor|Dili|TL|TLS|+670|UTC+09|United States dollar
# ['East Timor', 'Dili', 'TL', 'TLS', '+670', 'UTC+09', 'United States dollar']
# Ecuador|Quito|EC|ECU|+593|UTC-05:00|United States dollar
# ['Ecuador', 'Quito', 'EC', 'ECU', '+593', 'UTC-05:00', 'United States dollar']
# Egypt|Cairo|EG|EGY|+20|UTC+02:00|Egyptian pound
# ['Egypt', 'Cairo', 'EG', 'EGY', '+20', 'UTC+02:00', 'Egyptian pound']
# El Salvador|San Salvador|SV|SLV|+503|UTC-06:00|Salvadoran colÃ³n
# ['El Salvador', 'San Salvador', 'SV', 'SLV', '+503', 'UTC-06:00', 'Salvadoran colÃ³n']
# Equatorial Guinea|Malabo|GQ|GNQ|+240|UTC+01:00|Central African CFA franc
# ['Equatorial Guinea', 'Malabo', 'GQ', 'GNQ', '+240', 'UTC+01:00', 'Central African CFA franc']
# Eritrea|Asmara|ER|ERI|+291|UTC+03:00|Eritrean nakfa
# ['Eritrea', 'Asmara', 'ER', 'ERI', '+291', 'UTC+03:00', 'Eritrean nakfa']
# Estonia|Tallinn|EE|EST|+372|UTC+03:00|Euro
# ['Estonia', 'Tallinn', 'EE', 'EST', '+372', 'UTC+03:00', 'Euro']
# Ethiopia|Addis Ababa|ET|ETH|+251|UTC+03:00|Ethiopian birr
# ['Ethiopia', 'Addis Ababa', 'ET', 'ETH', '+251', 'UTC+03:00', 'Ethiopian birr']
# Falkland Islands (Malvinas)|Stanley|FK|FLK|+500|UTC-04:00|Falkland Islands pound
# ['Falkland Islands (Malvinas)', 'Stanley', 'FK', 'FLK', '+500', 'UTC-04:00', 'Falkland Islands pound']
# Faroe Islands|TÃ³rshavn|FO|FRO|+298|UTC|Danish krone
# ['Faroe Islands', 'TÃ³rshavn', 'FO', 'FRO', '+298', 'UTC', 'Danish krone']
# Fiji|Suva|FJ|FJI|+679|UTC+12:00|Fijian dollar
# ['Fiji', 'Suva', 'FJ', 'FJI', '+679', 'UTC+12:00', 'Fijian dollar']
# Finland|Helsinki|FI|FIN|+358|UTC+02:00|Euro
# ['Finland', 'Helsinki', 'FI', 'FIN', '+358', 'UTC+02:00', 'Euro']
# France|Paris|FR|FRA|+33|UTC+01:00|Euro
# ['France', 'Paris', 'FR', 'FRA', '+33', 'UTC+01:00', 'Euro']
# French Guiana|Cayenne|GF|GUF|+594|UTC-01:00|Euro
# ['French Guiana', 'Cayenne', 'GF', 'GUF', '+594', 'UTC-01:00', 'Euro']
# French Polynesia|Papeete|PF|PYF|+689|UTC-10:00|CFP franc
# ['French Polynesia', 'Papeete', 'PF', 'PYF', '+689', 'UTC-10:00', 'CFP franc']
# French Southern Territories|Port-aux-FranÃ§ais|TF|ATF||UTC+05:00|Euro
# ['French Southern Territories', 'Port-aux-FranÃ§ais', 'TF', 'ATF', '', 'UTC+05:00', 'Euro']
# Gabon|Libreville|GA|GAB|+241|UTC+01:00|Central African CFA franc
# ['Gabon', 'Libreville', 'GA', 'GAB', '+241', 'UTC+01:00', 'Central African CFA franc']
# Gambia|Banjul|GM|GMB|+220|UTC|Gambian dalasi
# ['Gambia', 'Banjul', 'GM', 'GMB', '+220', 'UTC', 'Gambian dalasi']
# Georgia|Tbilisi|GE|GEO|+995|UTC+04:00|Georgian lari
# ['Georgia', 'Tbilisi', 'GE', 'GEO', '+995', 'UTC+04:00', 'Georgian lari']
# Germany|Berlin|DE|DEU|+49|UTC+01:00|Euro
# ['Germany', 'Berlin', 'DE', 'DEU', '+49', 'UTC+01:00', 'Euro']
# Ghana|Accra|GH|GHA|+233|UTC|Ghanaian cedi
# ['Ghana', 'Accra', 'GH', 'GHA', '+233', 'UTC', 'Ghanaian cedi']
# Gibraltar|Gibraltar|GI|GIB|+350|UTC+01:00|Gibraltar pound
# ['Gibraltar', 'Gibraltar', 'GI', 'GIB', '+350', 'UTC+01:00', 'Gibraltar pound']
# Greece|Athens|GR|GRC|+30|UTC+02:00|Euro
# ['Greece', 'Athens', 'GR', 'GRC', '+30', 'UTC+02:00', 'Euro']
# Greenland|Nuuk|GL|GRL|+299|UTC-03:00|Danish krone
# ['Greenland', 'Nuuk', 'GL', 'GRL', '+299', 'UTC-03:00', 'Danish krone']
# Grenada|St. George's|GD|GRD|+1 473|UTC-04:00|East Caribbean dollar
# ['Grenada', "St. George's", 'GD', 'GRD', '+1 473', 'UTC-04:00', 'East Caribbean dollar']
# Guadeloupe|Basse-Terre|GP|GLP|+590|UTC-04:00|Euro
# ['Guadeloupe', 'Basse-Terre', 'GP', 'GLP', '+590', 'UTC-04:00', 'Euro']
# Guam|HagÃ¥tÃ±a|GU|GUM|+1 671|UTC+10:00|United States dollar
# ['Guam', 'HagÃ¥tÃ±a', 'GU', 'GUM', '+1 671', 'UTC+10:00', 'United States dollar']
# Guatemala|Guatemala City|GT|GTM|+502|UTC-06:00|Guatemalan quetzal
# ['Guatemala', 'Guatemala City', 'GT', 'GTM', '+502', 'UTC-06:00', 'Guatemalan quetzal']
# Guernsey|St. Peter Port|GG|GGY|+44 1481|UTC|British pound
# ['Guernsey', 'St. Peter Port', 'GG', 'GGY', '+44 1481', 'UTC', 'British pound']
# Guinea|Conakry|GN|GIN|+224|UTC|Guinean franc
# ['Guinea', 'Conakry', 'GN', 'GIN', '+224', 'UTC', 'Guinean franc']
# Guinea-Bissau|Bissau|GW|GNB|+245|UTC|West African CFA franc
# ['Guinea-Bissau', 'Bissau', 'GW', 'GNB', '+245', 'UTC', 'West African CFA franc']
# Guyana|Georgetown|GY|GUY|+592|UTC-03:00|Guyanese dollar
# ['Guyana', 'Georgetown', 'GY', 'GUY', '+592', 'UTC-03:00', 'Guyanese dollar']
# Haiti|Port-au-Prince|HT|HTI|+509|UTC-05:00|Haitian gourde
# ['Haiti', 'Port-au-Prince', 'HT', 'HTI', '+509', 'UTC-05:00', 'Haitian gourde']
# Heard Island and McDonald Islands||HM|HMD||UTC+05|
# ['Heard Island and McDonald Islands', '', 'HM', 'HMD', '', 'UTC+05', '']
# Honduras|Tegucigalpa|HN|HND|+504|UTC-06:00|Honduran lempira
# ['Honduras', 'Tegucigalpa', 'HN', 'HND', '+504', 'UTC-06:00', 'Honduran lempira']
# Hong Kong||HK|HKG|+852|UTC+08:00|Hong Kong dollar
# ['Hong Kong', '', 'HK', 'HKG', '+852', 'UTC+08:00', 'Hong Kong dollar']
# Hungary|Budapest|HU|HUN|+36|UTC+01:00|Hungarian forint
# ['Hungary', 'Budapest', 'HU', 'HUN', '+36', 'UTC+01:00', 'Hungarian forint']
# Iceland|ReykjavÃ­k|IS|ISL|+354|UTC|Icelandic krÃ³na
# ['Iceland', 'ReykjavÃ\xadk', 'IS', 'ISL', '+354', 'UTC', 'Icelandic krÃ³na']
# India|New Delhi|IN|IND|+91|UTC+05:30|Indian rupee
# ['India', 'New Delhi', 'IN', 'IND', '+91', 'UTC+05:30', 'Indian rupee']
# Indonesia|Jakarta|ID|IDN|+62|UTC+07:00 - UTC+09:00|Indonesian rupiah
# ['Indonesia', 'Jakarta', 'ID', 'IDN', '+62', 'UTC+07:00 - UTC+09:00', 'Indonesian rupiah']
# Iran|Tehran|IR|IRN|+98|UTC+03:30|Iranian rial
# ['Iran', 'Tehran', 'IR', 'IRN', '+98', 'UTC+03:30', 'Iranian rial']
# Iraq|Baghdad|IQ|IRQ|+964|UTC+03:00|Iraqi dinar
# ['Iraq', 'Baghdad', 'IQ', 'IRQ', '+964', 'UTC+03:00', 'Iraqi dinar']
# Ireland|Dublin|IE|IRL|+353|UTC|Euro
# ['Ireland', 'Dublin', 'IE', 'IRL', '+353', 'UTC', 'Euro']
# Isle of Man|Douglas|IM|IMN|+44 1624|UTC|British pound
# ['Isle of Man', 'Douglas', 'IM', 'IMN', '+44 1624', 'UTC', 'British pound']
# Israel|Jerusalem|IL|ISR|+972|UTC+02:00|Israeli new shekel
# ['Israel', 'Jerusalem', 'IL', 'ISR', '+972', 'UTC+02:00', 'Israeli new shekel']
# Italy|Rome|IT|ITA|+39|UTC+01:00|Euro
# ['Italy', 'Rome', 'IT', 'ITA', '+39', 'UTC+01:00', 'Euro']
# Jamaica|Kingston|JM|JAM|+1 876|UTC-05:00|Jamaican dollar
# ['Jamaica', 'Kingston', 'JM', 'JAM', '+1 876', 'UTC-05:00', 'Jamaican dollar']
# Japan|Tokyo|JP|JPN|+81|UTC+09:00|Japanese yen
# ['Japan', 'Tokyo', 'JP', 'JPN', '+81', 'UTC+09:00', 'Japanese yen']
# Jersey|St. Helier|JE|JEY|+44 1534|UTC|British pound
# ['Jersey', 'St. Helier', 'JE', 'JEY', '+44 1534', 'UTC', 'British pound']
# Jordan|Amman|JO|JOR|+962|UTC+02:00|Jordanian dinar
# ['Jordan', 'Amman', 'JO', 'JOR', '+962', 'UTC+02:00', 'Jordanian dinar']
# Kazakhstan|Astana|KZ|KAZ|+7 6xx/7xx|UTC+06:00|Kazakhstani tenge
# ['Kazakhstan', 'Astana', 'KZ', 'KAZ', '+7 6xx/7xx', 'UTC+06:00', 'Kazakhstani tenge']
# Kenya|Nairobi|KE|KEN|+254|UTC+03:00|Kenyan shilling
# ['Kenya', 'Nairobi', 'KE', 'KEN', '+254', 'UTC+03:00', 'Kenyan shilling']
# Kiribati|Tarawa|KI|KIR|+686|UTC+12:00|Australian dollar
# ['Kiribati', 'Tarawa', 'KI', 'KIR', '+686', 'UTC+12:00', 'Australian dollar']
# Kuwait|Kuwait City|KW|KWT|+965|UTC+03:00|Kuwaiti dinar
# ['Kuwait', 'Kuwait City', 'KW', 'KWT', '+965', 'UTC+03:00', 'Kuwaiti dinar']
# Kyrgyzstan|Bishkek|KG|KGZ|+996|UTC+06:00|Kyrgyzstani som
# ['Kyrgyzstan', 'Bishkek', 'KG', 'KGZ', '+996', 'UTC+06:00', 'Kyrgyzstani som']
# Laos|Vientiane|LA|LAO|+856|UTC+07:00|Lao kip
# ['Laos', 'Vientiane', 'LA', 'LAO', '+856', 'UTC+07:00', 'Lao kip']
# Latvia|Riga|LV|LVA|+371|UTC+03:00|Latvian lats
# ['Latvia', 'Riga', 'LV', 'LVA', '+371', 'UTC+03:00', 'Latvian lats']
# Lebanon|Beirut|LB|LBN|+961|UTC+02:00|Lebanese pound
# ['Lebanon', 'Beirut', 'LB', 'LBN', '+961', 'UTC+02:00', 'Lebanese pound']
# Lesotho|Maseru|LS|LSO|+266|UTC+02:00|Lesotho loti
# ['Lesotho', 'Maseru', 'LS', 'LSO', '+266', 'UTC+02:00', 'Lesotho loti']
# Liberia|Monrovia|LR|LBR|+231|UTC|Liberian dollar
# ['Liberia', 'Monrovia', 'LR', 'LBR', '+231', 'UTC', 'Liberian dollar']
# Libya|Tripoli|LY|LBY|+218|UTC+02:00|Libyan dinar
# ['Libya', 'Tripoli', 'LY', 'LBY', '+218', 'UTC+02:00', 'Libyan dinar']
# Liechtenstein|Vaduz|LI|LIE|+423|UTC+01:00|Swiss franc
# ['Liechtenstein', 'Vaduz', 'LI', 'LIE', '+423', 'UTC+01:00', 'Swiss franc']
# Lithuania|Vilnius|LT|LTU|+370|UTC+02:00|Lithuanian litas
# ['Lithuania', 'Vilnius', 'LT', 'LTU', '+370', 'UTC+02:00', 'Lithuanian litas']
# Luxembourg|Luxembourg|LU|LUX|+352|UTC+01:00|Euro
# ['Luxembourg', 'Luxembourg', 'LU', 'LUX', '+352', 'UTC+01:00', 'Euro']
# Macau||MO|MAC|+853|UTC+08:00|Macanese pataca
# ['Macau', '', 'MO', 'MAC', '+853', 'UTC+08:00', 'Macanese pataca']
# Macedonia|Skopje|MK|MKD|+389|UTC+01:00|Macedonian denar
# ['Macedonia', 'Skopje', 'MK', 'MKD', '+389', 'UTC+01:00', 'Macedonian denar']
# Madagascar|Antananarivo|MG|MDG|+261|UTC+03:00|Malagasy ariary
# ['Madagascar', 'Antananarivo', 'MG', 'MDG', '+261', 'UTC+03:00', 'Malagasy ariary']
# Malawi|Lilongwe|MW|MWI|+265|UTC+02:00|Malawian kwacha
# ['Malawi', 'Lilongwe', 'MW', 'MWI', '+265', 'UTC+02:00', 'Malawian kwacha']
# Malaysia|Kuala Lumpur|MY|MYS|+60|UTC+08:00|Malaysian ringgit
# ['Malaysia', 'Kuala Lumpur', 'MY', 'MYS', '+60', 'UTC+08:00', 'Malaysian ringgit']
# Maldives|MalÃ©|MV|MDV|+960|UTC+05:00|Maldivian rufiyaa
# ['Maldives', 'MalÃ©', 'MV', 'MDV', '+960', 'UTC+05:00', 'Maldivian rufiyaa']
# Mali|Bamako|ML|MLI|+223|UTC|West African CFA franc
# ['Mali', 'Bamako', 'ML', 'MLI', '+223', 'UTC', 'West African CFA franc']
# Malta|Valletta|MT|MLT|+356|UTC+01:00|Euro
# ['Malta', 'Valletta', 'MT', 'MLT', '+356', 'UTC+01:00', 'Euro']
# Marshall Islands|Majuro|MH|MHL|+692|UTC+10:00|United States dollar
# ['Marshall Islands', 'Majuro', 'MH', 'MHL', '+692', 'UTC+10:00', 'United States dollar']
# Martinique|Fort-de-France|MQ|MTQ|+596|UTC-04:00|Euro
# ['Martinique', 'Fort-de-France', 'MQ', 'MTQ', '+596', 'UTC-04:00', 'Euro']
# Mauritania|Nouakchott|MR|MRT|+222|UTC|Mauritanian ouguiya
# ['Mauritania', 'Nouakchott', 'MR', 'MRT', '+222', 'UTC', 'Mauritanian ouguiya']
# Mauritius|Port Louis|MU|MUS|+230|UTC+04:00|Mauritian rupee
# ['Mauritius', 'Port Louis', 'MU', 'MUS', '+230', 'UTC+04:00', 'Mauritian rupee']
# Mayotte|Mamoudzou|YT|MYT|+262 269/639|UTC+03:00|Euro
# ['Mayotte', 'Mamoudzou', 'YT', 'MYT', '+262 269/639', 'UTC+03:00', 'Euro']
# Mexico|Mexico City|MX|MEX|+52|UTC-08:00 - UTC-06:00|Mexican peso
# ['Mexico', 'Mexico City', 'MX', 'MEX', '+52', 'UTC-08:00 - UTC-06:00', 'Mexican peso']
# Micronesia|Palikir|FM|FSM|+691|UTC+10:00|Micronesian dollar
# ['Micronesia', 'Palikir', 'FM', 'FSM', '+691', 'UTC+10:00', 'Micronesian dollar']
# Moldova|Chisinau|MD|MDA|+373|UTC+03:00|Moldovan leu
# ['Moldova', 'Chisinau', 'MD', 'MDA', '+373', 'UTC+03:00', 'Moldovan leu']
# Monaco|Monaco|MC|MCO|+377|UTC+01:00|Euro
# ['Monaco', 'Monaco', 'MC', 'MCO', '+377', 'UTC+01:00', 'Euro']
# Mongolia|Ulaanbaatar|MN|MNG|+976|UTC+08:00|Mongolian tÃ¶grÃ¶g
# ['Mongolia', 'Ulaanbaatar', 'MN', 'MNG', '+976', 'UTC+08:00', 'Mongolian tÃ¶grÃ¶g']
# Montenegro|Podgorica|ME|MNE|+382|UTC+01|Euro
# ['Montenegro', 'Podgorica', 'ME', 'MNE', '+382', 'UTC+01', 'Euro']
# Montserrat|Plymouth|MS|MSR|+1 664|UTC-04:00|East Caribbean dollar
# ['Montserrat', 'Plymouth', 'MS', 'MSR', '+1 664', 'UTC-04:00', 'East Caribbean dollar']
# Morocco|Rabat|MA|MAR|+212|UTC|Moroccan dirham
# ['Morocco', 'Rabat', 'MA', 'MAR', '+212', 'UTC', 'Moroccan dirham']
# Mozambique|Maputo|MZ|MOZ|+258|UTC+02:00|Mozambican metical
# ['Mozambique', 'Maputo', 'MZ', 'MOZ', '+258', 'UTC+02:00', 'Mozambican metical']
# Myanmar (Burma)|Naypyidaw|MM|MMR|+95|UTC+06:30|Myanma kyat
# ['Myanmar (Burma)', 'Naypyidaw', 'MM', 'MMR', '+95', 'UTC+06:30', 'Myanma kyat']
# Namibia|Windhoek|NA|NAM|+264|UTC+02:00|Namibian dollar
# ['Namibia', 'Windhoek', 'NA', 'NAM', '+264', 'UTC+02:00', 'Namibian dollar']
# Nauru|Yaren|NR|NRU|+674|UTC+12:00|Australian dollar
# ['Nauru', 'Yaren', 'NR', 'NRU', '+674', 'UTC+12:00', 'Australian dollar']
# Nepal|Kathmandu|NP|NPL|+977|UTC+05:30|Nepalese rupee
# ['Nepal', 'Kathmandu', 'NP', 'NPL', '+977', 'UTC+05:30', 'Nepalese rupee']
# Netherlands|Amsterdam|NL|NLD|+31|UTC+01:00|Euro
# ['Netherlands', 'Amsterdam', 'NL', 'NLD', '+31', 'UTC+01:00', 'Euro']
# New Caledonia|NoumÃ©a|NC|NCL|+687|UTC+11:00|CFP franc
# ['New Caledonia', 'NoumÃ©a', 'NC', 'NCL', '+687', 'UTC+11:00', 'CFP franc']
# New Zealand|Wellington|NZ|NZL|+64|UTC+12:00|New Zealand dollar
# ['New Zealand', 'Wellington', 'NZ', 'NZL', '+64', 'UTC+12:00', 'New Zealand dollar']
# Nicaragua|Managua|NI|NIC|+505|UTC-06:00|Nicaraguan cÃ³rdoba
# ['Nicaragua', 'Managua', 'NI', 'NIC', '+505', 'UTC-06:00', 'Nicaraguan cÃ³rdoba']
# Niger|Niamey|NE|NER|+227|UTC+01:00|West African CFA franc
# ['Niger', 'Niamey', 'NE', 'NER', '+227', 'UTC+01:00', 'West African CFA franc']
# Nigeria|Abuja|NG|NGA|+234|UTC+01:00|Nigerian naira
# ['Nigeria', 'Abuja', 'NG', 'NGA', '+234', 'UTC+01:00', 'Nigerian naira']
# Niue|Alofi|NU|NIU|+683|UTC-11:00|New Zealand dollar
# ['Niue', 'Alofi', 'NU', 'NIU', '+683', 'UTC-11:00', 'New Zealand dollar']
# Norfolk Island|Kingston|NF|NFK|+672 3|UTC+11:30|Australian dollar
# ['Norfolk Island', 'Kingston', 'NF', 'NFK', '+672 3', 'UTC+11:30', 'Australian dollar']
# North Korea|Pyongyang|KP|PRK|+850|UTC+09:00|North Korean won
# ['North Korea', 'Pyongyang', 'KP', 'PRK', '+850', 'UTC+09:00', 'North Korean won']
# Northern Mariana Islands|Saipan|MP|MNP|+1 670|UTC+10:00|United States dollar
# ['Northern Mariana Islands', 'Saipan', 'MP', 'MNP', '+1 670', 'UTC+10:00', 'United States dollar']
# Norway|Oslo|NO|NOR|+47|UTC+01:00|Norwegian krone
# ['Norway', 'Oslo', 'NO', 'NOR', '+47', 'UTC+01:00', 'Norwegian krone']
# Oman|Muscat|OM|OMN|+968|UTC+04:00|Omani rial
# ['Oman', 'Muscat', 'OM', 'OMN', '+968', 'UTC+04:00', 'Omani rial']
# Pakistan|Islamabad|PK|PAK|+92|UTC+05:00|Pakistani rupee
# ['Pakistan', 'Islamabad', 'PK', 'PAK', '+92', 'UTC+05:00', 'Pakistani rupee']
# Palau|Ngerulmud|PW|PLW|+680|UTC+09:00|Palauan dollar
# ['Palau', 'Ngerulmud', 'PW', 'PLW', '+680', 'UTC+09:00', 'Palauan dollar']
# Panama|Panama City|PA|PAN|+507|UTC-05:00|Panamanian balboa
# ['Panama', 'Panama City', 'PA', 'PAN', '+507', 'UTC-05:00', 'Panamanian balboa']
# Papua New Guinea|Port Moresby|PG|PNG|+675|UTC+10:00|Papua New Guinean kina
# ['Papua New Guinea', 'Port Moresby', 'PG', 'PNG', '+675', 'UTC+10:00', 'Papua New Guinean kina']
# Paraguay|AsunciÃ³n|PY|PRY|+595|UTC-04:00|Paraguayan guaranÃ­
# ['Paraguay', 'AsunciÃ³n', 'PY', 'PRY', '+595', 'UTC-04:00', 'Paraguayan guaranÃ\xad']
# Peru|Lima|PE|PER|+51|UTC-05:00|Peruvian nuevo sol
# ['Peru', 'Lima', 'PE', 'PER', '+51', 'UTC-05:00', 'Peruvian nuevo sol']
# Philippines|Manila|PH|PHL|+63|UTC+08:00|Philippine peso
# ['Philippines', 'Manila', 'PH', 'PHL', '+63', 'UTC+08:00', 'Philippine peso']
# Pitcairn|Adamstown|PN|PCN|+872|UTC-08|New Zealand dollar
# ['Pitcairn', 'Adamstown', 'PN', 'PCN', '+872', 'UTC-08', 'New Zealand dollar']
# Poland|Warsaw|PL|POL|+48|UTC+01:00|Polish zÅ‚oty
# ['Poland', 'Warsaw', 'PL', 'POL', '+48', 'UTC+01:00', 'Polish zÅ‚oty']
# Portugal|Lisbon|PT|PRT|+351|UTC+01:00|Euro
# ['Portugal', 'Lisbon', 'PT', 'PRT', '+351', 'UTC+01:00', 'Euro']
# Puerto Rico|San Juan|PR|PRI|+1 787/939|UTC-04:00|United States dollar
# ['Puerto Rico', 'San Juan', 'PR', 'PRI', '+1 787/939', 'UTC-04:00', 'United States dollar']
# Qatar|Doha|QA|QAT|+974|UTC+03:00|Qatari riyal
# ['Qatar', 'Doha', 'QA', 'QAT', '+974', 'UTC+03:00', 'Qatari riyal']
# Reunion||RE|REU|+262|UTC+04:00|Euro
# ['Reunion', '', 'RE', 'REU', '+262', 'UTC+04:00', 'Euro']
# Romania|Bucharest|RO|ROU|+40|UTC+02:00|Romanian leu
# ['Romania', 'Bucharest', 'RO', 'ROU', '+40', 'UTC+02:00', 'Romanian leu']
# Russia|Moscow|RU|RUS|+7|UTC+03:00|Russian ruble
# ['Russia', 'Moscow', 'RU', 'RUS', '+7', 'UTC+03:00', 'Russian ruble']
# Rwanda|Kigali|RW|RWA|+250|UTC+02:00|Rwandan franc
# ['Rwanda', 'Kigali', 'RW', 'RWA', '+250', 'UTC+02:00', 'Rwandan franc']
# Saint Barthelemy|Gustavia|BL|BLM|+590|UTC-04|Euro
# ['Saint Barthelemy', 'Gustavia', 'BL', 'BLM', '+590', 'UTC-04', 'Euro']
# Saint Helena|Jamestown|SH|SHN|+290|UTC|Saint Helena pound
# ['Saint Helena', 'Jamestown', 'SH', 'SHN', '+290', 'UTC', 'Saint Helena pound']
# Saint Kitts and Nevis|Basseterre|KN|KNA|+1 869|UTC-04:00|East Caribbean dollar
# ['Saint Kitts and Nevis', 'Basseterre', 'KN', 'KNA', '+1 869', 'UTC-04:00', 'East Caribbean dollar']
# Saint Lucia|Castries|LC|LCA|+1 758|UTC-04:00|East Caribbean dollar
# ['Saint Lucia', 'Castries', 'LC', 'LCA', '+1 758', 'UTC-04:00', 'East Caribbean dollar']
# Saint Martin|Marigot|MF|MAF|+590|UTC-04|Euro
# ['Saint Martin', 'Marigot', 'MF', 'MAF', '+590', 'UTC-04', 'Euro']
# Saint Pierre and Miquelon|St. Pierre|PM|SPM|+508|UTC-03|Euro
# ['Saint Pierre and Miquelon', 'St. Pierre', 'PM', 'SPM', '+508', 'UTC-03', 'Euro']
# Saint Vincent and the Grenadines|Kingstown|VC|VCT|+1 784|UTC-04|East Caribbean dollar
# ['Saint Vincent and the Grenadines', 'Kingstown', 'VC', 'VCT', '+1 784', 'UTC-04', 'East Caribbean dollar']
# Samoa|Apia|WS|WSM|+685|UTC-11:00|Samoan tala
# ['Samoa', 'Apia', 'WS', 'WSM', '+685', 'UTC-11:00', 'Samoan tala']
# San Marino|San Marino|SM|SMR|+378|UTC+01:00|Euro
# ['San Marino', 'San Marino', 'SM', 'SMR', '+378', 'UTC+01:00', 'Euro']
# Sao Tome and PrÃ­ncipe|SÃ£o TomÃ©|ST|STP|+239|UTC|SÃ£o TomÃ© and PrÃ­ncipe dobra
# ['Sao Tome and PrÃ\xadncipe', 'SÃ£o TomÃ©', 'ST', 'STP', '+239', 'UTC', 'SÃ£o TomÃ© and PrÃ\xadncipe dobra']
# Saudi Arabia|Riyadh|SA|SAU|+966|UTC+03:00|Saudi riyal
# ['Saudi Arabia', 'Riyadh', 'SA', 'SAU', '+966', 'UTC+03:00', 'Saudi riyal']
# Senegal|Dakar|SN|SEN|+221|UTC|West African CFA franc
# ['Senegal', 'Dakar', 'SN', 'SEN', '+221', 'UTC', 'West African CFA franc']
# Serbia|Belgrade|RS|SRB|+381|UTC+01:00|Serbian dinar
# ['Serbia', 'Belgrade', 'RS', 'SRB', '+381', 'UTC+01:00', 'Serbian dinar']
# Seychelles|Victoria|SC|SYC|+248|UTC+04:00|Seychellois rupee
# ['Seychelles', 'Victoria', 'SC', 'SYC', '+248', 'UTC+04:00', 'Seychellois rupee']
# Sierra Leone|Freetown|SL|SLE|+232|UTC|Sierra Leonean leone
# ['Sierra Leone', 'Freetown', 'SL', 'SLE', '+232', 'UTC', 'Sierra Leonean leone']
# Singapore|Singapore|SG|SGP|+65|UTC+08:00|Brunei dollar
# ['Singapore', 'Singapore', 'SG', 'SGP', '+65', 'UTC+08:00', 'Brunei dollar']
# Sint Maarten|Philipsburg|SX|SXM|+599 5|UTC-04:00|Netherlands Antillean guilder
# ['Sint Maarten', 'Philipsburg', 'SX', 'SXM', '+599 5', 'UTC-04:00', 'Netherlands Antillean guilder']
# Slovakia|Bratislava|SK|SVK|+421|UTC+01:00|Euro
# ['Slovakia', 'Bratislava', 'SK', 'SVK', '+421', 'UTC+01:00', 'Euro']
# Slovenia|Ljubljana|SI|SVN|+386|UTC+01:00|Euro
# ['Slovenia', 'Ljubljana', 'SI', 'SVN', '+386', 'UTC+01:00', 'Euro']
# Solomon Islands|Honiara|SB|SLB|+677|UTC+11:00|Solomon Islands dollar
# ['Solomon Islands', 'Honiara', 'SB', 'SLB', '+677', 'UTC+11:00', 'Solomon Islands dollar']
# Somalia|Mogadishu|SO|SOM|+252|UTC+03:00|Somali shilling
# ['Somalia', 'Mogadishu', 'SO', 'SOM', '+252', 'UTC+03:00', 'Somali shilling']
# South Africa|Pretoria|ZA|ZAF|+27|UTC+02:00|South African rand
# ['South Africa', 'Pretoria', 'ZA', 'ZAF', '+27', 'UTC+02:00', 'South African rand']
# South Georgia and the South Sandwich Islands|Grytviken|GS|SGS||UTC-02|British pound
# ['South Georgia and the South Sandwich Islands', 'Grytviken', 'GS', 'SGS', '', 'UTC-02', 'British pound']
# South Korea|Seoul|KR|KOR|+82|UTC+09:00|South Korean won
# ['South Korea', 'Seoul', 'KR', 'KOR', '+82', 'UTC+09:00', 'South Korean won']
# Spain|Madrid|ES|ESP|+34|UTC+01:00|Euro
# ['Spain', 'Madrid', 'ES', 'ESP', '+34', 'UTC+01:00', 'Euro']
# Sri Lanka|Sri Jayawardenapura Kotte|LK|LKA|+94|UTC+05:30|Sri Lankan rupee
# ['Sri Lanka', 'Sri Jayawardenapura Kotte', 'LK', 'LKA', '+94', 'UTC+05:30', 'Sri Lankan rupee']
# Sudan|Khartoum|SD|SDN|+249|UTC+02:00|Sudanese pound
# ['Sudan', 'Khartoum', 'SD', 'SDN', '+249', 'UTC+02:00', 'Sudanese pound']
# Suriname|Paramaribo|SR|SUR|+597|UTC-03:30|Surinamese dollar
# ['Suriname', 'Paramaribo', 'SR', 'SUR', '+597', 'UTC-03:30', 'Surinamese dollar']
# Svalbard and Jan Mayen||SJ|SJM|+47|UTC+01:00|Norwegian krone
# ['Svalbard and Jan Mayen', '', 'SJ', 'SJM', '+47', 'UTC+01:00', 'Norwegian krone']
# Swaziland|Mbabane|SZ|SWZ|+268|UTC+02:00|Swazi lilangeni
# ['Swaziland', 'Mbabane', 'SZ', 'SWZ', '+268', 'UTC+02:00', 'Swazi lilangeni']
# Sweden|Stockholm|SE|SWE|+46|UTC+01:00|Swedish krona
# ['Sweden', 'Stockholm', 'SE', 'SWE', '+46', 'UTC+01:00', 'Swedish krona']
# Switzerland|Bern|CH|CHE|+41|UTC+01:00|Swiss franc
# ['Switzerland', 'Bern', 'CH', 'CHE', '+41', 'UTC+01:00', 'Swiss franc']
# Syrian Arab Republic|Damascus|SY|SYR|+963|UTC+02:00|Syrian pound
# ['Syrian Arab Republic', 'Damascus', 'SY', 'SYR', '+963', 'UTC+02:00', 'Syrian pound']
# Taiwan|Taipei|TW|TWN|+886|UTC+08:00|New Taiwan dollar
# ['Taiwan', 'Taipei', 'TW', 'TWN', '+886', 'UTC+08:00', 'New Taiwan dollar']
# Tajikistan|Dushanbe|TJ|TJK|+992|UTC+06:00|Tajikistani somoni
# ['Tajikistan', 'Dushanbe', 'TJ', 'TJK', '+992', 'UTC+06:00', 'Tajikistani somoni']
# Tanzania|Dodoma|TZ|TZA|+255|UTC+03:00|Tanzanian shilling
# ['Tanzania', 'Dodoma', 'TZ', 'TZA', '+255', 'UTC+03:00', 'Tanzanian shilling']
# Thailand|Bangkok|TH|THA|+66|UTC+07:00|Thai baht
# ['Thailand', 'Bangkok', 'TH', 'THA', '+66', 'UTC+07:00', 'Thai baht']
# Togo|LomÃ©|TG|TGO|+228|UTC|West African CFA franc
# ['Togo', 'LomÃ©', 'TG', 'TGO', '+228', 'UTC', 'West African CFA franc']
# Tokelau|Rotates annually|TK|TKL|+690|UTC-10|New Zealand dollar
# ['Tokelau', 'Rotates annually', 'TK', 'TKL', '+690', 'UTC-10', 'New Zealand dollar']
# Tonga|Nuku|TO|TON|+676|UTC+13:00|Tongan paÊ»anga
# ['Tonga', 'Nuku', 'TO', 'TON', '+676', 'UTC+13:00', 'Tongan paÊ»anga']
# Trinidad and Tobago|Port of Spain|TT|TTO|+1 868|UTC-04:00|Trinidad and Tobago dollar
# ['Trinidad and Tobago', 'Port of Spain', 'TT', 'TTO', '+1 868', 'UTC-04:00', 'Trinidad and Tobago dollar']
# Tunisia|Tunis|TN|TUN|+216|UTC+01:00|Tunisian dinar
# ['Tunisia', 'Tunis', 'TN', 'TUN', '+216', 'UTC+01:00', 'Tunisian dinar']
# Turkey|Ankara|TR|TUR|+90|UTC+02:00|Turkish lira
# ['Turkey', 'Ankara', 'TR', 'TUR', '+90', 'UTC+02:00', 'Turkish lira']
# Turkmenistan|Ashgabat|TM|TKM|+993|UTC+05:00|Turkmenistani manat
# ['Turkmenistan', 'Ashgabat', 'TM', 'TKM', '+993', 'UTC+05:00', 'Turkmenistani manat']
# Turks and Caicos Islands|Cockburn Town|TC|TCA|+1 649|UTC-05:00|United States dollar
# ['Turks and Caicos Islands', 'Cockburn Town', 'TC', 'TCA', '+1 649', 'UTC-05:00', 'United States dollar']
# Tuvalu|Funafuti|TV|TUV|+688|UTC+12:00|Australian dollar
# ['Tuvalu', 'Funafuti', 'TV', 'TUV', '+688', 'UTC+12:00', 'Australian dollar']
# Uganda|Kampala|UG|UGA|+256|UTC+03:00|Ugandan shilling
# ['Uganda', 'Kampala', 'UG', 'UGA', '+256', 'UTC+03:00', 'Ugandan shilling']
# Ukraine|Kiev|UA|UKR|+380|UTC+03:00|Ukrainian hryvnia
# ['Ukraine', 'Kiev', 'UA', 'UKR', '+380', 'UTC+03:00', 'Ukrainian hryvnia']
# United Arab Emirates|Abu Dhabi|AE|ARE|+971|UTC+04:00|United Arab Emirates dirham
# ['United Arab Emirates', 'Abu Dhabi', 'AE', 'ARE', '+971', 'UTC+04:00', 'United Arab Emirates dirham']
# United Kingdom|London|GB|GBR|+44|UTC|British pound
# ['United Kingdom', 'London', 'GB', 'GBR', '+44', 'UTC', 'British pound']
# United States|Washington D.C.|US|USA|+1|UTC-11:00 - UTC-05:00|United States dollar
# ['United States', 'Washington D.C.', 'US', 'USA', '+1', 'UTC-11:00 - UTC-05:00', 'United States dollar']
# United States Minor Outlying Islands||UM|UMI|+1||United States dollar
# ['United States Minor Outlying Islands', '', 'UM', 'UMI', '+1', '', 'United States dollar']
# Uruguay|Montevideo|UY|URY|+598|UTC-03:00|Uruguayan peso
# ['Uruguay', 'Montevideo', 'UY', 'URY', '+598', 'UTC-03:00', 'Uruguayan peso']
# Uzbekistan|Tashkent|UZ|UZB|+998|UTC+06:00|Uzbekistani som
# ['Uzbekistan', 'Tashkent', 'UZ', 'UZB', '+998', 'UTC+06:00', 'Uzbekistani som']
# Vanuatu|Port Vila|VU|VUT|+678|UTC+11:00|Vanuatu vatu
# ['Vanuatu', 'Port Vila', 'VU', 'VUT', '+678', 'UTC+11:00', 'Vanuatu vatu']
# Vatican City|Vatican City|VA|VAT|+39 06 698|UTC+01|Euro
# ['Vatican City', 'Vatican City', 'VA', 'VAT', '+39 06 698', 'UTC+01', 'Euro']
# Venezuela|Caracas|VE|VEN|+58|UTC-04:00|Venezuelan bolÃ­var
# ['Venezuela', 'Caracas', 'VE', 'VEN', '+58', 'UTC-04:00', 'Venezuelan bolÃ\xadvar']
# Vietnam|Hanoi|VN|VNM|+84|UTC+07:00|Vietnamese Ä‘á»“ng
# ['Vietnam', 'Hanoi', 'VN', 'VNM', '+84', 'UTC+07:00', 'Vietnamese Ä‘á»“ng']
# Virgin Islands|Road Town|VG|VGB|+1 284|UTC-04|British Virgin Islands dollar
# ['Virgin Islands', 'Road Town', 'VG', 'VGB', '+1 284', 'UTC-04', 'British Virgin Islands dollar']
# Virgin Islands of the United States|Charlotte Amalie|VI|VIR|+1 340|UTC-04|United States dollar
# ['Virgin Islands of the United States', 'Charlotte Amalie', 'VI', 'VIR', '+1 340', 'UTC-04', 'United States dollar']
# Wallis and Futuna|Mata-Utu|WF|WLF|+681|UTC+12:00|CFP franc
# ['Wallis and Futuna', 'Mata-Utu', 'WF', 'WLF', '+681', 'UTC+12:00', 'CFP franc']
# Western Sahara|LaÃ¢youne (El AaiÃºn)|EH|ESH|+212 5288/5289|UTC+01|Moroccan dirham
# ['Western Sahara', 'LaÃ¢youne (El AaiÃºn)', 'EH', 'ESH', '+212 5288/5289', 'UTC+01', 'Moroccan dirham']
# Yemen|SanaÃ¡|YE|YEM|+967|UTC+03:00|Yemeni rial
# ['Yemen', 'SanaÃ¡', 'YE', 'YEM', '+967', 'UTC+03:00', 'Yemeni rial']
# Zambia|Lusaka|ZM|ZMB|+260|UTC+02:00|Zambian kwacha
# ['Zambia', 'Lusaka', 'ZM', 'ZMB', '+260', 'UTC+02:00', 'Zambian kwacha']
# Zimbabwe|Harare|ZW|ZWE|+263|UTC+02:00|Botswana pula
# ['Zimbabwe', 'Harare', 'ZW', 'ZWE', '+263', 'UTC+02:00', 'Botswana pula']

# %%
# convertiong above data into formatted data
input_filename = 'country_info.txt'

countries = {}
with open(input_filename) as country_file:
    country_file.readline()
    for row in country_file:
        data = row.strip('\n').split('|')
        country, capital, code, code3, dialing, timezone, currency = data
        # print(country, capital, code, code3, dialing, timezone, currency, sep='\n\t')
        country_dict = {
            'name': country,
            'capital': capital,
            'country_code': code,
            'cc3': code3,
            'dialing_code': dialing,
            'timezone': timezone,
            'currency': currency,
        }
        print(country_dict)
        countries[country.casefold()] = country_dict

print(countries)
# Out:
# {'name': 'Afghanistan', 'capital': 'Kabul', 'country_code': 'AF', 'cc3': 'AFG', 'dialing_code': '+93', 'timezone': 'UTC+04:30', 'currency': 'Afghan afghani'}
# {'name': 'Aland Islands', 'capital': 'Mariehamn', 'country_code': 'AX', 'cc3': 'ALA', 'dialing_code': '+358', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'name': 'Albania', 'capital': 'Tirana', 'country_code': 'AL', 'cc3': 'ALB', 'dialing_code': '+355', 'timezone': 'UTC+01:00', 'currency': 'Albanian lek'}
# {'name': 'Algeria', 'capital': 'Algiers', 'country_code': 'DZ', 'cc3': 'DZA', 'dialing_code': '+213', 'timezone': 'UTC', 'currency': 'Algerian dinar'}
# {'name': 'American Samoa', 'capital': 'Pago Pago', 'country_code': 'AS', 'cc3': 'ASM', 'dialing_code': '+1 684', 'timezone': 'UTC-11:00', 'currency': ''}
# {'name': 'Andorra', 'capital': 'Andorra la Vella', 'country_code': 'AD', 'cc3': 'AND', 'dialing_code': '+376', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Angola', 'capital': 'Luanda', 'country_code': 'AO', 'cc3': 'AGO', 'dialing_code': '+244', 'timezone': 'UTC+01:00', 'currency': 'Angolan kwanza'}
# {'name': 'Anguilla', 'capital': 'The Valley', 'country_code': 'AI', 'cc3': 'AIA', 'dialing_code': '+1 264', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Antarctica', 'capital': '', 'country_code': 'AQ', 'cc3': 'ATA', 'dialing_code': '', 'timezone': '', 'currency': ''}
# {'name': 'Antigua and Barbuda', 'capital': "St. John's", 'country_code': 'AG', 'cc3': 'ATG', 'dialing_code': '+1 268', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Argentina', 'capital': 'Buenos Aires', 'country_code': 'AR', 'cc3': 'ARG', 'dialing_code': '+54', 'timezone': 'UTC-03:00', 'currency': 'Argentine peso'}
# {'name': 'Armenia', 'capital': 'Yerevan', 'country_code': 'AM', 'cc3': 'ARM', 'dialing_code': '+374', 'timezone': 'UTC+04:00', 'currency': 'Armenian dram'}
# {'name': 'Aruba', 'capital': 'Oranjestad', 'country_code': 'AW', 'cc3': 'ABW', 'dialing_code': '+297', 'timezone': 'UTC-04:00', 'currency': 'Aruban florin'}
# {'name': 'Australia', 'capital': 'Canberra', 'country_code': 'AU', 'cc3': 'AUS', 'dialing_code': '+61', 'timezone': 'UTC+07:00 - UTC+10:00', 'currency': 'Australian dollar'}
# {'name': 'Austria', 'capital': 'Vienna', 'country_code': 'AT', 'cc3': 'AUT', 'dialing_code': '+43', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Azerbaijan', 'capital': 'Baku', 'country_code': 'AZ', 'cc3': 'AZE', 'dialing_code': '+994', 'timezone': 'UTC+04:00', 'currency': 'Azerbaijani manat'}
# {'name': 'Bahamas', 'capital': 'Nassau', 'country_code': 'BS', 'cc3': 'BHS', 'dialing_code': '+1 242', 'timezone': 'UTC-05:00', 'currency': 'Bahamian dollar'}
# {'name': 'Bahrain', 'capital': 'Manama', 'country_code': 'BH', 'cc3': 'BHR', 'dialing_code': '+973', 'timezone': 'UTC+03:00', 'currency': 'Bahraini dinar'}
# {'name': 'Bangladesh', 'capital': 'Dhaka', 'country_code': 'BD', 'cc3': 'BGD', 'dialing_code': '+880', 'timezone': 'UTC+06:00', 'currency': 'Bangladeshi taka'}
# {'name': 'Barbados', 'capital': 'Bridgetown', 'country_code': 'BB', 'cc3': 'BRB', 'dialing_code': '+1 246', 'timezone': 'UTC-04:00', 'currency': 'Barbadian dollar'}
# {'name': 'Belarus', 'capital': 'Minsk', 'country_code': 'BY', 'cc3': 'BLR', 'dialing_code': '+375', 'timezone': 'UTC+03:00', 'currency': 'Belarusian ruble'}
# {'name': 'Belgium', 'capital': 'Brussels', 'country_code': 'BE', 'cc3': 'BEL', 'dialing_code': '+32', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Belize', 'capital': 'Belmopan', 'country_code': 'BZ', 'cc3': 'BLZ', 'dialing_code': '+501', 'timezone': 'UTC-06:00', 'currency': 'Belize dollar'}
# {'name': 'Benin', 'capital': 'Porto-Novo', 'country_code': 'BJ', 'cc3': 'BEN', 'dialing_code': '+229', 'timezone': 'UTC+01:00', 'currency': 'West African CFA franc'}
# {'name': 'Bermuda', 'capital': 'Hamilton', 'country_code': 'BM', 'cc3': 'BMU', 'dialing_code': '+1 441', 'timezone': 'UTC-04:00', 'currency': 'Bermudian dollar'}
# {'name': 'Bhutan', 'capital': 'Thimphu', 'country_code': 'BT', 'cc3': 'BTN', 'dialing_code': '+975', 'timezone': 'UTC+05:30', 'currency': 'Bhutanese ngultrum'}
# {'name': 'Bolivia', 'capital': 'Sucre', 'country_code': 'BO', 'cc3': 'BOL', 'dialing_code': '+591', 'timezone': 'UTC-04:00', 'currency': 'Bolivian boliviano'}
# {'name': 'Bonaire', 'capital': 'Kralendijk', 'country_code': 'BQ', 'cc3': 'BES', 'dialing_code': '+599', 'timezone': 'UTC-04:00', 'currency': 'United States dollar'}
# {'name': 'Bosnia and Herzegovina', 'capital': 'Sarajevo', 'country_code': 'BA', 'cc3': 'BIH', 'dialing_code': '+387', 'timezone': 'UTC+01:00', 'currency': 'Bosnia and Herzegovina convertible mark'}
# {'name': 'Botswana', 'capital': 'Gaborone', 'country_code': 'BW', 'cc3': 'BWA', 'dialing_code': '+267', 'timezone': 'UTC+02:00', 'currency': 'Botswana pula'}
# {'name': 'Bouvet Island', 'capital': '', 'country_code': 'BV', 'cc3': 'BVT', 'dialing_code': '', 'timezone': 'UTC+01:00', 'currency': ''}
# {'name': 'Brazil', 'capital': 'BrasÃ\xadlia', 'country_code': 'BR', 'cc3': 'BRA', 'dialing_code': '+55', 'timezone': 'UTC-05:00 - UTC-03:00', 'currency': 'Brazilian real'}
# {'name': 'British Indian Ocean Territory', 'capital': 'Diego Garcia', 'country_code': 'IO', 'cc3': 'IOT', 'dialing_code': '+246', 'timezone': 'UTC+06', 'currency': 'United States dollar'}
# {'name': 'Brunei', 'capital': 'Bandar Seri Begawan', 'country_code': 'BN', 'cc3': 'BRN', 'dialing_code': '+673', 'timezone': 'UTC+08:00', 'currency': 'Brunei dollar'}
# {'name': 'Bulgaria', 'capital': 'Sofia', 'country_code': 'BG', 'cc3': 'BGR', 'dialing_code': '+359', 'timezone': 'UTC+02:00', 'currency': 'Bulgarian lev'}
# {'name': 'Burkina Faso', 'capital': 'Ouagadougou', 'country_code': 'BF', 'cc3': 'BFA', 'dialing_code': '+226', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Burundi', 'capital': 'Bujumbura', 'country_code': 'BI', 'cc3': 'BDI', 'dialing_code': '+257', 'timezone': 'UTC+02:00', 'currency': 'Burundian franc'}
# {'name': 'Cambodia', 'capital': 'Phnom Penh', 'country_code': 'KH', 'cc3': 'KHM', 'dialing_code': '+855', 'timezone': 'UTC+07:00', 'currency': 'Cambodian riel'}
# {'name': 'Cameroon', 'capital': 'YaoundÃ©', 'country_code': 'CM', 'cc3': 'CMR', 'dialing_code': '+237', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Canada', 'capital': 'Ottawa', 'country_code': 'CA', 'cc3': 'CAN', 'dialing_code': '+1', 'timezone': 'UTC-08:00 - UTC-04:00', 'currency': 'Canadian dollar'}
# {'name': 'Cape Verde', 'capital': 'Praia', 'country_code': 'CV', 'cc3': 'CPV', 'dialing_code': '+238', 'timezone': 'UTC-01:00', 'currency': 'Cape Verdean escudo'}
# {'name': 'Cayman Islands', 'capital': 'George Town', 'country_code': 'KY', 'cc3': 'CYM', 'dialing_code': '+1 345', 'timezone': 'UTC-05:00', 'currency': 'Cayman Islands dollar'}
# {'name': 'Central African Republic', 'capital': 'Bangui', 'country_code': 'CF', 'cc3': 'CAF', 'dialing_code': '+236', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Chad', 'capital': "N'Djamena", 'country_code': 'TD', 'cc3': 'TCD', 'dialing_code': '+235', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Chile', 'capital': 'Santiago', 'country_code': 'CL', 'cc3': 'CHL', 'dialing_code': '+56', 'timezone': 'UTC-04:00', 'currency': 'Chilean peso'}
# {'name': 'China', 'capital': 'Beijing', 'country_code': 'CN', 'cc3': 'CHN', 'dialing_code': '+86', 'timezone': 'UTC+08:00', 'currency': 'Chinese yuan'}
# {'name': 'Christmas Island', 'capital': 'Flying Fish Cove', 'country_code': 'CX', 'cc3': 'CXR', 'dialing_code': '+61 8 9164', 'timezone': 'UTC+07', 'currency': 'Australian dollar'}
# {'name': 'Cocos (Keeling) Islands', 'capital': 'West Island', 'country_code': 'CC', 'cc3': 'CCK', 'dialing_code': '+61 8 9162', 'timezone': 'UTC+06:30', 'currency': 'Australian dollar'}
# {'name': 'Colombia', 'capital': 'BogotÃ¡', 'country_code': 'CO', 'cc3': 'COL', 'dialing_code': '+57', 'timezone': 'UTC-05:00', 'currency': 'Colombian peso'}
# {'name': 'Comoros', 'capital': 'Moroni', 'country_code': 'KM', 'cc3': 'COM', 'dialing_code': '+269', 'timezone': 'UTC+03:00', 'currency': 'Comorian franc'}
# {'name': 'Congo, Republic of the', 'capital': 'Brazzaville', 'country_code': 'CG', 'cc3': 'COG', 'dialing_code': '+242', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Congo, Democratic Republic of the', 'capital': 'Kinshasa', 'country_code': 'CD', 'cc3': 'COD', 'dialing_code': '+243', 'timezone': 'UTC+01:00 - UTC+02:00', 'currency': 'Congolese franc'}
# {'name': 'Cook Islands', 'capital': 'Avarua', 'country_code': 'CK', 'cc3': 'COK', 'dialing_code': '+682', 'timezone': 'UTC-10:00', 'currency': 'New Zealand dollar'}
# {'name': 'Costa Rica', 'capital': 'San JosÃ©', 'country_code': 'CR', 'cc3': 'CRI', 'dialing_code': '+506', 'timezone': 'UTC-06:00', 'currency': 'Costa Rican colÃ³n'}
# {'name': "CÃ´te d'Ivoire", 'capital': 'Yamoussoukro', 'country_code': 'CI', 'cc3': 'CIV', 'dialing_code': '+225', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Croatia', 'capital': 'Zagreb', 'country_code': 'HR', 'cc3': 'HRV', 'dialing_code': '+385', 'timezone': 'UTC+01:00', 'currency': 'Croatian kuna'}
# {'name': 'Cuba', 'capital': 'Havana', 'country_code': 'CU', 'cc3': 'CUB', 'dialing_code': '+53', 'timezone': 'UTC-03:00', 'currency': 'Cuban convertible peso'}
# {'name': 'Curacao', 'capital': 'Willemstad', 'country_code': 'CW', 'cc3': 'CUW', 'dialing_code': '+599 9', 'timezone': 'UTC-04:00', 'currency': 'Netherlands Antillean guilder'}
# {'name': 'Cyprus', 'capital': 'Nicosia', 'country_code': 'CY', 'cc3': 'CYP', 'dialing_code': '+357', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'name': 'Czech Republic', 'capital': 'Prague', 'country_code': 'CZ', 'cc3': 'CZE', 'dialing_code': '+420', 'timezone': 'UTC+01:00', 'currency': 'Czech koruna'}
# {'name': 'Denmark', 'capital': 'Copenhagen', 'country_code': 'DK', 'cc3': 'DNK', 'dialing_code': '+45', 'timezone': 'UTC+01:00', 'currency': 'Danish krone'}
# {'name': 'Djibouti', 'capital': 'Djibouti', 'country_code': 'DJ', 'cc3': 'DJI', 'dialing_code': '+253', 'timezone': 'UTC+03:00', 'currency': 'Djiboutian franc'}
# {'name': 'Dominica', 'capital': 'Roseau', 'country_code': 'DM', 'cc3': 'DMA', 'dialing_code': '+1 767', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Dominican Republic', 'capital': 'Santo Domingo', 'country_code': 'DO', 'cc3': 'DOM', 'dialing_code': '+1 809/829/849', 'timezone': 'UTC-04:00', 'currency': 'Dominican peso'}
# {'name': 'East Timor', 'capital': 'Dili', 'country_code': 'TL', 'cc3': 'TLS', 'dialing_code': '+670', 'timezone': 'UTC+09', 'currency': 'United States dollar'}
# {'name': 'Ecuador', 'capital': 'Quito', 'country_code': 'EC', 'cc3': 'ECU', 'dialing_code': '+593', 'timezone': 'UTC-05:00', 'currency': 'United States dollar'}
# {'name': 'Egypt', 'capital': 'Cairo', 'country_code': 'EG', 'cc3': 'EGY', 'dialing_code': '+20', 'timezone': 'UTC+02:00', 'currency': 'Egyptian pound'}
# {'name': 'El Salvador', 'capital': 'San Salvador', 'country_code': 'SV', 'cc3': 'SLV', 'dialing_code': '+503', 'timezone': 'UTC-06:00', 'currency': 'Salvadoran colÃ³n'}
# {'name': 'Equatorial Guinea', 'capital': 'Malabo', 'country_code': 'GQ', 'cc3': 'GNQ', 'dialing_code': '+240', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Eritrea', 'capital': 'Asmara', 'country_code': 'ER', 'cc3': 'ERI', 'dialing_code': '+291', 'timezone': 'UTC+03:00', 'currency': 'Eritrean nakfa'}
# {'name': 'Estonia', 'capital': 'Tallinn', 'country_code': 'EE', 'cc3': 'EST', 'dialing_code': '+372', 'timezone': 'UTC+03:00', 'currency': 'Euro'}
# {'name': 'Ethiopia', 'capital': 'Addis Ababa', 'country_code': 'ET', 'cc3': 'ETH', 'dialing_code': '+251', 'timezone': 'UTC+03:00', 'currency': 'Ethiopian birr'}
# {'name': 'Falkland Islands (Malvinas)', 'capital': 'Stanley', 'country_code': 'FK', 'cc3': 'FLK', 'dialing_code': '+500', 'timezone': 'UTC-04:00', 'currency': 'Falkland Islands pound'}
# {'name': 'Faroe Islands', 'capital': 'TÃ³rshavn', 'country_code': 'FO', 'cc3': 'FRO', 'dialing_code': '+298', 'timezone': 'UTC', 'currency': 'Danish krone'}
# {'name': 'Fiji', 'capital': 'Suva', 'country_code': 'FJ', 'cc3': 'FJI', 'dialing_code': '+679', 'timezone': 'UTC+12:00', 'currency': 'Fijian dollar'}
# {'name': 'Finland', 'capital': 'Helsinki', 'country_code': 'FI', 'cc3': 'FIN', 'dialing_code': '+358', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'name': 'France', 'capital': 'Paris', 'country_code': 'FR', 'cc3': 'FRA', 'dialing_code': '+33', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'French Guiana', 'capital': 'Cayenne', 'country_code': 'GF', 'cc3': 'GUF', 'dialing_code': '+594', 'timezone': 'UTC-01:00', 'currency': 'Euro'}
# {'name': 'French Polynesia', 'capital': 'Papeete', 'country_code': 'PF', 'cc3': 'PYF', 'dialing_code': '+689', 'timezone': 'UTC-10:00', 'currency': 'CFP franc'}
# {'name': 'French Southern Territories', 'capital': 'Port-aux-FranÃ§ais', 'country_code': 'TF', 'cc3': 'ATF', 'dialing_code': '', 'timezone': 'UTC+05:00', 'currency': 'Euro'}
# {'name': 'Gabon', 'capital': 'Libreville', 'country_code': 'GA', 'cc3': 'GAB', 'dialing_code': '+241', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'name': 'Gambia', 'capital': 'Banjul', 'country_code': 'GM', 'cc3': 'GMB', 'dialing_code': '+220', 'timezone': 'UTC', 'currency': 'Gambian dalasi'}
# {'name': 'Georgia', 'capital': 'Tbilisi', 'country_code': 'GE', 'cc3': 'GEO', 'dialing_code': '+995', 'timezone': 'UTC+04:00', 'currency': 'Georgian lari'}
# {'name': 'Germany', 'capital': 'Berlin', 'country_code': 'DE', 'cc3': 'DEU', 'dialing_code': '+49', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Ghana', 'capital': 'Accra', 'country_code': 'GH', 'cc3': 'GHA', 'dialing_code': '+233', 'timezone': 'UTC', 'currency': 'Ghanaian cedi'}
# {'name': 'Gibraltar', 'capital': 'Gibraltar', 'country_code': 'GI', 'cc3': 'GIB', 'dialing_code': '+350', 'timezone': 'UTC+01:00', 'currency': 'Gibraltar pound'}
# {'name': 'Greece', 'capital': 'Athens', 'country_code': 'GR', 'cc3': 'GRC', 'dialing_code': '+30', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'name': 'Greenland', 'capital': 'Nuuk', 'country_code': 'GL', 'cc3': 'GRL', 'dialing_code': '+299', 'timezone': 'UTC-03:00', 'currency': 'Danish krone'}
# {'name': 'Grenada', 'capital': "St. George's", 'country_code': 'GD', 'cc3': 'GRD', 'dialing_code': '+1 473', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Guadeloupe', 'capital': 'Basse-Terre', 'country_code': 'GP', 'cc3': 'GLP', 'dialing_code': '+590', 'timezone': 'UTC-04:00', 'currency': 'Euro'}
# {'name': 'Guam', 'capital': 'HagÃ¥tÃ±a', 'country_code': 'GU', 'cc3': 'GUM', 'dialing_code': '+1 671', 'timezone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'name': 'Guatemala', 'capital': 'Guatemala City', 'country_code': 'GT', 'cc3': 'GTM', 'dialing_code': '+502', 'timezone': 'UTC-06:00', 'currency': 'Guatemalan quetzal'}
# {'name': 'Guernsey', 'capital': 'St. Peter Port', 'country_code': 'GG', 'cc3': 'GGY', 'dialing_code': '+44 1481', 'timezone': 'UTC', 'currency': 'British pound'}
# {'name': 'Guinea', 'capital': 'Conakry', 'country_code': 'GN', 'cc3': 'GIN', 'dialing_code': '+224', 'timezone': 'UTC', 'currency': 'Guinean franc'}
# {'name': 'Guinea-Bissau', 'capital': 'Bissau', 'country_code': 'GW', 'cc3': 'GNB', 'dialing_code': '+245', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Guyana', 'capital': 'Georgetown', 'country_code': 'GY', 'cc3': 'GUY', 'dialing_code': '+592', 'timezone': 'UTC-03:00', 'currency': 'Guyanese dollar'}
# {'name': 'Haiti', 'capital': 'Port-au-Prince', 'country_code': 'HT', 'cc3': 'HTI', 'dialing_code': '+509', 'timezone': 'UTC-05:00', 'currency': 'Haitian gourde'}
# {'name': 'Heard Island and McDonald Islands', 'capital': '', 'country_code': 'HM', 'cc3': 'HMD', 'dialing_code': '', 'timezone': 'UTC+05', 'currency': ''}
# {'name': 'Honduras', 'capital': 'Tegucigalpa', 'country_code': 'HN', 'cc3': 'HND', 'dialing_code': '+504', 'timezone': 'UTC-06:00', 'currency': 'Honduran lempira'}
# {'name': 'Hong Kong', 'capital': '', 'country_code': 'HK', 'cc3': 'HKG', 'dialing_code': '+852', 'timezone': 'UTC+08:00', 'currency': 'Hong Kong dollar'}
# {'name': 'Hungary', 'capital': 'Budapest', 'country_code': 'HU', 'cc3': 'HUN', 'dialing_code': '+36', 'timezone': 'UTC+01:00', 'currency': 'Hungarian forint'}
# {'name': 'Iceland', 'capital': 'ReykjavÃ\xadk', 'country_code': 'IS', 'cc3': 'ISL', 'dialing_code': '+354', 'timezone': 'UTC', 'currency': 'Icelandic krÃ³na'}
# {'name': 'India', 'capital': 'New Delhi', 'country_code': 'IN', 'cc3': 'IND', 'dialing_code': '+91', 'timezone': 'UTC+05:30', 'currency': 'Indian rupee'}
# {'name': 'Indonesia', 'capital': 'Jakarta', 'country_code': 'ID', 'cc3': 'IDN', 'dialing_code': '+62', 'timezone': 'UTC+07:00 - UTC+09:00', 'currency': 'Indonesian rupiah'}
# {'name': 'Iran', 'capital': 'Tehran', 'country_code': 'IR', 'cc3': 'IRN', 'dialing_code': '+98', 'timezone': 'UTC+03:30', 'currency': 'Iranian rial'}
# {'name': 'Iraq', 'capital': 'Baghdad', 'country_code': 'IQ', 'cc3': 'IRQ', 'dialing_code': '+964', 'timezone': 'UTC+03:00', 'currency': 'Iraqi dinar'}
# {'name': 'Ireland', 'capital': 'Dublin', 'country_code': 'IE', 'cc3': 'IRL', 'dialing_code': '+353', 'timezone': 'UTC', 'currency': 'Euro'}
# {'name': 'Isle of Man', 'capital': 'Douglas', 'country_code': 'IM', 'cc3': 'IMN', 'dialing_code': '+44 1624', 'timezone': 'UTC', 'currency': 'British pound'}
# {'name': 'Israel', 'capital': 'Jerusalem', 'country_code': 'IL', 'cc3': 'ISR', 'dialing_code': '+972', 'timezone': 'UTC+02:00', 'currency': 'Israeli new shekel'}
# {'name': 'Italy', 'capital': 'Rome', 'country_code': 'IT', 'cc3': 'ITA', 'dialing_code': '+39', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Jamaica', 'capital': 'Kingston', 'country_code': 'JM', 'cc3': 'JAM', 'dialing_code': '+1 876', 'timezone': 'UTC-05:00', 'currency': 'Jamaican dollar'}
# {'name': 'Japan', 'capital': 'Tokyo', 'country_code': 'JP', 'cc3': 'JPN', 'dialing_code': '+81', 'timezone': 'UTC+09:00', 'currency': 'Japanese yen'}
# {'name': 'Jersey', 'capital': 'St. Helier', 'country_code': 'JE', 'cc3': 'JEY', 'dialing_code': '+44 1534', 'timezone': 'UTC', 'currency': 'British pound'}
# {'name': 'Jordan', 'capital': 'Amman', 'country_code': 'JO', 'cc3': 'JOR', 'dialing_code': '+962', 'timezone': 'UTC+02:00', 'currency': 'Jordanian dinar'}
# {'name': 'Kazakhstan', 'capital': 'Astana', 'country_code': 'KZ', 'cc3': 'KAZ', 'dialing_code': '+7 6xx/7xx', 'timezone': 'UTC+06:00', 'currency': 'Kazakhstani tenge'}
# {'name': 'Kenya', 'capital': 'Nairobi', 'country_code': 'KE', 'cc3': 'KEN', 'dialing_code': '+254', 'timezone': 'UTC+03:00', 'currency': 'Kenyan shilling'}
# {'name': 'Kiribati', 'capital': 'Tarawa', 'country_code': 'KI', 'cc3': 'KIR', 'dialing_code': '+686', 'timezone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'name': 'Kuwait', 'capital': 'Kuwait City', 'country_code': 'KW', 'cc3': 'KWT', 'dialing_code': '+965', 'timezone': 'UTC+03:00', 'currency': 'Kuwaiti dinar'}
# {'name': 'Kyrgyzstan', 'capital': 'Bishkek', 'country_code': 'KG', 'cc3': 'KGZ', 'dialing_code': '+996', 'timezone': 'UTC+06:00', 'currency': 'Kyrgyzstani som'}
# {'name': 'Laos', 'capital': 'Vientiane', 'country_code': 'LA', 'cc3': 'LAO', 'dialing_code': '+856', 'timezone': 'UTC+07:00', 'currency': 'Lao kip'}
# {'name': 'Latvia', 'capital': 'Riga', 'country_code': 'LV', 'cc3': 'LVA', 'dialing_code': '+371', 'timezone': 'UTC+03:00', 'currency': 'Latvian lats'}
# {'name': 'Lebanon', 'capital': 'Beirut', 'country_code': 'LB', 'cc3': 'LBN', 'dialing_code': '+961', 'timezone': 'UTC+02:00', 'currency': 'Lebanese pound'}
# {'name': 'Lesotho', 'capital': 'Maseru', 'country_code': 'LS', 'cc3': 'LSO', 'dialing_code': '+266', 'timezone': 'UTC+02:00', 'currency': 'Lesotho loti'}
# {'name': 'Liberia', 'capital': 'Monrovia', 'country_code': 'LR', 'cc3': 'LBR', 'dialing_code': '+231', 'timezone': 'UTC', 'currency': 'Liberian dollar'}
# {'name': 'Libya', 'capital': 'Tripoli', 'country_code': 'LY', 'cc3': 'LBY', 'dialing_code': '+218', 'timezone': 'UTC+02:00', 'currency': 'Libyan dinar'}
# {'name': 'Liechtenstein', 'capital': 'Vaduz', 'country_code': 'LI', 'cc3': 'LIE', 'dialing_code': '+423', 'timezone': 'UTC+01:00', 'currency': 'Swiss franc'}
# {'name': 'Lithuania', 'capital': 'Vilnius', 'country_code': 'LT', 'cc3': 'LTU', 'dialing_code': '+370', 'timezone': 'UTC+02:00', 'currency': 'Lithuanian litas'}
# {'name': 'Luxembourg', 'capital': 'Luxembourg', 'country_code': 'LU', 'cc3': 'LUX', 'dialing_code': '+352', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Macau', 'capital': '', 'country_code': 'MO', 'cc3': 'MAC', 'dialing_code': '+853', 'timezone': 'UTC+08:00', 'currency': 'Macanese pataca'}
# {'name': 'Macedonia', 'capital': 'Skopje', 'country_code': 'MK', 'cc3': 'MKD', 'dialing_code': '+389', 'timezone': 'UTC+01:00', 'currency': 'Macedonian denar'}
# {'name': 'Madagascar', 'capital': 'Antananarivo', 'country_code': 'MG', 'cc3': 'MDG', 'dialing_code': '+261', 'timezone': 'UTC+03:00', 'currency': 'Malagasy ariary'}
# {'name': 'Malawi', 'capital': 'Lilongwe', 'country_code': 'MW', 'cc3': 'MWI', 'dialing_code': '+265', 'timezone': 'UTC+02:00', 'currency': 'Malawian kwacha'}
# {'name': 'Malaysia', 'capital': 'Kuala Lumpur', 'country_code': 'MY', 'cc3': 'MYS', 'dialing_code': '+60', 'timezone': 'UTC+08:00', 'currency': 'Malaysian ringgit'}
# {'name': 'Maldives', 'capital': 'MalÃ©', 'country_code': 'MV', 'cc3': 'MDV', 'dialing_code': '+960', 'timezone': 'UTC+05:00', 'currency': 'Maldivian rufiyaa'}
# {'name': 'Mali', 'capital': 'Bamako', 'country_code': 'ML', 'cc3': 'MLI', 'dialing_code': '+223', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Malta', 'capital': 'Valletta', 'country_code': 'MT', 'cc3': 'MLT', 'dialing_code': '+356', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Marshall Islands', 'capital': 'Majuro', 'country_code': 'MH', 'cc3': 'MHL', 'dialing_code': '+692', 'timezone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'name': 'Martinique', 'capital': 'Fort-de-France', 'country_code': 'MQ', 'cc3': 'MTQ', 'dialing_code': '+596', 'timezone': 'UTC-04:00', 'currency': 'Euro'}
# {'name': 'Mauritania', 'capital': 'Nouakchott', 'country_code': 'MR', 'cc3': 'MRT', 'dialing_code': '+222', 'timezone': 'UTC', 'currency': 'Mauritanian ouguiya'}
# {'name': 'Mauritius', 'capital': 'Port Louis', 'country_code': 'MU', 'cc3': 'MUS', 'dialing_code': '+230', 'timezone': 'UTC+04:00', 'currency': 'Mauritian rupee'}
# {'name': 'Mayotte', 'capital': 'Mamoudzou', 'country_code': 'YT', 'cc3': 'MYT', 'dialing_code': '+262 269/639', 'timezone': 'UTC+03:00', 'currency': 'Euro'}
# {'name': 'Mexico', 'capital': 'Mexico City', 'country_code': 'MX', 'cc3': 'MEX', 'dialing_code': '+52', 'timezone': 'UTC-08:00 - UTC-06:00', 'currency': 'Mexican peso'}
# {'name': 'Micronesia', 'capital': 'Palikir', 'country_code': 'FM', 'cc3': 'FSM', 'dialing_code': '+691', 'timezone': 'UTC+10:00', 'currency': 'Micronesian dollar'}
# {'name': 'Moldova', 'capital': 'Chisinau', 'country_code': 'MD', 'cc3': 'MDA', 'dialing_code': '+373', 'timezone': 'UTC+03:00', 'currency': 'Moldovan leu'}
# {'name': 'Monaco', 'capital': 'Monaco', 'country_code': 'MC', 'cc3': 'MCO', 'dialing_code': '+377', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Mongolia', 'capital': 'Ulaanbaatar', 'country_code': 'MN', 'cc3': 'MNG', 'dialing_code': '+976', 'timezone': 'UTC+08:00', 'currency': 'Mongolian tÃ¶grÃ¶g'}
# {'name': 'Montenegro', 'capital': 'Podgorica', 'country_code': 'ME', 'cc3': 'MNE', 'dialing_code': '+382', 'timezone': 'UTC+01', 'currency': 'Euro'}
# {'name': 'Montserrat', 'capital': 'Plymouth', 'country_code': 'MS', 'cc3': 'MSR', 'dialing_code': '+1 664', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Morocco', 'capital': 'Rabat', 'country_code': 'MA', 'cc3': 'MAR', 'dialing_code': '+212', 'timezone': 'UTC', 'currency': 'Moroccan dirham'}
# {'name': 'Mozambique', 'capital': 'Maputo', 'country_code': 'MZ', 'cc3': 'MOZ', 'dialing_code': '+258', 'timezone': 'UTC+02:00', 'currency': 'Mozambican metical'}
# {'name': 'Myanmar (Burma)', 'capital': 'Naypyidaw', 'country_code': 'MM', 'cc3': 'MMR', 'dialing_code': '+95', 'timezone': 'UTC+06:30', 'currency': 'Myanma kyat'}
# {'name': 'Namibia', 'capital': 'Windhoek', 'country_code': 'NA', 'cc3': 'NAM', 'dialing_code': '+264', 'timezone': 'UTC+02:00', 'currency': 'Namibian dollar'}
# {'name': 'Nauru', 'capital': 'Yaren', 'country_code': 'NR', 'cc3': 'NRU', 'dialing_code': '+674', 'timezone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'name': 'Nepal', 'capital': 'Kathmandu', 'country_code': 'NP', 'cc3': 'NPL', 'dialing_code': '+977', 'timezone': 'UTC+05:30', 'currency': 'Nepalese rupee'}
# {'name': 'Netherlands', 'capital': 'Amsterdam', 'country_code': 'NL', 'cc3': 'NLD', 'dialing_code': '+31', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'New Caledonia', 'capital': 'NoumÃ©a', 'country_code': 'NC', 'cc3': 'NCL', 'dialing_code': '+687', 'timezone': 'UTC+11:00', 'currency': 'CFP franc'}
# {'name': 'New Zealand', 'capital': 'Wellington', 'country_code': 'NZ', 'cc3': 'NZL', 'dialing_code': '+64', 'timezone': 'UTC+12:00', 'currency': 'New Zealand dollar'}
# {'name': 'Nicaragua', 'capital': 'Managua', 'country_code': 'NI', 'cc3': 'NIC', 'dialing_code': '+505', 'timezone': 'UTC-06:00', 'currency': 'Nicaraguan cÃ³rdoba'}
# {'name': 'Niger', 'capital': 'Niamey', 'country_code': 'NE', 'cc3': 'NER', 'dialing_code': '+227', 'timezone': 'UTC+01:00', 'currency': 'West African CFA franc'}
# {'name': 'Nigeria', 'capital': 'Abuja', 'country_code': 'NG', 'cc3': 'NGA', 'dialing_code': '+234', 'timezone': 'UTC+01:00', 'currency': 'Nigerian naira'}
# {'name': 'Niue', 'capital': 'Alofi', 'country_code': 'NU', 'cc3': 'NIU', 'dialing_code': '+683', 'timezone': 'UTC-11:00', 'currency': 'New Zealand dollar'}
# {'name': 'Norfolk Island', 'capital': 'Kingston', 'country_code': 'NF', 'cc3': 'NFK', 'dialing_code': '+672 3', 'timezone': 'UTC+11:30', 'currency': 'Australian dollar'}
# {'name': 'North Korea', 'capital': 'Pyongyang', 'country_code': 'KP', 'cc3': 'PRK', 'dialing_code': '+850', 'timezone': 'UTC+09:00', 'currency': 'North Korean won'}
# {'name': 'Northern Mariana Islands', 'capital': 'Saipan', 'country_code': 'MP', 'cc3': 'MNP', 'dialing_code': '+1 670', 'timezone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'name': 'Norway', 'capital': 'Oslo', 'country_code': 'NO', 'cc3': 'NOR', 'dialing_code': '+47', 'timezone': 'UTC+01:00', 'currency': 'Norwegian krone'}
# {'name': 'Oman', 'capital': 'Muscat', 'country_code': 'OM', 'cc3': 'OMN', 'dialing_code': '+968', 'timezone': 'UTC+04:00', 'currency': 'Omani rial'}
# {'name': 'Pakistan', 'capital': 'Islamabad', 'country_code': 'PK', 'cc3': 'PAK', 'dialing_code': '+92', 'timezone': 'UTC+05:00', 'currency': 'Pakistani rupee'}
# {'name': 'Palau', 'capital': 'Ngerulmud', 'country_code': 'PW', 'cc3': 'PLW', 'dialing_code': '+680', 'timezone': 'UTC+09:00', 'currency': 'Palauan dollar'}
# {'name': 'Panama', 'capital': 'Panama City', 'country_code': 'PA', 'cc3': 'PAN', 'dialing_code': '+507', 'timezone': 'UTC-05:00', 'currency': 'Panamanian balboa'}
# {'name': 'Papua New Guinea', 'capital': 'Port Moresby', 'country_code': 'PG', 'cc3': 'PNG', 'dialing_code': '+675', 'timezone': 'UTC+10:00', 'currency': 'Papua New Guinean kina'}
# {'name': 'Paraguay', 'capital': 'AsunciÃ³n', 'country_code': 'PY', 'cc3': 'PRY', 'dialing_code': '+595', 'timezone': 'UTC-04:00', 'currency': 'Paraguayan guaranÃ\xad'}
# {'name': 'Peru', 'capital': 'Lima', 'country_code': 'PE', 'cc3': 'PER', 'dialing_code': '+51', 'timezone': 'UTC-05:00', 'currency': 'Peruvian nuevo sol'}
# {'name': 'Philippines', 'capital': 'Manila', 'country_code': 'PH', 'cc3': 'PHL', 'dialing_code': '+63', 'timezone': 'UTC+08:00', 'currency': 'Philippine peso'}
# {'name': 'Pitcairn', 'capital': 'Adamstown', 'country_code': 'PN', 'cc3': 'PCN', 'dialing_code': '+872', 'timezone': 'UTC-08', 'currency': 'New Zealand dollar'}
# {'name': 'Poland', 'capital': 'Warsaw', 'country_code': 'PL', 'cc3': 'POL', 'dialing_code': '+48', 'timezone': 'UTC+01:00', 'currency': 'Polish zÅ‚oty'}
# {'name': 'Portugal', 'capital': 'Lisbon', 'country_code': 'PT', 'cc3': 'PRT', 'dialing_code': '+351', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Puerto Rico', 'capital': 'San Juan', 'country_code': 'PR', 'cc3': 'PRI', 'dialing_code': '+1 787/939', 'timezone': 'UTC-04:00', 'currency': 'United States dollar'}
# {'name': 'Qatar', 'capital': 'Doha', 'country_code': 'QA', 'cc3': 'QAT', 'dialing_code': '+974', 'timezone': 'UTC+03:00', 'currency': 'Qatari riyal'}
# {'name': 'Reunion', 'capital': '', 'country_code': 'RE', 'cc3': 'REU', 'dialing_code': '+262', 'timezone': 'UTC+04:00', 'currency': 'Euro'}
# {'name': 'Romania', 'capital': 'Bucharest', 'country_code': 'RO', 'cc3': 'ROU', 'dialing_code': '+40', 'timezone': 'UTC+02:00', 'currency': 'Romanian leu'}
# {'name': 'Russia', 'capital': 'Moscow', 'country_code': 'RU', 'cc3': 'RUS', 'dialing_code': '+7', 'timezone': 'UTC+03:00', 'currency': 'Russian ruble'}
# {'name': 'Rwanda', 'capital': 'Kigali', 'country_code': 'RW', 'cc3': 'RWA', 'dialing_code': '+250', 'timezone': 'UTC+02:00', 'currency': 'Rwandan franc'}
# {'name': 'Saint Barthelemy', 'capital': 'Gustavia', 'country_code': 'BL', 'cc3': 'BLM', 'dialing_code': '+590', 'timezone': 'UTC-04', 'currency': 'Euro'}
# {'name': 'Saint Helena', 'capital': 'Jamestown', 'country_code': 'SH', 'cc3': 'SHN', 'dialing_code': '+290', 'timezone': 'UTC', 'currency': 'Saint Helena pound'}
# {'name': 'Saint Kitts and Nevis', 'capital': 'Basseterre', 'country_code': 'KN', 'cc3': 'KNA', 'dialing_code': '+1 869', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Saint Lucia', 'capital': 'Castries', 'country_code': 'LC', 'cc3': 'LCA', 'dialing_code': '+1 758', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'name': 'Saint Martin', 'capital': 'Marigot', 'country_code': 'MF', 'cc3': 'MAF', 'dialing_code': '+590', 'timezone': 'UTC-04', 'currency': 'Euro'}
# {'name': 'Saint Pierre and Miquelon', 'capital': 'St. Pierre', 'country_code': 'PM', 'cc3': 'SPM', 'dialing_code': '+508', 'timezone': 'UTC-03', 'currency': 'Euro'}
# {'name': 'Saint Vincent and the Grenadines', 'capital': 'Kingstown', 'country_code': 'VC', 'cc3': 'VCT', 'dialing_code': '+1 784', 'timezone': 'UTC-04', 'currency': 'East Caribbean dollar'}
# {'name': 'Samoa', 'capital': 'Apia', 'country_code': 'WS', 'cc3': 'WSM', 'dialing_code': '+685', 'timezone': 'UTC-11:00', 'currency': 'Samoan tala'}
# {'name': 'San Marino', 'capital': 'San Marino', 'country_code': 'SM', 'cc3': 'SMR', 'dialing_code': '+378', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Sao Tome and PrÃ\xadncipe', 'capital': 'SÃ£o TomÃ©', 'country_code': 'ST', 'cc3': 'STP', 'dialing_code': '+239', 'timezone': 'UTC', 'currency': 'SÃ£o TomÃ© and PrÃ\xadncipe dobra'}
# {'name': 'Saudi Arabia', 'capital': 'Riyadh', 'country_code': 'SA', 'cc3': 'SAU', 'dialing_code': '+966', 'timezone': 'UTC+03:00', 'currency': 'Saudi riyal'}
# {'name': 'Senegal', 'capital': 'Dakar', 'country_code': 'SN', 'cc3': 'SEN', 'dialing_code': '+221', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Serbia', 'capital': 'Belgrade', 'country_code': 'RS', 'cc3': 'SRB', 'dialing_code': '+381', 'timezone': 'UTC+01:00', 'currency': 'Serbian dinar'}
# {'name': 'Seychelles', 'capital': 'Victoria', 'country_code': 'SC', 'cc3': 'SYC', 'dialing_code': '+248', 'timezone': 'UTC+04:00', 'currency': 'Seychellois rupee'}
# {'name': 'Sierra Leone', 'capital': 'Freetown', 'country_code': 'SL', 'cc3': 'SLE', 'dialing_code': '+232', 'timezone': 'UTC', 'currency': 'Sierra Leonean leone'}
# {'name': 'Singapore', 'capital': 'Singapore', 'country_code': 'SG', 'cc3': 'SGP', 'dialing_code': '+65', 'timezone': 'UTC+08:00', 'currency': 'Brunei dollar'}
# {'name': 'Sint Maarten', 'capital': 'Philipsburg', 'country_code': 'SX', 'cc3': 'SXM', 'dialing_code': '+599 5', 'timezone': 'UTC-04:00', 'currency': 'Netherlands Antillean guilder'}
# {'name': 'Slovakia', 'capital': 'Bratislava', 'country_code': 'SK', 'cc3': 'SVK', 'dialing_code': '+421', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Slovenia', 'capital': 'Ljubljana', 'country_code': 'SI', 'cc3': 'SVN', 'dialing_code': '+386', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Solomon Islands', 'capital': 'Honiara', 'country_code': 'SB', 'cc3': 'SLB', 'dialing_code': '+677', 'timezone': 'UTC+11:00', 'currency': 'Solomon Islands dollar'}
# {'name': 'Somalia', 'capital': 'Mogadishu', 'country_code': 'SO', 'cc3': 'SOM', 'dialing_code': '+252', 'timezone': 'UTC+03:00', 'currency': 'Somali shilling'}
# {'name': 'South Africa', 'capital': 'Pretoria', 'country_code': 'ZA', 'cc3': 'ZAF', 'dialing_code': '+27', 'timezone': 'UTC+02:00', 'currency': 'South African rand'}
# {'name': 'South Georgia and the South Sandwich Islands', 'capital': 'Grytviken', 'country_code': 'GS', 'cc3': 'SGS', 'dialing_code': '', 'timezone': 'UTC-02', 'currency': 'British pound'}
# {'name': 'South Korea', 'capital': 'Seoul', 'country_code': 'KR', 'cc3': 'KOR', 'dialing_code': '+82', 'timezone': 'UTC+09:00', 'currency': 'South Korean won'}
# {'name': 'Spain', 'capital': 'Madrid', 'country_code': 'ES', 'cc3': 'ESP', 'dialing_code': '+34', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'name': 'Sri Lanka', 'capital': 'Sri Jayawardenapura Kotte', 'country_code': 'LK', 'cc3': 'LKA', 'dialing_code': '+94', 'timezone': 'UTC+05:30', 'currency': 'Sri Lankan rupee'}
# {'name': 'Sudan', 'capital': 'Khartoum', 'country_code': 'SD', 'cc3': 'SDN', 'dialing_code': '+249', 'timezone': 'UTC+02:00', 'currency': 'Sudanese pound'}
# {'name': 'Suriname', 'capital': 'Paramaribo', 'country_code': 'SR', 'cc3': 'SUR', 'dialing_code': '+597', 'timezone': 'UTC-03:30', 'currency': 'Surinamese dollar'}
# {'name': 'Svalbard and Jan Mayen', 'capital': '', 'country_code': 'SJ', 'cc3': 'SJM', 'dialing_code': '+47', 'timezone': 'UTC+01:00', 'currency': 'Norwegian krone'}
# {'name': 'Swaziland', 'capital': 'Mbabane', 'country_code': 'SZ', 'cc3': 'SWZ', 'dialing_code': '+268', 'timezone': 'UTC+02:00', 'currency': 'Swazi lilangeni'}
# {'name': 'Sweden', 'capital': 'Stockholm', 'country_code': 'SE', 'cc3': 'SWE', 'dialing_code': '+46', 'timezone': 'UTC+01:00', 'currency': 'Swedish krona'}
# {'name': 'Switzerland', 'capital': 'Bern', 'country_code': 'CH', 'cc3': 'CHE', 'dialing_code': '+41', 'timezone': 'UTC+01:00', 'currency': 'Swiss franc'}
# {'name': 'Syrian Arab Republic', 'capital': 'Damascus', 'country_code': 'SY', 'cc3': 'SYR', 'dialing_code': '+963', 'timezone': 'UTC+02:00', 'currency': 'Syrian pound'}
# {'name': 'Taiwan', 'capital': 'Taipei', 'country_code': 'TW', 'cc3': 'TWN', 'dialing_code': '+886', 'timezone': 'UTC+08:00', 'currency': 'New Taiwan dollar'}
# {'name': 'Tajikistan', 'capital': 'Dushanbe', 'country_code': 'TJ', 'cc3': 'TJK', 'dialing_code': '+992', 'timezone': 'UTC+06:00', 'currency': 'Tajikistani somoni'}
# {'name': 'Tanzania', 'capital': 'Dodoma', 'country_code': 'TZ', 'cc3': 'TZA', 'dialing_code': '+255', 'timezone': 'UTC+03:00', 'currency': 'Tanzanian shilling'}
# {'name': 'Thailand', 'capital': 'Bangkok', 'country_code': 'TH', 'cc3': 'THA', 'dialing_code': '+66', 'timezone': 'UTC+07:00', 'currency': 'Thai baht'}
# {'name': 'Togo', 'capital': 'LomÃ©', 'country_code': 'TG', 'cc3': 'TGO', 'dialing_code': '+228', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'name': 'Tokelau', 'capital': 'Rotates annually', 'country_code': 'TK', 'cc3': 'TKL', 'dialing_code': '+690', 'timezone': 'UTC-10', 'currency': 'New Zealand dollar'}
# {'name': 'Tonga', 'capital': 'Nuku', 'country_code': 'TO', 'cc3': 'TON', 'dialing_code': '+676', 'timezone': 'UTC+13:00', 'currency': 'Tongan paÊ»anga'}
# {'name': 'Trinidad and Tobago', 'capital': 'Port of Spain', 'country_code': 'TT', 'cc3': 'TTO', 'dialing_code': '+1 868', 'timezone': 'UTC-04:00', 'currency': 'Trinidad and Tobago dollar'}
# {'name': 'Tunisia', 'capital': 'Tunis', 'country_code': 'TN', 'cc3': 'TUN', 'dialing_code': '+216', 'timezone': 'UTC+01:00', 'currency': 'Tunisian dinar'}
# {'name': 'Turkey', 'capital': 'Ankara', 'country_code': 'TR', 'cc3': 'TUR', 'dialing_code': '+90', 'timezone': 'UTC+02:00', 'currency': 'Turkish lira'}
# {'name': 'Turkmenistan', 'capital': 'Ashgabat', 'country_code': 'TM', 'cc3': 'TKM', 'dialing_code': '+993', 'timezone': 'UTC+05:00', 'currency': 'Turkmenistani manat'}
# {'name': 'Turks and Caicos Islands', 'capital': 'Cockburn Town', 'country_code': 'TC', 'cc3': 'TCA', 'dialing_code': '+1 649', 'timezone': 'UTC-05:00', 'currency': 'United States dollar'}
# {'name': 'Tuvalu', 'capital': 'Funafuti', 'country_code': 'TV', 'cc3': 'TUV', 'dialing_code': '+688', 'timezone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'name': 'Uganda', 'capital': 'Kampala', 'country_code': 'UG', 'cc3': 'UGA', 'dialing_code': '+256', 'timezone': 'UTC+03:00', 'currency': 'Ugandan shilling'}
# {'name': 'Ukraine', 'capital': 'Kiev', 'country_code': 'UA', 'cc3': 'UKR', 'dialing_code': '+380', 'timezone': 'UTC+03:00', 'currency': 'Ukrainian hryvnia'}
# {'name': 'United Arab Emirates', 'capital': 'Abu Dhabi', 'country_code': 'AE', 'cc3': 'ARE', 'dialing_code': '+971', 'timezone': 'UTC+04:00', 'currency': 'United Arab Emirates dirham'}
# {'name': 'United Kingdom', 'capital': 'London', 'country_code': 'GB', 'cc3': 'GBR', 'dialing_code': '+44', 'timezone': 'UTC', 'currency': 'British pound'}
# {'name': 'United States', 'capital': 'Washington D.C.', 'country_code': 'US', 'cc3': 'USA', 'dialing_code': '+1', 'timezone': 'UTC-11:00 - UTC-05:00', 'currency': 'United States dollar'}
# {'name': 'United States Minor Outlying Islands', 'capital': '', 'country_code': 'UM', 'cc3': 'UMI', 'dialing_code': '+1', 'timezone': '', 'currency': 'United States dollar'}
# {'name': 'Uruguay', 'capital': 'Montevideo', 'country_code': 'UY', 'cc3': 'URY', 'dialing_code': '+598', 'timezone': 'UTC-03:00', 'currency': 'Uruguayan peso'}
# {'name': 'Uzbekistan', 'capital': 'Tashkent', 'country_code': 'UZ', 'cc3': 'UZB', 'dialing_code': '+998', 'timezone': 'UTC+06:00', 'currency': 'Uzbekistani som'}
# {'name': 'Vanuatu', 'capital': 'Port Vila', 'country_code': 'VU', 'cc3': 'VUT', 'dialing_code': '+678', 'timezone': 'UTC+11:00', 'currency': 'Vanuatu vatu'}
# {'name': 'Vatican City', 'capital': 'Vatican City', 'country_code': 'VA', 'cc3': 'VAT', 'dialing_code': '+39 06 698', 'timezone': 'UTC+01', 'currency': 'Euro'}
# {'name': 'Venezuela', 'capital': 'Caracas', 'country_code': 'VE', 'cc3': 'VEN', 'dialing_code': '+58', 'timezone': 'UTC-04:00', 'currency': 'Venezuelan bolÃ\xadvar'}
# {'name': 'Vietnam', 'capital': 'Hanoi', 'country_code': 'VN', 'cc3': 'VNM', 'dialing_code': '+84', 'timezone': 'UTC+07:00', 'currency': 'Vietnamese Ä‘á»“ng'}
# {'name': 'Virgin Islands', 'capital': 'Road Town', 'country_code': 'VG', 'cc3': 'VGB', 'dialing_code': '+1 284', 'timezone': 'UTC-04', 'currency': 'British Virgin Islands dollar'}
# {'name': 'Virgin Islands of the United States', 'capital': 'Charlotte Amalie', 'country_code': 'VI', 'cc3': 'VIR', 'dialing_code': '+1 340', 'timezone': 'UTC-04', 'currency': 'United States dollar'}
# {'name': 'Wallis and Futuna', 'capital': 'Mata-Utu', 'country_code': 'WF', 'cc3': 'WLF', 'dialing_code': '+681', 'timezone': 'UTC+12:00', 'currency': 'CFP franc'}
# {'name': 'Western Sahara', 'capital': 'LaÃ¢youne (El AaiÃºn)', 'country_code': 'EH', 'cc3': 'ESH', 'dialing_code': '+212 5288/5289', 'timezone': 'UTC+01', 'currency': 'Moroccan dirham'}
# {'name': 'Yemen', 'capital': 'SanaÃ¡', 'country_code': 'YE', 'cc3': 'YEM', 'dialing_code': '+967', 'timezone': 'UTC+03:00', 'currency': 'Yemeni rial'}
# {'name': 'Zambia', 'capital': 'Lusaka', 'country_code': 'ZM', 'cc3': 'ZMB', 'dialing_code': '+260', 'timezone': 'UTC+02:00', 'currency': 'Zambian kwacha'}
# {'name': 'Zimbabwe', 'capital': 'Harare', 'country_code': 'ZW', 'cc3': 'ZWE', 'dialing_code': '+263', 'timezone': 'UTC+02:00', 'currency': 'Botswana pula'}
# {'afghanistan': {'name': 'Afghanistan', 'capital': 'Kabul', 'country_code': 'AF', 'cc3': 'AFG', 'dialing_code': '+93', 'timezone': 'UTC+04:30', 'currency': 'Afghan afghani'}, 'aland islands': {'name': 'Aland Islands', 'capital': 'Mariehamn', 'country_code': 'AX', 'cc3': 'ALA', 'dialing_code': '+358', 'timezone': 'UTC+02:00', 'currency': 'Euro'}, 'albania': {'name': 'Albania', 'capital': 'Tirana', 'country_code': 'AL', 'cc3': 'ALB', 'dialing_code': '+355', 'timezone': 'UTC+01:00', 'currency': 'Albanian lek'}, 'algeria': {'name': 'Algeria', 'capital': 'Algiers', 'country_code': 'DZ', 'cc3': 'DZA', 'dialing_code': '+213', 'timezone': 'UTC', 'currency': 'Algerian dinar'}, 'american samoa': {'name': 'American Samoa', 'capital': 'Pago Pago', 'country_code': 'AS', 'cc3': 'ASM', 'dialing_code': '+1 684', 'timezone': 'UTC-11:00', 'currency': ''}, 'andorra': {'name': 'Andorra', 'capital': 'Andorra la Vella', 'country_code': 'AD', 'cc3': 'AND', 'dialing_code': '+376', 'timezone': 'UTC+01:00', 'currency': 'Euro'}, 'angola': {'name': 'Angola', 'capital': 'Luanda', 'country_code': 'AO', 'cc3': 'AGO', 'dialing_code': '+244', 'timezone': 'UTC+01:00', 'currency': 'Angolan kwanza'}, 'anguilla': {'name': 'Anguilla', 'capital': 'The Valley', 'country_code': 'AI', 'cc3': 'AIA', 'dialing_code': '+1 264', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}, 'antarctica': {'name': 'Antarctica', 'capital': '', 'country_code': 'AQ', 'cc3': 'ATA', 'dialing_code': '', 'timezone': '', 'currency': ''}, 'antigua and barbuda': {'name': 'Antigua and Barbuda', 'capital': "St. John's", 'country_code': 'AG', 'cc3': 'ATG', 'dialing_code': '+1 268', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}, 'argentina': {'name': 'Argentina', 'capital': 'Buenos Aires', 'country_code': 'AR', 'cc3': 'ARG', 'dialing_code': '+54', 'timezone': 'UTC-03:00', 'currency': 'Argentine peso'}, 'armenia': {'name': 'Armenia', 'capital': 'Yerevan', 'country_code': 'AM', 'cc3': 'ARM', 'dialing_code': '+374', 'timezone': 'UTC+04:00', 'currency': 'Armenian dram'}, 'aruba': {'name': 'Aruba', 'capital': 'Oranjestad', 'country_code': 'AW', 'cc3': 'ABW', 'dialing_code': '+297', 'timezone': 'UTC-04:00', 'currency': 'Aruban florin'}, 'australia': {'name': 'Australia', 'capital': 'Canberra', 'country_code': 'AU', 'cc3': 'AUS', 'dialing_code': '+61', 'timezone': 'UTC+07:00 - UTC+10:00', 'currency': 'Australian dollar'}, 'austria': {'name': 'Austria', 'capital': 'Vienna', 'country_code': 'AT', 'cc3': 'AUT', 'dialing_code': '+43', 'timezone': 'UTC+01:00', 'currency': 'Euro'}, 'azerbaijan': {'name': 'Azerbaijan', 'capital': 'Baku', 'country_code': 'AZ', 'cc3': 'AZE', 'dialing_code': '+994', 'timezone': 'UTC+04:00', 'currency': 'Azerbaijani manat'}, 'bahamas': {'name': 'Bahamas', 'capital': 'Nassau', 'country_code': 'BS', 'cc3': 'BHS', 'dialing_code': '+1 242', 'timezone': 'UTC-05:00', 'currency': 'Bahamian dollar'}, 'bahrain': {'name': 'Bahrain', 'capital': 'Manama', 'country_code': 'BH', 'cc3': 'BHR', 'dialing_code': '+973', 'timezone': 'UTC+03:00', 'currency': 'Bahraini dinar'}, 'bangladesh': {'name': 'Bangladesh', 'capital': 'Dhaka', 'country_code': 'BD', 'cc3': 'BGD', 'dialing_code': '+880', 'timezone': 'UTC+06:00', 'currency': 'Bangladeshi taka'}, 'barbados': {'name': 'Barbados', 'capital': 'Bridgetown', 'country_code': 'BB', 'cc3': 'BRB', 'dialing_code': '+1 246', 'timezone': 'UTC-04:00', 'currency': 'Barbadian dollar'}, 'belarus': {'name': 'Belarus', 'capital': 'Minsk', 'country_code': 'BY', 'cc3': 'BLR', 'dialing_code': '+375', 'timezone': 'UTC+03:00', 'currency': 'Belarusian ruble'}, 'belgium': {'name': 'Belgium', 'capital': 'Brussels', 'country_code': 'BE', 'cc3': 'BEL', 'dialing_code': '+32', 'timezone': 'UTC+01:00', 'currency': 'Euro'}, 'belize': {'name': 'Belize', 'capital': 'Belmopan', 'country_code': 'BZ', 'cc3': 'BLZ', 'dialing_code': '+501', 'timezone': 'UTC-06:00', 'currency': 'Belize dollar'}, 'benin': {'name': 'Benin', 'capital': 'Porto-Novo', 'country_code':  ...

# %%
# to check wheather the entered country present in the dict or not
while True:
    chosen_country = input('Please enter the name of a country: ').casefold()
    if chosen_country in countries:
        country_data = countries[chosen_country]
        print(country_data)
    else:
        print("try with another")
        break
# Out:
# Please enter the name of a country: lok
# try with another

# %%
#printing data to a text file

data = [
    "Andromeda - Shrub",
    "Bellflower - Flower",
    "China Pink - Flower",
    "Daffodil - Flower",
    "Evening Primrose - Flower",
    "French Marigold - Flower",
    "Hydrangea - Shrub",
    "Iris - Flower",
    "Japanese Camellia - Shrub",
    "Lavender - Shrub",
    "Lilac- Shrub",
    "Magnolia - Shrub",
    "Peony - Shrub",
    "Queen Anne's Lace - Flower",
    "Red Hot Poker - Flower",
    "Snapdragon - Flower",
    "Sunflower - Flower",
    "Tiger Lily - Flower",
    "Witch Hazel - Shrub",
]
plants_filename = "flowers_print.txt"

with open(plants_filename, "w") as plants:
    for plant in data:
        print(plant, file=plants)

new_list = []
with open(plants_filename) as plants:
    for plant in plants:
        new_list.append(plant.rstrip())

print(new_list)
# Out:
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']

# %%
# writing data to a flower_plant data (inserting data in existing file)
plants_filename = "flowers_write.txt"
with open(plants_filename, "w") as plants:
    for plant in data:
        plants.write(plant)
        print(data)
string_representation = data.__str__()
print(type(string_representation))
# Out:
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac- Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']
# <class 'str'>

# %%
# writing data to a text file
filename = "test_numbers.txt"
with open(filename, "w") as test:
    for i in range(10):
        print(i, file=test)

with open(filename, "w") as test:
    for i in range(10):
        test.write(str(i) + "\n")

# %%
# to overcome with strange string in the poem using encoding
with open('Jabberwocky.txt', encoding='utf-8') as jabber:
    for line in jabber:
        print(line.rstrip())
# Out:
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# "Beware the Jabberwock, my son!
# The jaws that bite, the claws that catch!
# Beware the Jubjub bird, and shun
# The frumious Bandersnatch!"
#
# He took his vorpal sword in hand:
# Long time the manxome foe he sought—
# So rested he by the Tumtum tree,
# And stood awhile in thought.
#
# And as in uffish thought he stood,
# The Jabberwock, with eyes of flame,
# Came whiffling through the tulgey wood,
# And burbled as it came!
#
# One two! One two! And through and through
# The vorpal blade went snicker-snack!
# He left it dead, and with its head
# He went galumphing back.
#
# "And hast thou slain the Jabberwock?
# Come to my arms, my beamish boy!"
# "O frabjous day! Callooh! Callay!"
# He chortled in his joy.
#
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
#     – Lewis Carroll

# %%
# reading csv file
import csv
with open('marks.csv','r') as file:
    r=csv.reader(file,delimiter=',') # default value of delimeter is ',' #if we give '\t' its consider row as one object
    for i in r:
        print(i) # 1st row is header  #LA-->lab assesment
# Out:
# ['Reg', 'Name', 'LA1', 'LA2', 'LA3', 'LA4']
# ['2018-MC-01', 'Muhammad Usman', '4', '5', '0', '3']
# ['2018-MC-02', 'Tahir Mehmood', '0.5', '5.5', '1', '1']
# ['2018-MC-03', 'Muhammad Bilal', '2.5', '5', '2', '4']
# ['2018-MC-04', 'Muhammad Nadeem', '3.5', '4.5', '1', '5']
# ['2018-MC-05', 'Muhammad Ahmad Iftikhar', '4.5', '6', '0', '5']
# ['2018-MC-06', 'Syed Faraz Abbas', '1', '6.5', '3', '3']
# ['2018-MC-07', 'Muhammad Qasim', 'A', 'A', 'A', 'A']
# ['2018-MC-08', 'Muhammad Ghufran', '4', '6', '3', '5']
# ['2018-MC-09', 'Taimoor Sikandar', '2', '6', '5', '4']
# ['2018-MC-10', 'Muhammad Moadib Nasir', '3.5', '3', '3', '3']
# ['2018-MC-11', 'Sheikh Osama Fazal', '2', '2', '1', 'A']
# ['2018-MC-12', 'Roshaan Sajjad', '4', '5', '5', '4']
# ['2018-MC-13', 'Muhammad Awais Akhter', '3', '6.5', '3', '3']
# ['2018-MC-14', 'Muhammad Kazim Raza', '3', '5', '2', '1']
# ['2018-MC-15', 'Omar Ashraf', 'A', '5', '2', '5']
# ['2018-MC-16', 'Muhammad Asaad', '3.5', '5', '5', '5']
# ['2018-MC-17', 'Abdul Majid', '3.5', '3', '5', '5']
# ['2018-MC-18', 'Muhammad Awais', '1.5', 'A', '1', '3']
# ['2018-MC-19', 'Muhammad Ali Hadir', '4', '4.5', '5', '5']
# ['2018-MC-20', 'Jahanzaib Aslam', '2.5', '3', '0', '3.5']
# ['2018-MC-21', 'Muhammad Ibtisam Umer', '4', '3.5', '5', '5']
# ['2018-MC-22', 'Tufail Hussain', '3', '6.5', '2', '0']
# ['2018-MC-23', 'M Atif Riaz', '4.5', '6', '3', '4']
# ['2018-MC-24', 'Muhammad Abdullah', '3.5', '4', '3', '5']
# ['2018-MC-25', 'Ahmad Shaukat', '3.5', '5', '2', '1']
# ['2018-MC-26', 'Muhammad Nauman', '5', '6.5', '5', '4']
# ['2018-MC-27', 'Hamza Rizwan', '3', '5', '3', '3']
# ['2018-MC-28', 'Burhan Azeem', '2', '6.5', '2', '5']
# ['2018-MC-29', 'Muhammad Sikander Raheem', '3.5', '4', '5', '4']
# ['2018-MC-30', 'Muhammad Abdullah', '3', '6.5', '3', '5']
# ['2018-MC-31', 'Mian Ali Haider', '3.5', '6.5', '0', '5']
# ['2018-MC-32', 'Muhammad Irfan Saleem', '1', 'A', 'A', '3']
# ['2018-MC-33', 'Muhammad Hamza Mushtaq', '4.5', '3.5', '2.5', '3']
# ['2018-MC-34', 'Jamshaid Zafar', '4.5', '5.5', '5', '5']
# ['2018-MC-35', 'Zamara Batool', '1.5', '5', '3', '4']
# ['2018-MC-36', 'Noor Ul Ain', '4', '5', '5', '5']
# ['2018-MC-37', 'Farwa Mehmood', '5', '6.5', '5', '5']
# ['2018-MC-38', 'Tanzeela Arif', '1', '3.5', '1', '2']
# ['2018-MC-39', 'Samra Yousaf', '0', '3.5', '0', '5']
# ['2018-MC-40', 'Ayesha Aslam', '2', '5', '3', '4']
# ['2018-MC-41', 'Maryum Kainat', '3', '5', '2', '5']
# ['2018-MC-42', 'Hadiqa', '4', '7', '5', '5']
# ['2018-MC-43', 'Iram', '4', '3.5', '1', '2']
# ['2018-MC-44', 'Rida Fatima', '4.5', '4', '3', '5']
# ['2018-MC-45', 'Mahesh Sharma', '2.5', '2.5', '5', '5']
# ['2018-MC-46', 'Faqeeha Khan', '3.5', '3', '0', '2']
# ['2018-R/2017-MC-29', 'Abdul Manan', '1.5', '6.5', '0', '2']
# ['2018-R/2017-MC-36', 'Hafiz M. Waleed Shoaib', '2', '3.5', '2', '1']
# ['2018-R/2017-MC-37', 'Ikram Khan', 'A', 'A', '1', '0']
# ['2018-MC-51', 'Danish', '4.5', '7', '3', '5']
# ['2018-MC-52', 'Hafiz Muhammad Aqib Ali', '4.5', '3.5', '2', '4.5']
# ['2018-MC-53', 'Muhammad Ibrahim', '4', '7', '5', '5']
# ['2018-MC-54', 'Hamayoun Qamar Qureshi', '3', '6.5', '5', '5']
# ['2018-MC-55', 'Muhammad Abdul Wahab', '4', '6.5', '3', '2']
# ['2018-MC-56', 'Muhammad Ehtisham Zafar', '4', '5.5', '5', '5']
# ['2018-MC-58', 'Muhammad Faisal Shahid', '4.5', '7', '5', '5']
# ['2018-MC-59', 'Ahmad Hussain', '5', '7', '5', '5']
# ['2018-MC-60', 'Shahroz Ahmed', '5', '7', '3', '5']
# ['2018-MC-61', 'M Sannan Arshad', '4.5', '6.5', '2', '4']
# ['2018-MC-62', 'Khaqan Ahmed', '4.5', '6', '5', '5']
# ['2018-MC-63', 'Arbab Khalid', '3.5', '3', '5', '1']
# ['2018-MC-64', 'Talha Khan', '4', '5', '0', '3']
# ['2018-MC-65', 'Abdul Rehman Baig', '3.5', '5.5', '5', '4']
# ['2018-MC-66', 'Muhammad Ammar', '4.5', '7', '5', '5']
# ['2018-MC-67', 'Mohammad Hozefa Saleem', '2.5', '4', '2', '2']
# ['2018-MC-68', 'Muhammad Abdullah', '4.5', '2', '5', '5']
# ['2018-MC-69', 'Ali Zaman', '5', '5', '5', '5']
# ['2018-MC-70', 'Syed Waqar Haider Bukhari', '2.5', '3', '4', '2']
# ['2018-MC-72', 'Mian M.Husnain Akram', '5', '7', '5', '5']
# ['2018-MC-73', 'Shahzad Niaz', '4.5', '7', '5', '5']
# ['2018-MC-74', 'Waleed Bin Qaisar', '4', '6.5', '5', '4']
# ['2018-MC-75', 'Huzaifa Imtiaz', '4', '6', '5', '5']
# ['2018-MC-76', 'Ibtisam Ul Hassan', '4', '7', 'A', '3']
# ['2018-MC-77', 'Muhammad Usman Ghani', '3.5', '6', '3', '5']
# ['2018-MC-78', 'Aurang Zaib Younis Virk', '4.5', '6.5', '5', '3']
# ['2018-MC-79', 'Hassan Abdul Basit', '4.5', '6', '5', '5']
# ['2018-MC-80', 'Taimoor Ahmed Pal', '5', '7', '5', '4']
# ['2018-MC-81', 'Hafiz Muhammad Usman Ahmed', '5', '6.5', '5', '5']
# ['2018-MC-82', 'Tayyab Rasheed', '3.5', '5.5', '3', '3']
# ['2018-MC-83', 'Usama Iqbal', '5', '6.5', '5', '5']
# ['2018-MC-84', 'Ahtesham Zafar', '1.5', '4.5', '5', '3']
# ['2018-MC-85', 'Assad Ali', '3.5', '1.5', '5', '0']
# ['2018-MC-86', 'Mazhar Mustafa', '2', '5.5', '4', '2']
# ['2018-MC-87', 'Muhammad Muneeb Irfan Mughal', '4.5', '6', '5', '5']
# ['2018-MC-88', 'Abdul Rehman', '4.5', '7', '5', '3']
# ['2018-MC-89', 'Syeda Tayyaba Bukhari', '5', '6.5', '5', '5']
# ['2018-MC-90', 'Maheen Abdul Ghani', '5', '6', '5', '5']
# ['2018-MC-91', 'Faryal Nasir', '3.5', '7', '2', '5']
# ['2018-MC-92', 'Ayesha Nadeem', '3', '3', '5', '3']
# ['2018-MC-93', 'Aqsa Amjad', '5', '5.5', '5', '3']
# ['2018-MC-94', 'Arfa Nisar', '4.5', '7', '5', '5']
# ['2018-MC-95', 'Iqra Amjad', '5', '7', '5', '5']
# ['2018-MC-96', 'Noor Fatima', '3', '7', '5', 'A']
# ['2018-R/2017-MC-47', 'Muhammad Abdullah', '5', '6', '0', '4']
# ['2018-R/2017-MC-77', 'Muhammad Faseeh Bin Naeem', '4', '5', '2', '5']
# ['2018-R/2017-MC-103', 'Jehanzeb Hussain', 'A', '4', '5', 'A']

# %%
#  converting each row to dict
import csv
with open('marks.csv','r') as file:
    r=csv.DictReader(file,delimiter=',') # each line converted to dict with keys = header(1st row),values=records(from 2nd line onwards)
    for i in r:
        print(i)
# Out:
# {'Reg': '2018-MC-01', 'Name': 'Muhammad Usman', 'LA1': '4', 'LA2': '5', 'LA3': '0', 'LA4': '3'}
# {'Reg': '2018-MC-02', 'Name': 'Tahir Mehmood', 'LA1': '0.5', 'LA2': '5.5', 'LA3': '1', 'LA4': '1'}
# {'Reg': '2018-MC-03', 'Name': 'Muhammad Bilal', 'LA1': '2.5', 'LA2': '5', 'LA3': '2', 'LA4': '4'}
# {'Reg': '2018-MC-04', 'Name': 'Muhammad Nadeem', 'LA1': '3.5', 'LA2': '4.5', 'LA3': '1', 'LA4': '5'}
# {'Reg': '2018-MC-05', 'Name': 'Muhammad Ahmad Iftikhar', 'LA1': '4.5', 'LA2': '6', 'LA3': '0', 'LA4': '5'}
# {'Reg': '2018-MC-06', 'Name': 'Syed Faraz Abbas', 'LA1': '1', 'LA2': '6.5', 'LA3': '3', 'LA4': '3'}
# {'Reg': '2018-MC-07', 'Name': 'Muhammad Qasim', 'LA1': 'A', 'LA2': 'A', 'LA3': 'A', 'LA4': 'A'}
# {'Reg': '2018-MC-08', 'Name': 'Muhammad Ghufran', 'LA1': '4', 'LA2': '6', 'LA3': '3', 'LA4': '5'}
# {'Reg': '2018-MC-09', 'Name': 'Taimoor Sikandar', 'LA1': '2', 'LA2': '6', 'LA3': '5', 'LA4': '4'}
# {'Reg': '2018-MC-10', 'Name': 'Muhammad Moadib Nasir', 'LA1': '3.5', 'LA2': '3', 'LA3': '3', 'LA4': '3'}
# {'Reg': '2018-MC-11', 'Name': 'Sheikh Osama Fazal', 'LA1': '2', 'LA2': '2', 'LA3': '1', 'LA4': 'A'}
# {'Reg': '2018-MC-12', 'Name': 'Roshaan Sajjad', 'LA1': '4', 'LA2': '5', 'LA3': '5', 'LA4': '4'}
# {'Reg': '2018-MC-13', 'Name': 'Muhammad Awais Akhter', 'LA1': '3', 'LA2': '6.5', 'LA3': '3', 'LA4': '3'}
# {'Reg': '2018-MC-14', 'Name': 'Muhammad Kazim Raza', 'LA1': '3', 'LA2': '5', 'LA3': '2', 'LA4': '1'}
# {'Reg': '2018-MC-15', 'Name': 'Omar Ashraf', 'LA1': 'A', 'LA2': '5', 'LA3': '2', 'LA4': '5'}
# {'Reg': '2018-MC-16', 'Name': 'Muhammad Asaad', 'LA1': '3.5', 'LA2': '5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-17', 'Name': 'Abdul Majid', 'LA1': '3.5', 'LA2': '3', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-18', 'Name': 'Muhammad Awais', 'LA1': '1.5', 'LA2': 'A', 'LA3': '1', 'LA4': '3'}
# {'Reg': '2018-MC-19', 'Name': 'Muhammad Ali Hadir', 'LA1': '4', 'LA2': '4.5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-20', 'Name': 'Jahanzaib Aslam', 'LA1': '2.5', 'LA2': '3', 'LA3': '0', 'LA4': '3.5'}
# {'Reg': '2018-MC-21', 'Name': 'Muhammad Ibtisam Umer', 'LA1': '4', 'LA2': '3.5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-22', 'Name': 'Tufail Hussain', 'LA1': '3', 'LA2': '6.5', 'LA3': '2', 'LA4': '0'}
# {'Reg': '2018-MC-23', 'Name': 'M Atif Riaz', 'LA1': '4.5', 'LA2': '6', 'LA3': '3', 'LA4': '4'}
# {'Reg': '2018-MC-24', 'Name': 'Muhammad Abdullah', 'LA1': '3.5', 'LA2': '4', 'LA3': '3', 'LA4': '5'}
# {'Reg': '2018-MC-25', 'Name': 'Ahmad Shaukat', 'LA1': '3.5', 'LA2': '5', 'LA3': '2', 'LA4': '1'}
# {'Reg': '2018-MC-26', 'Name': 'Muhammad Nauman', 'LA1': '5', 'LA2': '6.5', 'LA3': '5', 'LA4': '4'}
# {'Reg': '2018-MC-27', 'Name': 'Hamza Rizwan', 'LA1': '3', 'LA2': '5', 'LA3': '3', 'LA4': '3'}
# {'Reg': '2018-MC-28', 'Name': 'Burhan Azeem', 'LA1': '2', 'LA2': '6.5', 'LA3': '2', 'LA4': '5'}
# {'Reg': '2018-MC-29', 'Name': 'Muhammad Sikander Raheem', 'LA1': '3.5', 'LA2': '4', 'LA3': '5', 'LA4': '4'}
# {'Reg': '2018-MC-30', 'Name': 'Muhammad Abdullah', 'LA1': '3', 'LA2': '6.5', 'LA3': '3', 'LA4': '5'}
# {'Reg': '2018-MC-31', 'Name': 'Mian Ali Haider', 'LA1': '3.5', 'LA2': '6.5', 'LA3': '0', 'LA4': '5'}
# {'Reg': '2018-MC-32', 'Name': 'Muhammad Irfan Saleem', 'LA1': '1', 'LA2': 'A', 'LA3': 'A', 'LA4': '3'}
# {'Reg': '2018-MC-33', 'Name': 'Muhammad Hamza Mushtaq', 'LA1': '4.5', 'LA2': '3.5', 'LA3': '2.5', 'LA4': '3'}
# {'Reg': '2018-MC-34', 'Name': 'Jamshaid Zafar', 'LA1': '4.5', 'LA2': '5.5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-35', 'Name': 'Zamara Batool', 'LA1': '1.5', 'LA2': '5', 'LA3': '3', 'LA4': '4'}
# {'Reg': '2018-MC-36', 'Name': 'Noor Ul Ain', 'LA1': '4', 'LA2': '5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-37', 'Name': 'Farwa Mehmood', 'LA1': '5', 'LA2': '6.5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-38', 'Name': 'Tanzeela Arif', 'LA1': '1', 'LA2': '3.5', 'LA3': '1', 'LA4': '2'}
# {'Reg': '2018-MC-39', 'Name': 'Samra Yousaf', 'LA1': '0', 'LA2': '3.5', 'LA3': '0', 'LA4': '5'}
# {'Reg': '2018-MC-40', 'Name': 'Ayesha Aslam', 'LA1': '2', 'LA2': '5', 'LA3': '3', 'LA4': '4'}
# {'Reg': '2018-MC-41', 'Name': 'Maryum Kainat', 'LA1': '3', 'LA2': '5', 'LA3': '2', 'LA4': '5'}
# {'Reg': '2018-MC-42', 'Name': 'Hadiqa', 'LA1': '4', 'LA2': '7', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-43', 'Name': 'Iram', 'LA1': '4', 'LA2': '3.5', 'LA3': '1', 'LA4': '2'}
# {'Reg': '2018-MC-44', 'Name': 'Rida Fatima', 'LA1': '4.5', 'LA2': '4', 'LA3': '3', 'LA4': '5'}
# {'Reg': '2018-MC-45', 'Name': 'Mahesh Sharma', 'LA1': '2.5', 'LA2': '2.5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-46', 'Name': 'Faqeeha Khan', 'LA1': '3.5', 'LA2': '3', 'LA3': '0', 'LA4': '2'}
# {'Reg': '2018-R/2017-MC-29', 'Name': 'Abdul Manan', 'LA1': '1.5', 'LA2': '6.5', 'LA3': '0', 'LA4': '2'}
# {'Reg': '2018-R/2017-MC-36', 'Name': 'Hafiz M. Waleed Shoaib', 'LA1': '2', 'LA2': '3.5', 'LA3': '2', 'LA4': '1'}
# {'Reg': '2018-R/2017-MC-37', 'Name': 'Ikram Khan', 'LA1': 'A', 'LA2': 'A', 'LA3': '1', 'LA4': '0'}
# {'Reg': '2018-MC-51', 'Name': 'Danish', 'LA1': '4.5', 'LA2': '7', 'LA3': '3', 'LA4': '5'}
# {'Reg': '2018-MC-52', 'Name': 'Hafiz Muhammad Aqib Ali', 'LA1': '4.5', 'LA2': '3.5', 'LA3': '2', 'LA4': '4.5'}
# {'Reg': '2018-MC-53', 'Name': 'Muhammad Ibrahim', 'LA1': '4', 'LA2': '7', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-54', 'Name': 'Hamayoun Qamar Qureshi', 'LA1': '3', 'LA2': '6.5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-55', 'Name': 'Muhammad Abdul Wahab', 'LA1': '4', 'LA2': '6.5', 'LA3': '3', 'LA4': '2'}
# {'Reg': '2018-MC-56', 'Name': 'Muhammad Ehtisham Zafar', 'LA1': '4', 'LA2': '5.5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-58', 'Name': 'Muhammad Faisal Shahid', 'LA1': '4.5', 'LA2': '7', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-59', 'Name': 'Ahmad Hussain', 'LA1': '5', 'LA2': '7', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-60', 'Name': 'Shahroz Ahmed', 'LA1': '5', 'LA2': '7', 'LA3': '3', 'LA4': '5'}
# {'Reg': '2018-MC-61', 'Name': 'M Sannan Arshad', 'LA1': '4.5', 'LA2': '6.5', 'LA3': '2', 'LA4': '4'}
# {'Reg': '2018-MC-62', 'Name': 'Khaqan Ahmed', 'LA1': '4.5', 'LA2': '6', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-63', 'Name': 'Arbab Khalid', 'LA1': '3.5', 'LA2': '3', 'LA3': '5', 'LA4': '1'}
# {'Reg': '2018-MC-64', 'Name': 'Talha Khan', 'LA1': '4', 'LA2': '5', 'LA3': '0', 'LA4': '3'}
# {'Reg': '2018-MC-65', 'Name': 'Abdul Rehman Baig', 'LA1': '3.5', 'LA2': '5.5', 'LA3': '5', 'LA4': '4'}
# {'Reg': '2018-MC-66', 'Name': 'Muhammad Ammar', 'LA1': '4.5', 'LA2': '7', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-67', 'Name': 'Mohammad Hozefa Saleem', 'LA1': '2.5', 'LA2': '4', 'LA3': '2', 'LA4': '2'}
# {'Reg': '2018-MC-68', 'Name': 'Muhammad Abdullah', 'LA1': '4.5', 'LA2': '2', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-69', 'Name': 'Ali Zaman', 'LA1': '5', 'LA2': '5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-70', 'Name': 'Syed Waqar Haider Bukhari', 'LA1': '2.5', 'LA2': '3', 'LA3': '4', 'LA4': '2'}
# {'Reg': '2018-MC-72', 'Name': 'Mian M.Husnain Akram', 'LA1': '5', 'LA2': '7', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-73', 'Name': 'Shahzad Niaz', 'LA1': '4.5', 'LA2': '7', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-74', 'Name': 'Waleed Bin Qaisar', 'LA1': '4', 'LA2': '6.5', 'LA3': '5', 'LA4': '4'}
# {'Reg': '2018-MC-75', 'Name': 'Huzaifa Imtiaz', 'LA1': '4', 'LA2': '6', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-76', 'Name': 'Ibtisam Ul Hassan', 'LA1': '4', 'LA2': '7', 'LA3': 'A', 'LA4': '3'}
# {'Reg': '2018-MC-77', 'Name': 'Muhammad Usman Ghani', 'LA1': '3.5', 'LA2': '6', 'LA3': '3', 'LA4': '5'}
# {'Reg': '2018-MC-78', 'Name': 'Aurang Zaib Younis Virk', 'LA1': '4.5', 'LA2': '6.5', 'LA3': '5', 'LA4': '3'}
# {'Reg': '2018-MC-79', 'Name': 'Hassan Abdul Basit', 'LA1': '4.5', 'LA2': '6', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-80', 'Name': 'Taimoor Ahmed Pal', 'LA1': '5', 'LA2': '7', 'LA3': '5', 'LA4': '4'}
# {'Reg': '2018-MC-81', 'Name': 'Hafiz Muhammad Usman Ahmed', 'LA1': '5', 'LA2': '6.5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-82', 'Name': 'Tayyab Rasheed', 'LA1': '3.5', 'LA2': '5.5', 'LA3': '3', 'LA4': '3'}
# {'Reg': '2018-MC-83', 'Name': 'Usama Iqbal', 'LA1': '5', 'LA2': '6.5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-84', 'Name': 'Ahtesham Zafar', 'LA1': '1.5', 'LA2': '4.5', 'LA3': '5', 'LA4': '3'}
# {'Reg': '2018-MC-85', 'Name': 'Assad Ali', 'LA1': '3.5', 'LA2': '1.5', 'LA3': '5', 'LA4': '0'}
# {'Reg': '2018-MC-86', 'Name': 'Mazhar Mustafa', 'LA1': '2', 'LA2': '5.5', 'LA3': '4', 'LA4': '2'}
# {'Reg': '2018-MC-87', 'Name': 'Muhammad Muneeb Irfan Mughal', 'LA1': '4.5', 'LA2': '6', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-88', 'Name': 'Abdul Rehman', 'LA1': '4.5', 'LA2': '7', 'LA3': '5', 'LA4': '3'}
# {'Reg': '2018-MC-89', 'Name': 'Syeda Tayyaba Bukhari', 'LA1': '5', 'LA2': '6.5', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-90', 'Name': 'Maheen Abdul Ghani', 'LA1': '5', 'LA2': '6', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-91', 'Name': 'Faryal Nasir', 'LA1': '3.5', 'LA2': '7', 'LA3': '2', 'LA4': '5'}
# {'Reg': '2018-MC-92', 'Name': 'Ayesha Nadeem', 'LA1': '3', 'LA2': '3', 'LA3': '5', 'LA4': '3'}
# {'Reg': '2018-MC-93', 'Name': 'Aqsa Amjad', 'LA1': '5', 'LA2': '5.5', 'LA3': '5', 'LA4': '3'}
# {'Reg': '2018-MC-94', 'Name': 'Arfa Nisar', 'LA1': '4.5', 'LA2': '7', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-95', 'Name': 'Iqra Amjad', 'LA1': '5', 'LA2': '7', 'LA3': '5', 'LA4': '5'}
# {'Reg': '2018-MC-96', 'Name': 'Noor Fatima', 'LA1': '3', 'LA2': '7', 'LA3': '5', 'LA4': 'A'}
# {'Reg': '2018-R/2017-MC-47', 'Name': 'Muhammad Abdullah', 'LA1': '5', 'LA2': '6', 'LA3': '0', 'LA4': '4'}
# {'Reg': '2018-R/2017-MC-77', 'Name': 'Muhammad Faseeh Bin Naeem', 'LA1': '4', 'LA2': '5', 'LA3': '2', 'LA4': '5'}
# {'Reg': '2018-R/2017-MC-103', 'Name': 'Jehanzeb Hussain', 'LA1': 'A', 'LA2': '4', 'LA3': '5', 'LA4': 'A'}

# %%
#writing into csv file
a={'Reg': '2018-R/2017-MC-104', 'Name': 'Lokesha P', 'LA1': '3.5', 'LA2': '4', 'LA3': '5', 'LA4': '4'}
with open('marks.csv','w',newline='') as f:
    w=csv.DictWriter(f,fieldnames=a.keys())
    w.writeheader() # keys values are displayes as header in the file
    w.writerow(a)

# %%
# READING CSV FILES
import csv
csv_filename = 'OlympicMedals_2020.csv'
with open(csv_filename, encoding='utf-8', newline='') as csv_file:
    headers = csv_file.readline().strip('\n').split(',') # for getting header
    print(f'Column headers: {headers}')
    reader = csv.reader(csv_file)
    for row in reader:
        print(row)
# Out:
# Column headers: ['Rank', 'Country', 'Gold', 'Silver', 'Bronze', 'Total']
# ['1', 'United States', '39', '41', '33', '113']
# ['2', 'China', '38', '32', '18', '88']
# ['3', 'Japan', '27', '14', '17', '58']
# ['4', 'Great Britain', '22', '21', '22', '65']
# ['5', 'ROC', '20', '28', '23', '71']
# ['6', 'Australia', '17', '7', '22', '46']
# ['7', 'Netherlands', '10', '12', '14', '36']
# ['8', 'France', '10', '12', '11', '33']
# ['9', 'Germany', '10', '11', '16', '37']
# ['10', 'Italy', '10', '10', '20', '40']
# ['11', 'Canada', '7', '6', '11', '24']
# ['12', 'Brazil', '7', '6', '8', '21']
# ['13', 'New Zealand', '7', '6', '7', '20']
# ['14', 'Cuba', '7', '3', '5', '15']
# ['15', 'Hungary', '6', '7', '7', '20']
# ['16', 'South Korea', '6', '4', '10', '20']
# ['17', 'Poland', '4', '5', '5', '14']
# ['18', 'Czech Republic', '4', '4', '3', '11']
# ['19', 'Kenya', '4', '4', '2', '10']
# ['20', 'Norway', '4', '2', '2', '8']
# ['21', 'Jamaica', '4', '1', '4', '9']
# ['22', 'Spain', '3', '8', '6', '17']
# ['23', 'Sweden', '3', '6', '0', '9']
# ['24', 'Switzerland', '3', '4', '6', '13']
# ['25', 'Denmark', '3', '4', '4', '11']
# ['26', 'Croatia', '3', '3', '2', '8']
# ['27', 'Iran', '3', '2', '2', '7']
# ['28', 'Serbia', '3', '1', '5', '9']
# ['29', 'Belgium', '3', '1', '3', '7']
# ['30', 'Bulgaria', '3', '1', '2', '6']
# ['31', 'Slovenia', '3', '1', '1', '5']
# ['32', 'Uzbekistan', '3', '0', '2', '5']
# ['33', 'Georgia', '2', '5', '1', '8']
# ['34', 'Chinese Taipei', '2', '4', '6', '12']
# ['35', 'Turkey', '2', '2', '9', '13']
# ['36', 'Greece', '2', '1', '1', '4']
# ['36', 'Uganda', '2', '1', '1', '4']
# ['38', 'Ecuador', '2', '1', '0', '3']
# ['39', 'Ireland', '2', '0', '2', '4']
# ['39', 'Israel', '2', '0', '2', '4']
# ['41', 'Qatar', '2', '0', '1', '3']
# ['42', 'Bahamas', '2', '0', '0', '2']
# ['42', 'Kosovo', '2', '0', '0', '2']
# ['44', 'Ukraine', '1', '6', '12', '19']
# ['45', 'Belarus', '1', '3', '3', '7']
# ['46', 'Romania', '1', '3', '0', '4']
# ['46', 'Venezuela', '1', '3', '0', '4']
# ['48', 'India', '1', '2', '4', '7']
# ['49', 'Hong Kong', '1', '2', '3', '6']
# ['50', 'Philippines', '1', '2', '1', '4']
# ['50', 'Slovakia', '1', '2', '1', '4']
# ['52', 'South Africa', '1', '2', '0', '3']
# ['53', 'Austria', '1', '1', '5', '7']
# ['54', 'Egypt', '1', '1', '4', '6']
# ['55', 'Indonesia', '1', '1', '3', '5']
# ['56', 'Ethiopia', '1', '1', '2', '4']
# ['56', 'Portugal', '1', '1', '2', '4']
# ['58', 'Tunisia', '1', '1', '0', '2']
# ['59', 'Estonia', '1', '0', '1', '2']
# ['59', 'Fiji', '1', '0', '1', '2']
# ['59', 'Latvia', '1', '0', '1', '2']
# ['59', 'Thailand', '1', '0', '1', '2']
# ['63', 'Bermuda', '1', '0', '0', '1']
# ['63', 'Morocco', '1', '0', '0', '1']
# ['63', 'Puerto Rico', '1', '0', '0', '1']
# ['66', 'Colombia', '0', '4', '1', '5']
# ['67', 'Azerbaijan', '0', '3', '4', '7']
# ['68', 'Dominican Republic', '0', '3', '2', '5']
# ['69', 'Armenia', '0', '2', '2', '4']
# ['70', 'Kyrgyzstan', '0', '2', '1', '3']
# ['71', 'Mongolia', '0', '1', '3', '4']
# ['72', 'Argentina', '0', '1', '2', '3']
# ['72', 'San Marino', '0', '1', '2', '3']
# ['74', 'Jordan', '0', '1', '1', '2']
# ['74', 'Malaysia', '0', '1', '1', '2']
# ['74', 'Nigeria', '0', '1', '1', '2']
# ['77', 'Bahrain', '0', '1', '0', '1']
# ['77', 'Saudi Arabia', '0', '1', '0', '1']
# ['77', 'Lithuania', '0', '1', '0', '1']
# ['77', 'North Macedonia', '0', '1', '0', '1']
# ['77', 'Namibia', '0', '1', '0', '1']
# ['77', 'Turkmenistan', '0', '1', '0', '1']
# ['83', 'Kazakhstan', '0', '0', '8', '8']
# ['84', 'Mexico', '0', '0', '4', '4']
# ['85', 'Finland', '0', '0', '2', '2']
# ['86', 'Botswana', '0', '0', '1', '1']
# ['86', 'Burkina Faso', '0', '0', '1', '1']
# ['86', "Côte d'Ivoire", '0', '0', '1', '1']
# ['86', 'Ghana', '0', '0', '1', '1']
# ['86', 'Grenada', '0', '0', '1', '1']
# ['86', 'Kuwait', '0', '0', '1', '1']
# ['86', 'Moldova', '0', '0', '1', '1']
# ['86', 'Syria', '0', '0', '1', '1']

# %%
# quating in csv files ==>here numerical values in the form of string type so we need to make it as numerical
import csv
csv_filename = 'cereal_grains.csv'
with open(csv_filename, encoding='utf-8', newline='') as csv_file:
    reader = csv.reader(csv_file, quoting=csv.QUOTE_NONNUMERIC) # converting to numerical value
    for row in reader:
        print(row)
# Out:
# ['Cereal', 'Calories', 'Fat', 'Protein', 'Fibre', 'Vitamin E']
# ['Barley', 556.0, 1.7, 32.9, 10.1, 13.8]
# ['Durum', 339.0, 5.0, 27.4, 4.09, 9.7]
# ['Fonio', 240.0, 1.0, 4.0, 1.7, 0.05]
# ['Maize', 442.0, 7.4, 37.45, 6.15, 11.03]
# ['Millet', 484.0, 2.0, 37.9, 13.4, 9.15]
# ['Oats', 231.0, 9.2, 35.1, 10.3, 3.73]
# ['Rice (Brown)', 346.0, 2.8, 38.1, 9.9, 0.8]
# ['Rice (White)', 345.0, 3.6, 37.6, 5.4, 0.1]
# ['Rye', 422.0, 2.0, 31.4, 18.2, 21.2]
# ['Sorghum', 316.0, 3.0, 37.8, 9.92, 9.15]
# ['Triticale', 338.0, 1.81, 36.6, 19.0, 0.9]
# ['Wheat', 407.0, 1.2, 27.8, 12.9, 13.8]

# %%
# sniffer and dialect in csv files ( in text file we have pipe for ecach values so we need to convert this text to csv by sciffer and dielect)
import csv
input_filename = 'country_info.txt'
with open(input_filename, encoding='utf-8', newline='') as countries_data:
    sample = ""
    for line in range(3):
        sample += countries_data.readline()
    country_dialect = csv.Sniffer().sniff(sample)
    countries_data.seek(0)
    country_reader = csv.reader(countries_data, dialect=country_dialect)
    for row in country_reader:
        print(row)
# 4 to 6 not neccesory
# Out:
# ['Country', 'Capital', 'CC', 'CC3', 'IAC', 'TimeZone', 'Currency']
# ['Afghanistan', 'Kabul', 'AF', 'AFG', '+93', 'UTC+04:30', 'Afghan afghani']
# ['Aland Islands', 'Mariehamn', 'AX', 'ALA', '+358', 'UTC+02:00', 'Euro']
# ['Albania', 'Tirana', 'AL', 'ALB', '+355', 'UTC+01:00', 'Albanian lek']
# ['Algeria', 'Algiers', 'DZ', 'DZA', '+213', 'UTC', 'Algerian dinar']
# ['American Samoa', 'Pago Pago', 'AS', 'ASM', '+1 684', 'UTC-11:00', '']
# ['Andorra', 'Andorra la Vella', 'AD', 'AND', '+376', 'UTC+01:00', 'Euro']
# ['Angola', 'Luanda', 'AO', 'AGO', '+244', 'UTC+01:00', 'Angolan kwanza']
# ['Anguilla', 'The Valley', 'AI', 'AIA', '+1 264', 'UTC-04:00', 'East Caribbean dollar']
# ['Antarctica', '', 'AQ', 'ATA', '', '', '']
# ['Antigua and Barbuda', "St. John's", 'AG', 'ATG', '+1 268', 'UTC-04:00', 'East Caribbean dollar']
# ['Argentina', 'Buenos Aires', 'AR', 'ARG', '+54', 'UTC-03:00', 'Argentine peso']
# ['Armenia', 'Yerevan', 'AM', 'ARM', '+374', 'UTC+04:00', 'Armenian dram']
# ['Aruba', 'Oranjestad', 'AW', 'ABW', '+297', 'UTC-04:00', 'Aruban florin']
# ['Australia', 'Canberra', 'AU', 'AUS', '+61', 'UTC+07:00 - UTC+10:00', 'Australian dollar']
# ['Austria', 'Vienna', 'AT', 'AUT', '+43', 'UTC+01:00', 'Euro']
# ['Azerbaijan', 'Baku', 'AZ', 'AZE', '+994', 'UTC+04:00', 'Azerbaijani manat']
# ['Bahamas', 'Nassau', 'BS', 'BHS', '+1 242', 'UTC-05:00', 'Bahamian dollar']
# ['Bahrain', 'Manama', 'BH', 'BHR', '+973', 'UTC+03:00', 'Bahraini dinar']
# ['Bangladesh', 'Dhaka', 'BD', 'BGD', '+880', 'UTC+06:00', 'Bangladeshi taka']
# ['Barbados', 'Bridgetown', 'BB', 'BRB', '+1 246', 'UTC-04:00', 'Barbadian dollar']
# ['Belarus', 'Minsk', 'BY', 'BLR', '+375', 'UTC+03:00', 'Belarusian ruble']
# ['Belgium', 'Brussels', 'BE', 'BEL', '+32', 'UTC+01:00', 'Euro']
# ['Belize', 'Belmopan', 'BZ', 'BLZ', '+501', 'UTC-06:00', 'Belize dollar']
# ['Benin', 'Porto-Novo', 'BJ', 'BEN', '+229', 'UTC+01:00', 'West African CFA franc']
# ['Bermuda', 'Hamilton', 'BM', 'BMU', '+1 441', 'UTC-04:00', 'Bermudian dollar']
# ['Bhutan', 'Thimphu', 'BT', 'BTN', '+975', 'UTC+05:30', 'Bhutanese ngultrum']
# ['Bolivia', 'Sucre', 'BO', 'BOL', '+591', 'UTC-04:00', 'Bolivian boliviano']
# ['Bonaire', 'Kralendijk', 'BQ', 'BES', '+599', 'UTC-04:00', 'United States dollar']
# ['Bosnia and Herzegovina', 'Sarajevo', 'BA', 'BIH', '+387', 'UTC+01:00', 'Bosnia and Herzegovina convertible mark']
# ['Botswana', 'Gaborone', 'BW', 'BWA', '+267', 'UTC+02:00', 'Botswana pula']
# ['Bouvet Island', '', 'BV', 'BVT', '', 'UTC+01:00', '']
# ['Brazil', 'Brasília', 'BR', 'BRA', '+55', 'UTC-05:00 - UTC-03:00', 'Brazilian real']
# ['British Indian Ocean Territory', 'Diego Garcia', 'IO', 'IOT', '+246', 'UTC+06', 'United States dollar']
# ['Brunei', 'Bandar Seri Begawan', 'BN', 'BRN', '+673', 'UTC+08:00', 'Brunei dollar']
# ['Bulgaria', 'Sofia', 'BG', 'BGR', '+359', 'UTC+02:00', 'Bulgarian lev']
# ['Burkina Faso', 'Ouagadougou', 'BF', 'BFA', '+226', 'UTC', 'West African CFA franc']
# ['Burundi', 'Bujumbura', 'BI', 'BDI', '+257', 'UTC+02:00', 'Burundian franc']
# ['Cambodia', 'Phnom Penh', 'KH', 'KHM', '+855', 'UTC+07:00', 'Cambodian riel']
# ['Cameroon', 'Yaoundé', 'CM', 'CMR', '+237', 'UTC+01:00', 'Central African CFA franc']
# ['Canada', 'Ottawa', 'CA', 'CAN', '+1', 'UTC-08:00 - UTC-04:00', 'Canadian dollar']
# ['Cape Verde', 'Praia', 'CV', 'CPV', '+238', 'UTC-01:00', 'Cape Verdean escudo']
# ['Cayman Islands', 'George Town', 'KY', 'CYM', '+1 345', 'UTC-05:00', 'Cayman Islands dollar']
# ['Central African Republic', 'Bangui', 'CF', 'CAF', '+236', 'UTC+01:00', 'Central African CFA franc']
# ['Chad', "N'Djamena", 'TD', 'TCD', '+235', 'UTC+01:00', 'Central African CFA franc']
# ['Chile', 'Santiago', 'CL', 'CHL', '+56', 'UTC-04:00', 'Chilean peso']
# ['China', 'Beijing', 'CN', 'CHN', '+86', 'UTC+08:00', 'Chinese yuan']
# ['Christmas Island', 'Flying Fish Cove', 'CX', 'CXR', '+61 8 9164', 'UTC+07', 'Australian dollar']
# ['Cocos (Keeling) Islands', 'West Island', 'CC', 'CCK', '+61 8 9162', 'UTC+06:30', 'Australian dollar']
# ['Colombia', 'Bogotá', 'CO', 'COL', '+57', 'UTC-05:00', 'Colombian peso']
# ['Comoros', 'Moroni', 'KM', 'COM', '+269', 'UTC+03:00', 'Comorian franc']
# ['Congo, Republic of the', 'Brazzaville', 'CG', 'COG', '+242', 'UTC+01:00', 'Central African CFA franc']
# ['Congo, Democratic Republic of the', 'Kinshasa', 'CD', 'COD', '+243', 'UTC+01:00 - UTC+02:00', 'Congolese franc']
# ['Cook Islands', 'Avarua', 'CK', 'COK', '+682', 'UTC-10:00', 'New Zealand dollar']
# ['Costa Rica', 'San José', 'CR', 'CRI', '+506', 'UTC-06:00', 'Costa Rican colón']
# ["Côte d'Ivoire", 'Yamoussoukro', 'CI', 'CIV', '+225', 'UTC', 'West African CFA franc']
# ['Croatia', 'Zagreb', 'HR', 'HRV', '+385', 'UTC+01:00', 'Croatian kuna']
# ['Cuba', 'Havana', 'CU', 'CUB', '+53', 'UTC-03:00', 'Cuban convertible peso']
# ['Curacao', 'Willemstad', 'CW', 'CUW', '+599 9', 'UTC-04:00', 'Netherlands Antillean guilder']
# ['Cyprus', 'Nicosia', 'CY', 'CYP', '+357', 'UTC+02:00', 'Euro']
# ['Czech Republic', 'Prague', 'CZ', 'CZE', '+420', 'UTC+01:00', 'Czech koruna']
# ['Denmark', 'Copenhagen', 'DK', 'DNK', '+45', 'UTC+01:00', 'Danish krone']
# ['Djibouti', 'Djibouti', 'DJ', 'DJI', '+253', 'UTC+03:00', 'Djiboutian franc']
# ['Dominica', 'Roseau', 'DM', 'DMA', '+1 767', 'UTC-04:00', 'East Caribbean dollar']
# ['Dominican Republic', 'Santo Domingo', 'DO', 'DOM', '+1 809/829/849', 'UTC-04:00', 'Dominican peso']
# ['East Timor', 'Dili', 'TL', 'TLS', '+670', 'UTC+09', 'United States dollar']
# ['Ecuador', 'Quito', 'EC', 'ECU', '+593', 'UTC-05:00', 'United States dollar']
# ['Egypt', 'Cairo', 'EG', 'EGY', '+20', 'UTC+02:00', 'Egyptian pound']
# ['El Salvador', 'San Salvador', 'SV', 'SLV', '+503', 'UTC-06:00', 'Salvadoran colón']
# ['Equatorial Guinea', 'Malabo', 'GQ', 'GNQ', '+240', 'UTC+01:00', 'Central African CFA franc']
# ['Eritrea', 'Asmara', 'ER', 'ERI', '+291', 'UTC+03:00', 'Eritrean nakfa']
# ['Estonia', 'Tallinn', 'EE', 'EST', '+372', 'UTC+03:00', 'Euro']
# ['Ethiopia', 'Addis Ababa', 'ET', 'ETH', '+251', 'UTC+03:00', 'Ethiopian birr']
# ['Falkland Islands (Malvinas)', 'Stanley', 'FK', 'FLK', '+500', 'UTC-04:00', 'Falkland Islands pound']
# ['Faroe Islands', 'Tórshavn', 'FO', 'FRO', '+298', 'UTC', 'Danish krone']
# ['Fiji', 'Suva', 'FJ', 'FJI', '+679', 'UTC+12:00', 'Fijian dollar']
# ['Finland', 'Helsinki', 'FI', 'FIN', '+358', 'UTC+02:00', 'Euro']
# ['France', 'Paris', 'FR', 'FRA', '+33', 'UTC+01:00', 'Euro']
# ['French Guiana', 'Cayenne', 'GF', 'GUF', '+594', 'UTC-01:00', 'Euro']
# ['French Polynesia', 'Papeete', 'PF', 'PYF', '+689', 'UTC-10:00', 'CFP franc']
# ['French Southern Territories', 'Port-aux-Français', 'TF', 'ATF', '', 'UTC+05:00', 'Euro']
# ['Gabon', 'Libreville', 'GA', 'GAB', '+241', 'UTC+01:00', 'Central African CFA franc']
# ['Gambia', 'Banjul', 'GM', 'GMB', '+220', 'UTC', 'Gambian dalasi']
# ['Georgia', 'Tbilisi', 'GE', 'GEO', '+995', 'UTC+04:00', 'Georgian lari']
# ['Germany', 'Berlin', 'DE', 'DEU', '+49', 'UTC+01:00', 'Euro']
# ['Ghana', 'Accra', 'GH', 'GHA', '+233', 'UTC', 'Ghanaian cedi']
# ['Gibraltar', 'Gibraltar', 'GI', 'GIB', '+350', 'UTC+01:00', 'Gibraltar pound']
# ['Greece', 'Athens', 'GR', 'GRC', '+30', 'UTC+02:00', 'Euro']
# ['Greenland', 'Nuuk', 'GL', 'GRL', '+299', 'UTC-03:00', 'Danish krone']
# ['Grenada', "St. George's", 'GD', 'GRD', '+1 473', 'UTC-04:00', 'East Caribbean dollar']
# ['Guadeloupe', 'Basse-Terre', 'GP', 'GLP', '+590', 'UTC-04:00', 'Euro']
# ['Guam', 'Hagåtña', 'GU', 'GUM', '+1 671', 'UTC+10:00', 'United States dollar']
# ['Guatemala', 'Guatemala City', 'GT', 'GTM', '+502', 'UTC-06:00', 'Guatemalan quetzal']
# ['Guernsey', 'St. Peter Port', 'GG', 'GGY', '+44 1481', 'UTC', 'British pound']
# ['Guinea', 'Conakry', 'GN', 'GIN', '+224', 'UTC', 'Guinean franc']
# ['Guinea-Bissau', 'Bissau', 'GW', 'GNB', '+245', 'UTC', 'West African CFA franc']
# ['Guyana', 'Georgetown', 'GY', 'GUY', '+592', 'UTC-03:00', 'Guyanese dollar']
# ['Haiti', 'Port-au-Prince', 'HT', 'HTI', '+509', 'UTC-05:00', 'Haitian gourde']
# ['Heard Island and McDonald Islands', '', 'HM', 'HMD', '', 'UTC+05', '']
# ['Honduras', 'Tegucigalpa', 'HN', 'HND', '+504', 'UTC-06:00', 'Honduran lempira']
# ['Hong Kong', '', 'HK', 'HKG', '+852', 'UTC+08:00', 'Hong Kong dollar']
# ['Hungary', 'Budapest', 'HU', 'HUN', '+36', 'UTC+01:00', 'Hungarian forint']
# ['Iceland', 'Reykjavík', 'IS', 'ISL', '+354', 'UTC', 'Icelandic króna']
# ['India', 'New Delhi', 'IN', 'IND', '+91', 'UTC+05:30', 'Indian rupee']
# ['Indonesia', 'Jakarta', 'ID', 'IDN', '+62', 'UTC+07:00 - UTC+09:00', 'Indonesian rupiah']
# ['Iran', 'Tehran', 'IR', 'IRN', '+98', 'UTC+03:30', 'Iranian rial']
# ['Iraq', 'Baghdad', 'IQ', 'IRQ', '+964', 'UTC+03:00', 'Iraqi dinar']
# ['Ireland', 'Dublin', 'IE', 'IRL', '+353', 'UTC', 'Euro']
# ['Isle of Man', 'Douglas', 'IM', 'IMN', '+44 1624', 'UTC', 'British pound']
# ['Israel', 'Jerusalem', 'IL', 'ISR', '+972', 'UTC+02:00', 'Israeli new shekel']
# ['Italy', 'Rome', 'IT', 'ITA', '+39', 'UTC+01:00', 'Euro']
# ['Jamaica', 'Kingston', 'JM', 'JAM', '+1 876', 'UTC-05:00', 'Jamaican dollar']
# ['Japan', 'Tokyo', 'JP', 'JPN', '+81', 'UTC+09:00', 'Japanese yen']
# ['Jersey', 'St. Helier', 'JE', 'JEY', '+44 1534', 'UTC', 'British pound']
# ['Jordan', 'Amman', 'JO', 'JOR', '+962', 'UTC+02:00', 'Jordanian dinar']
# ['Kazakhstan', 'Astana', 'KZ', 'KAZ', '+7 6xx/7xx', 'UTC+06:00', 'Kazakhstani tenge']
# ['Kenya', 'Nairobi', 'KE', 'KEN', '+254', 'UTC+03:00', 'Kenyan shilling']
# ['Kiribati', 'Tarawa', 'KI', 'KIR', '+686', 'UTC+12:00', 'Australian dollar']
# ['Kuwait', 'Kuwait City', 'KW', 'KWT', '+965', 'UTC+03:00', 'Kuwaiti dinar']
# ['Kyrgyzstan', 'Bishkek', 'KG', 'KGZ', '+996', 'UTC+06:00', 'Kyrgyzstani som']
# ['Laos', 'Vientiane', 'LA', 'LAO', '+856', 'UTC+07:00', 'Lao kip']
# ['Latvia', 'Riga', 'LV', 'LVA', '+371', 'UTC+03:00', 'Latvian lats']
# ['Lebanon', 'Beirut', 'LB', 'LBN', '+961', 'UTC+02:00', 'Lebanese pound']
# ['Lesotho', 'Maseru', 'LS', 'LSO', '+266', 'UTC+02:00', 'Lesotho loti']
# ['Liberia', 'Monrovia', 'LR', 'LBR', '+231', 'UTC', 'Liberian dollar']
# ['Libya', 'Tripoli', 'LY', 'LBY', '+218', 'UTC+02:00', 'Libyan dinar']
# ['Liechtenstein', 'Vaduz', 'LI', 'LIE', '+423', 'UTC+01:00', 'Swiss franc']
# ['Lithuania', 'Vilnius', 'LT', 'LTU', '+370', 'UTC+02:00', 'Lithuanian litas']
# ['Luxembourg', 'Luxembourg', 'LU', 'LUX', '+352', 'UTC+01:00', 'Euro']
# ['Macau', '', 'MO', 'MAC', '+853', 'UTC+08:00', 'Macanese pataca']
# ['Macedonia', 'Skopje', 'MK', 'MKD', '+389', 'UTC+01:00', 'Macedonian denar']
# ['Madagascar', 'Antananarivo', 'MG', 'MDG', '+261', 'UTC+03:00', 'Malagasy ariary']
# ['Malawi', 'Lilongwe', 'MW', 'MWI', '+265', 'UTC+02:00', 'Malawian kwacha']
# ['Malaysia', 'Kuala Lumpur', 'MY', 'MYS', '+60', 'UTC+08:00', 'Malaysian ringgit']
# ['Maldives', 'Malé', 'MV', 'MDV', '+960', 'UTC+05:00', 'Maldivian rufiyaa']
# ['Mali', 'Bamako', 'ML', 'MLI', '+223', 'UTC', 'West African CFA franc']
# ['Malta', 'Valletta', 'MT', 'MLT', '+356', 'UTC+01:00', 'Euro']
# ['Marshall Islands', 'Majuro', 'MH', 'MHL', '+692', 'UTC+10:00', 'United States dollar']
# ['Martinique', 'Fort-de-France', 'MQ', 'MTQ', '+596', 'UTC-04:00', 'Euro']
# ['Mauritania', 'Nouakchott', 'MR', 'MRT', '+222', 'UTC', 'Mauritanian ouguiya']
# ['Mauritius', 'Port Louis', 'MU', 'MUS', '+230', 'UTC+04:00', 'Mauritian rupee']
# ['Mayotte', 'Mamoudzou', 'YT', 'MYT', '+262 269/639', 'UTC+03:00', 'Euro']
# ['Mexico', 'Mexico City', 'MX', 'MEX', '+52', 'UTC-08:00 - UTC-06:00', 'Mexican peso']
# ['Micronesia', 'Palikir', 'FM', 'FSM', '+691', 'UTC+10:00', 'Micronesian dollar']
# ['Moldova', 'Chisinau', 'MD', 'MDA', '+373', 'UTC+03:00', 'Moldovan leu']
# ['Monaco', 'Monaco', 'MC', 'MCO', '+377', 'UTC+01:00', 'Euro']
# ['Mongolia', 'Ulaanbaatar', 'MN', 'MNG', '+976', 'UTC+08:00', 'Mongolian tögrög']
# ['Montenegro', 'Podgorica', 'ME', 'MNE', '+382', 'UTC+01', 'Euro']
# ['Montserrat', 'Plymouth', 'MS', 'MSR', '+1 664', 'UTC-04:00', 'East Caribbean dollar']
# ['Morocco', 'Rabat', 'MA', 'MAR', '+212', 'UTC', 'Moroccan dirham']
# ['Mozambique', 'Maputo', 'MZ', 'MOZ', '+258', 'UTC+02:00', 'Mozambican metical']
# ['Myanmar (Burma)', 'Naypyidaw', 'MM', 'MMR', '+95', 'UTC+06:30', 'Myanma kyat']
# ['Namibia', 'Windhoek', 'NA', 'NAM', '+264', 'UTC+02:00', 'Namibian dollar']
# ['Nauru', 'Yaren', 'NR', 'NRU', '+674', 'UTC+12:00', 'Australian dollar']
# ['Nepal', 'Kathmandu', 'NP', 'NPL', '+977', 'UTC+05:30', 'Nepalese rupee']
# ['Netherlands', 'Amsterdam', 'NL', 'NLD', '+31', 'UTC+01:00', 'Euro']
# ['New Caledonia', 'Nouméa', 'NC', 'NCL', '+687', 'UTC+11:00', 'CFP franc']
# ['New Zealand', 'Wellington', 'NZ', 'NZL', '+64', 'UTC+12:00', 'New Zealand dollar']
# ['Nicaragua', 'Managua', 'NI', 'NIC', '+505', 'UTC-06:00', 'Nicaraguan córdoba']
# ['Niger', 'Niamey', 'NE', 'NER', '+227', 'UTC+01:00', 'West African CFA franc']
# ['Nigeria', 'Abuja', 'NG', 'NGA', '+234', 'UTC+01:00', 'Nigerian naira']
# ['Niue', 'Alofi', 'NU', 'NIU', '+683', 'UTC-11:00', 'New Zealand dollar']
# ['Norfolk Island', 'Kingston', 'NF', 'NFK', '+672 3', 'UTC+11:30', 'Australian dollar']
# ['North Korea', 'Pyongyang', 'KP', 'PRK', '+850', 'UTC+09:00', 'North Korean won']
# ['Northern Mariana Islands', 'Saipan', 'MP', 'MNP', '+1 670', 'UTC+10:00', 'United States dollar']
# ['Norway', 'Oslo', 'NO', 'NOR', '+47', 'UTC+01:00', 'Norwegian krone']
# ['Oman', 'Muscat', 'OM', 'OMN', '+968', 'UTC+04:00', 'Omani rial']
# ['Pakistan', 'Islamabad', 'PK', 'PAK', '+92', 'UTC+05:00', 'Pakistani rupee']
# ['Palau', 'Ngerulmud', 'PW', 'PLW', '+680', 'UTC+09:00', 'Palauan dollar']
# ['Panama', 'Panama City', 'PA', 'PAN', '+507', 'UTC-05:00', 'Panamanian balboa']
# ['Papua New Guinea', 'Port Moresby', 'PG', 'PNG', '+675', 'UTC+10:00', 'Papua New Guinean kina']
# ['Paraguay', 'Asunción', 'PY', 'PRY', '+595', 'UTC-04:00', 'Paraguayan guaraní']
# ['Peru', 'Lima', 'PE', 'PER', '+51', 'UTC-05:00', 'Peruvian nuevo sol']
# ['Philippines', 'Manila', 'PH', 'PHL', '+63', 'UTC+08:00', 'Philippine peso']
# ['Pitcairn', 'Adamstown', 'PN', 'PCN', '+872', 'UTC-08', 'New Zealand dollar']
# ['Poland', 'Warsaw', 'PL', 'POL', '+48', 'UTC+01:00', 'Polish złoty']
# ['Portugal', 'Lisbon', 'PT', 'PRT', '+351', 'UTC+01:00', 'Euro']
# ['Puerto Rico', 'San Juan', 'PR', 'PRI', '+1 787/939', 'UTC-04:00', 'United States dollar']
# ['Qatar', 'Doha', 'QA', 'QAT', '+974', 'UTC+03:00', 'Qatari riyal']
# ['Reunion', '', 'RE', 'REU', '+262', 'UTC+04:00', 'Euro']
# ['Romania', 'Bucharest', 'RO', 'ROU', '+40', 'UTC+02:00', 'Romanian leu']
# ['Russia', 'Moscow', 'RU', 'RUS', '+7', 'UTC+03:00', 'Russian ruble']
# ['Rwanda', 'Kigali', 'RW', 'RWA', '+250', 'UTC+02:00', 'Rwandan franc']
# ['Saint Barthelemy', 'Gustavia', 'BL', 'BLM', '+590', 'UTC-04', 'Euro']
# ['Saint Helena', 'Jamestown', 'SH', 'SHN', '+290', 'UTC', 'Saint Helena pound']
# ['Saint Kitts and Nevis', 'Basseterre', 'KN', 'KNA', '+1 869', 'UTC-04:00', 'East Caribbean dollar']
# ['Saint Lucia', 'Castries', 'LC', 'LCA', '+1 758', 'UTC-04:00', 'East Caribbean dollar']
# ['Saint Martin', 'Marigot', 'MF', 'MAF', '+590', 'UTC-04', 'Euro']
# ['Saint Pierre and Miquelon', 'St. Pierre', 'PM', 'SPM', '+508', 'UTC-03', 'Euro']
# ['Saint Vincent and the Grenadines', 'Kingstown', 'VC', 'VCT', '+1 784', 'UTC-04', 'East Caribbean dollar']
# ['Samoa', 'Apia', 'WS', 'WSM', '+685', 'UTC-11:00', 'Samoan tala']
# ['San Marino', 'San Marino', 'SM', 'SMR', '+378', 'UTC+01:00', 'Euro']
# ['Sao Tome and Príncipe', 'São Tomé', 'ST', 'STP', '+239', 'UTC', 'São Tomé and Príncipe dobra']
# ['Saudi Arabia', 'Riyadh', 'SA', 'SAU', '+966', 'UTC+03:00', 'Saudi riyal']
# ['Senegal', 'Dakar', 'SN', 'SEN', '+221', 'UTC', 'West African CFA franc']
# ['Serbia', 'Belgrade', 'RS', 'SRB', '+381', 'UTC+01:00', 'Serbian dinar']
# ['Seychelles', 'Victoria', 'SC', 'SYC', '+248', 'UTC+04:00', 'Seychellois rupee']
# ['Sierra Leone', 'Freetown', 'SL', 'SLE', '+232', 'UTC', 'Sierra Leonean leone']
# ['Singapore', 'Singapore', 'SG', 'SGP', '+65', 'UTC+08:00', 'Brunei dollar']
# ['Sint Maarten', 'Philipsburg', 'SX', 'SXM', '+599 5', 'UTC-04:00', 'Netherlands Antillean guilder']
# ['Slovakia', 'Bratislava', 'SK', 'SVK', '+421', 'UTC+01:00', 'Euro']
# ['Slovenia', 'Ljubljana', 'SI', 'SVN', '+386', 'UTC+01:00', 'Euro']
# ['Solomon Islands', 'Honiara', 'SB', 'SLB', '+677', 'UTC+11:00', 'Solomon Islands dollar']
# ['Somalia', 'Mogadishu', 'SO', 'SOM', '+252', 'UTC+03:00', 'Somali shilling']
# ['South Africa', 'Pretoria', 'ZA', 'ZAF', '+27', 'UTC+02:00', 'South African rand']
# ['South Georgia and the South Sandwich Islands', 'Grytviken', 'GS', 'SGS', '', 'UTC-02', 'British pound']
# ['South Korea', 'Seoul', 'KR', 'KOR', '+82', 'UTC+09:00', 'South Korean won']
# ['Spain', 'Madrid', 'ES', 'ESP', '+34', 'UTC+01:00', 'Euro']
# ['Sri Lanka', 'Sri Jayawardenapura Kotte', 'LK', 'LKA', '+94', 'UTC+05:30', 'Sri Lankan rupee']
# ['Sudan', 'Khartoum', 'SD', 'SDN', '+249', 'UTC+02:00', 'Sudanese pound']
# ['Suriname', 'Paramaribo', 'SR', 'SUR', '+597', 'UTC-03:30', 'Surinamese dollar']
# ['Svalbard and Jan Mayen', '', 'SJ', 'SJM', '+47', 'UTC+01:00', 'Norwegian krone']
# ['Swaziland', 'Mbabane', 'SZ', 'SWZ', '+268', 'UTC+02:00', 'Swazi lilangeni']
# ['Sweden', 'Stockholm', 'SE', 'SWE', '+46', 'UTC+01:00', 'Swedish krona']
# ['Switzerland', 'Bern', 'CH', 'CHE', '+41', 'UTC+01:00', 'Swiss franc']
# ['Syrian Arab Republic', 'Damascus', 'SY', 'SYR', '+963', 'UTC+02:00', 'Syrian pound']
# ['Taiwan', 'Taipei', 'TW', 'TWN', '+886', 'UTC+08:00', 'New Taiwan dollar']
# ['Tajikistan', 'Dushanbe', 'TJ', 'TJK', '+992', 'UTC+06:00', 'Tajikistani somoni']
# ['Tanzania', 'Dodoma', 'TZ', 'TZA', '+255', 'UTC+03:00', 'Tanzanian shilling']
# ['Thailand', 'Bangkok', 'TH', 'THA', '+66', 'UTC+07:00', 'Thai baht']
# ['Togo', 'Lomé', 'TG', 'TGO', '+228', 'UTC', 'West African CFA franc']
# ['Tokelau', 'Rotates annually', 'TK', 'TKL', '+690', 'UTC-10', 'New Zealand dollar']
# ['Tonga', 'Nuku', 'TO', 'TON', '+676', 'UTC+13:00', 'Tongan paʻanga']
# ['Trinidad and Tobago', 'Port of Spain', 'TT', 'TTO', '+1 868', 'UTC-04:00', 'Trinidad and Tobago dollar']
# ['Tunisia', 'Tunis', 'TN', 'TUN', '+216', 'UTC+01:00', 'Tunisian dinar']
# ['Turkey', 'Ankara', 'TR', 'TUR', '+90', 'UTC+02:00', 'Turkish lira']
# ['Turkmenistan', 'Ashgabat', 'TM', 'TKM', '+993', 'UTC+05:00', 'Turkmenistani manat']
# ['Turks and Caicos Islands', 'Cockburn Town', 'TC', 'TCA', '+1 649', 'UTC-05:00', 'United States dollar']
# ['Tuvalu', 'Funafuti', 'TV', 'TUV', '+688', 'UTC+12:00', 'Australian dollar']
# ['Uganda', 'Kampala', 'UG', 'UGA', '+256', 'UTC+03:00', 'Ugandan shilling']
# ['Ukraine', 'Kiev', 'UA', 'UKR', '+380', 'UTC+03:00', 'Ukrainian hryvnia']
# ['United Arab Emirates', 'Abu Dhabi', 'AE', 'ARE', '+971', 'UTC+04:00', 'United Arab Emirates dirham']
# ['United Kingdom', 'London', 'GB', 'GBR', '+44', 'UTC', 'British pound']
# ['United States', 'Washington D.C.', 'US', 'USA', '+1', 'UTC-11:00 - UTC-05:00', 'United States dollar']
# ['United States Minor Outlying Islands', '', 'UM', 'UMI', '+1', '', 'United States dollar']
# ['Uruguay', 'Montevideo', 'UY', 'URY', '+598', 'UTC-03:00', 'Uruguayan peso']
# ['Uzbekistan', 'Tashkent', 'UZ', 'UZB', '+998', 'UTC+06:00', 'Uzbekistani som']
# ['Vanuatu', 'Port Vila', 'VU', 'VUT', '+678', 'UTC+11:00', 'Vanuatu vatu']
# ['Vatican City', 'Vatican City', 'VA', 'VAT', '+39 06 698', 'UTC+01', 'Euro']
# ['Venezuela', 'Caracas', 'VE', 'VEN', '+58', 'UTC-04:00', 'Venezuelan bolívar']
# ['Vietnam', 'Hanoi', 'VN', 'VNM', '+84', 'UTC+07:00', 'Vietnamese đồng']
# ['Virgin Islands', 'Road Town', 'VG', 'VGB', '+1 284', 'UTC-04', 'British Virgin Islands dollar']
# ['Virgin Islands of the United States', 'Charlotte Amalie', 'VI', 'VIR', '+1 340', 'UTC-04', 'United States dollar']
# ['Wallis and Futuna', 'Mata-Utu', 'WF', 'WLF', '+681', 'UTC+12:00', 'CFP franc']
# ['Western Sahara', 'Laâyoune (El Aaiún)', 'EH', 'ESH', '+212 5288/5289', 'UTC+01', 'Moroccan dirham']
# ['Yemen', 'Sanaá', 'YE', 'YEM', '+967', 'UTC+03:00', 'Yemeni rial']
# ['Zambia', 'Lusaka', 'ZM', 'ZMB', '+260', 'UTC+02:00', 'Zambian kwacha']
# ['Zimbabwe', 'Harare', 'ZW', 'ZWE', '+263', 'UTC+02:00', 'Botswana pula']

# %%
# dialect
attributes = ['delimiter',
              'doublequote',
              'escapechar',
              'lineterminator',
              'quotechar',
              'quoting',
              'skipinitialspace',
              ]

for attribute in attributes:
    print(f'{attribute}: {repr(getattr(country_dialect, attribute))}')
# Out:
# delimiter: '|'
# doublequote: False
# escapechar: None
# lineterminator: '\r\n'
# quotechar: '"'
# quoting: 0
# skipinitialspace: False

# %%
# writing csv files
import csv

cereals = [
    ["Barley", 556, 1.7, 32.9, 10.1, 13.8],
    ["Durum", 339, 5, 27.4, 4.09, 9.7],
    ["Fonio", 240, 1, 4, 1.7, 0.05],
    ["Maize", 442, 7.4, 37.45, 6.15, 11.03],
    ["Millet", 484, 2, 37.9, 13.4, 9.15],
    ["Oats", 231, 9.2, 35.1, 10.3, 3.73],
    ["Rice (Brown)", 346, 2.8, 38.1, 9.9, 0.8],
    ["Rice, (White)", 345, 3.6, 37.6, 5.4, 0.1],
    ["Rye", 422, 2, 31.4, 18.2, 21.2],
    ["Sorghum", 316, 3, 37.8, 9.92, 9.15],
    ["Triticale", 338, 1.81, 36.6, 19, 0.9],
    ["Wheat", 407, 1.2, 27.8, 12.9, 13.8],
]

column_headings = ["Cereal", "Calories", "Fat", "Protein", "Fibre", "Vitamin E"]

output_filename = 'my_cereals.csv'

with open(output_filename, 'w', encoding='utf-8', newline='') as output_file:
    writer = csv.writer(output_file, quoting=csv.QUOTE_NONNUMERIC)
    writer.writerow(column_headings)
    writer.writerows(cereals) 
# now we can see the file in folder

# %%
# dictreader
import csv

input_filename = 'country_info.txt'

countries = {}
with open(input_filename, encoding='utf-8', newline='') as country_file:
    dict_reader = csv.DictReader(country_file, delimiter='|')
    for row in dict_reader:
        # countries[country.casefold()] = country_dict
        countries[row['Country'].casefold()] = row
        # countries[code.casefold()] = country_dict
        countries[row['CC'].casefold()] = row

# print(countries)

while True:
    chosen_country = input('Please enter the name of a country: ')
    country_key = chosen_country.casefold()
    if country_key in countries:
        country_data = countries[country_key]
        print(f"The capital of {chosen_country} is {country_data['Capital']}")
    elif chosen_country == 'quit':
        break
# Out:
# Please enter the name of a country: quit

# %%
# multiple files
import csv
ordering = ['Country', 'Gold', 'Silver', 'Bronze', 'Rank']
# Note the lack of 'Total' in `ordering`
with open('OlympicMedals_2020.csv', encoding='utf-8', newline='') as data,\
        open('medals_dict.py', 'w', encoding='utf-8') as output_file:
    # Write the first part of the code (excluding the actual data)
    print('import csv', file=output_file)
    print(file=output_file)
    print('medals_table = [', file=output_file)

    reader = csv.DictReader(data)
    # Read each row from the CSV file, as a dictionary,
    # and produce a new dictionary containing the key/value
    # pairs we want, in the order we want.
    for row_dict in reader:
        new_dict = {}
        # Only print the values for the keys we want
        # (in the order we want them).
        for key in ordering:
            value = row_dict[key]
            if value.isnumeric():
                value = int(value)
            new_dict[key.casefold()] = value

        # print the dictionary to the output file
        # (indented by 4 spaces, with a trailing comma).
        print(f'    {new_dict},', file=output_file)

    # All the data rows have been written, print the terminating ]
    print(']', file=output_file)
    print(file=output_file)  # and finish with a blank line.

# %%
# csv dictwriter
import csv

medals_table = [
    {'country': 'United States', 'gold': 39, 'silver': 41, 'bronze': 33, 'rank': 1},
    {'country': 'China', 'gold': 38, 'silver': 32, 'bronze': 18, 'rank': 2},
    {'country': 'Japan', 'gold': 27, 'silver': 14, 'bronze': 17, 'rank': 3},
    {'country': 'Great Britain', 'gold': 22, 'silver': 21, 'bronze': 22, 'rank': 4},
    {'country': 'ROC', 'gold': 20, 'silver': 28, 'bronze': 23, 'rank': 5},
    {'country': 'Australia', 'gold': 17, 'silver': 7, 'bronze': 22, 'rank': 6},
    {'country': 'Netherlands', 'gold': 10, 'silver': 12, 'bronze': 14, 'rank': 7},
    {'country': 'France', 'gold': 10, 'silver': 12, 'bronze': 11, 'rank': 8},
    {'country': 'Germany', 'gold': 10, 'silver': 11, 'bronze': 16, 'rank': 9},
    {'country': 'Italy', 'gold': 10, 'silver': 10, 'bronze': 20, 'rank': 10},
    {'country': 'Canada', 'gold': 7, 'silver': 6, 'bronze': 11, 'rank': 11},
    {'country': 'Brazil', 'gold': 7, 'silver': 6, 'bronze': 8, 'rank': 12},
    {'country': 'New Zealand', 'gold': 7, 'silver': 6, 'bronze': 7, 'rank': 13},
    {'country': 'Cuba', 'gold': 7, 'silver': 3, 'bronze': 5, 'rank': 14},
    {'country': 'Hungary', 'gold': 6, 'silver': 7, 'bronze': 7, 'rank': 15},
    {'country': 'South Korea', 'gold': 6, 'silver': 4, 'bronze': 10, 'rank': 16},
    {'country': 'Poland', 'gold': 4, 'silver': 5, 'bronze': 5, 'rank': 17},
    {'country': 'Czech Republic', 'gold': 4, 'silver': 4, 'bronze': 3, 'rank': 18},
    {'country': 'Kenya', 'gold': 4, 'silver': 4, 'bronze': 2, 'rank': 19},
    {'country': 'Norway', 'gold': 4, 'silver': 2, 'bronze': 2, 'rank': 20},
    {'country': 'Jamaica', 'gold': 4, 'silver': 1, 'bronze': 4, 'rank': 21},
    {'country': 'Spain', 'gold': 3, 'silver': 8, 'bronze': 6, 'rank': 22},
    {'country': 'Sweden', 'gold': 3, 'silver': 6, 'bronze': 0, 'rank': 23},
    {'country': 'Switzerland', 'gold': 3, 'silver': 4, 'bronze': 6, 'rank': 24},
    {'country': 'Denmark', 'gold': 3, 'silver': 4, 'bronze': 4, 'rank': 25},
    {'country': 'Croatia', 'gold': 3, 'silver': 3, 'bronze': 2, 'rank': 26},
    {'country': 'Iran', 'gold': 3, 'silver': 2, 'bronze': 2, 'rank': 27},
    {'country': 'Serbia', 'gold': 3, 'silver': 1, 'bronze': 5, 'rank': 28},
    {'country': 'Belgium', 'gold': 3, 'silver': 1, 'bronze': 3, 'rank': 29},
    {'country': 'Bulgaria', 'gold': 3, 'silver': 1, 'bronze': 2, 'rank': 30},
    {'country': 'Slovenia', 'gold': 3, 'silver': 1, 'bronze': 1, 'rank': 31},
    {'country': 'Uzbekistan', 'gold': 3, 'silver': 0, 'bronze': 2, 'rank': 32},
    {'country': 'Georgia', 'gold': 2, 'silver': 5, 'bronze': 1, 'rank': 33},
    {'country': 'Chinese Taipei', 'gold': 2, 'silver': 4, 'bronze': 6, 'rank': 34},
    {'country': 'Turkey', 'gold': 2, 'silver': 2, 'bronze': 9, 'rank': 35},
    {'country': 'Greece', 'gold': 2, 'silver': 1, 'bronze': 1, 'rank': 36},
    {'country': 'Uganda', 'gold': 2, 'silver': 1, 'bronze': 1, 'rank': 36},
    {'country': 'Ecuador', 'gold': 2, 'silver': 1, 'bronze': 0, 'rank': 38},
    {'country': 'Ireland', 'gold': 2, 'silver': 0, 'bronze': 2, 'rank': 39},
    {'country': 'Israel', 'gold': 2, 'silver': 0, 'bronze': 2, 'rank': 39},
    {'country': 'Qatar', 'gold': 2, 'silver': 0, 'bronze': 1, 'rank': 41},
    {'country': 'Bahamas', 'gold': 2, 'silver': 0, 'bronze': 0, 'rank': 42},
    {'country': 'Kosovo', 'gold': 2, 'silver': 0, 'bronze': 0, 'rank': 42},
    {'country': 'Ukraine', 'gold': 1, 'silver': 6, 'bronze': 12, 'rank': 44},
    {'country': 'Belarus', 'gold': 1, 'silver': 3, 'bronze': 3, 'rank': 45},
    {'country': 'Romania', 'gold': 1, 'silver': 3, 'bronze': 0, 'rank': 46},
    {'country': 'Venezuela', 'gold': 1, 'silver': 3, 'bronze': 0, 'rank': 46},
    {'country': 'India', 'gold': 1, 'silver': 2, 'bronze': 4, 'rank': 48},
    {'country': 'Hong Kong', 'gold': 1, 'silver': 2, 'bronze': 3, 'rank': 49},
    {'country': 'Philippines', 'gold': 1, 'silver': 2, 'bronze': 1, 'rank': 50},
    {'country': 'Slovakia', 'gold': 1, 'silver': 2, 'bronze': 1, 'rank': 50},
    {'country': 'South Africa', 'gold': 1, 'silver': 2, 'bronze': 0, 'rank': 52},
    {'country': 'Austria', 'gold': 1, 'silver': 1, 'bronze': 5, 'rank': 53},
    {'country': 'Egypt', 'gold': 1, 'silver': 1, 'bronze': 4, 'rank': 54},
    {'country': 'Indonesia', 'gold': 1, 'silver': 1, 'bronze': 3, 'rank': 55},
    {'country': 'Ethiopia', 'gold': 1, 'silver': 1, 'bronze': 2, 'rank': 56},
    {'country': 'Portugal', 'gold': 1, 'silver': 1, 'bronze': 2, 'rank': 56},
    {'country': 'Tunisia', 'gold': 1, 'silver': 1, 'bronze': 0, 'rank': 58},
    {'country': 'Estonia', 'gold': 1, 'silver': 0, 'bronze': 1, 'rank': 59},
    {'country': 'Fiji', 'gold': 1, 'silver': 0, 'bronze': 1, 'rank': 59},
    {'country': 'Latvia', 'gold': 1, 'silver': 0, 'bronze': 1, 'rank': 59},
    {'country': 'Thailand', 'gold': 1, 'silver': 0, 'bronze': 1, 'rank': 59},
    {'country': 'Bermuda', 'gold': 1, 'silver': 0, 'bronze': 0, 'rank': 63},
    {'country': 'Morocco', 'gold': 1, 'silver': 0, 'bronze': 0, 'rank': 63},
    {'country': 'Puerto Rico', 'gold': 1, 'silver': 0, 'bronze': 0, 'rank': 63},
    {'country': 'Colombia', 'gold': 0, 'silver': 4, 'bronze': 1, 'rank': 66},
    {'country': 'Azerbaijan', 'gold': 0, 'silver': 3, 'bronze': 4, 'rank': 67},
    {'country': 'Dominican Republic', 'gold': 0, 'silver': 3, 'bronze': 2, 'rank': 68},
    {'country': 'Armenia', 'gold': 0, 'silver': 2, 'bronze': 2, 'rank': 69},
    {'country': 'Kyrgyzstan', 'gold': 0, 'silver': 2, 'bronze': 1, 'rank': 70},
    {'country': 'Mongolia', 'gold': 0, 'silver': 1, 'bronze': 3, 'rank': 71},
    {'country': 'Argentina', 'gold': 0, 'silver': 1, 'bronze': 2, 'rank': 72},
    {'country': 'San Marino', 'gold': 0, 'silver': 1, 'bronze': 2, 'rank': 72},
    {'country': 'Jordan', 'gold': 0, 'silver': 1, 'bronze': 1, 'rank': 74},
    {'country': 'Malaysia', 'gold': 0, 'silver': 1, 'bronze': 1, 'rank': 74},
    {'country': 'Nigeria', 'gold': 0, 'silver': 1, 'bronze': 1, 'rank': 74},
    {'country': 'Bahrain', 'gold': 0, 'silver': 1, 'bronze': 0, 'rank': 77},
    {'country': 'Saudi Arabia', 'gold': 0, 'silver': 1, 'bronze': 0, 'rank': 77},
    {'country': 'Lithuania', 'gold': 0, 'silver': 1, 'bronze': 0, 'rank': 77},
    {'country': 'North Macedonia', 'gold': 0, 'silver': 1, 'bronze': 0, 'rank': 77},
    {'country': 'Namibia', 'gold': 0, 'silver': 1, 'bronze': 0, 'rank': 77},
    {'country': 'Turkmenistan', 'gold': 0, 'silver': 1, 'bronze': 0, 'rank': 77},
    {'country': 'Kazakhstan', 'gold': 0, 'silver': 0, 'bronze': 8, 'rank': 83},
    {'country': 'Mexico', 'gold': 0, 'silver': 0, 'bronze': 4, 'rank': 84},
    {'country': 'Finland', 'gold': 0, 'silver': 0, 'bronze': 2, 'rank': 85},
    {'country': 'Botswana', 'gold': 0, 'silver': 0, 'bronze': 1, 'rank': 86},
    {'country': 'Burkina Faso', 'gold': 0, 'silver': 0, 'bronze': 1, 'rank': 86},
    {'country': "CÃ´te d'Ivoire", 'gold': 0, 'silver': 0, 'bronze': 1, 'rank': 86},
    {'country': 'Ghana', 'gold': 0, 'silver': 0, 'bronze': 1, 'rank': 86},
    {'country': 'Grenada', 'gold': 0, 'silver': 0, 'bronze': 1, 'rank': 86},
    {'country': 'Kuwait', 'gold': 0, 'silver': 0, 'bronze': 1, 'rank': 86},
    {'country': 'Moldova', 'gold': 0, 'silver': 0, 'bronze': 1, 'rank': 86},
    {'country': 'Syria', 'gold': 0, 'silver': 0, 'bronze': 1, 'rank': 86},
]


def sort_key(d: dict) -> str:
    return d['country']


columns = ['country', 'gold', 'silver', 'bronze']

filename = 'country_medals.csv'
with open(filename, 'w', encoding='utf-8', newline='') as output_file:
    writer = csv.DictWriter(output_file, fieldnames=columns, extrasaction='ignore')
    writer.writeheader()
    # for row in medals_table:
    #     writer.writerow(row)
    writer.writerows(sorted(medals_table, key=sort_key))

# %%
#json files, json is a data format  json-javascript object notation
#its is a well structured and easily readble data format
import json
data=json.load(open('test.json','r')) #load the json file and will read the file and convert the data into python dict/list
print(data)
print(type(data))
# Out:
# [['ABC', 1987], ['Algol 68', 1968], ['APL', 1962], ['C', 1973], ['Haskell', 1990], ['Lisp', 1958], ['Modula-2', 1977], ['Perl', 1987]]
# <class 'list'>

# %%
with open('example_2.json','r') as f:
    data=json.load(f)
print(data)
print(type(data))
# Out:
# {'persons': [{'firstName': 'Ali', 'lastName': 'Hasan', 'age': 19, 'address': {'streetAddress': 'GT Road', 'city': 'Lahore'}, 'phoneNumbers': [{'type': 'home', 'number': '0423-111111'}, {'type': 'mobile', 'number': '0333-222222'}], 'salary': None, 'isMarried': False}, {'firstName': 'Ahmad', 'lastName': 'Hamza', 'age': 28, 'address': {'streetAddress': 'M. A. Jinnah Road', 'city': 'Karachi'}, 'phoneNumbers': [{'type': 'home', 'number': '021-111111'}, {'type': 'mobile', 'number': '0333-3232323'}], 'salary': 80000, 'isMarried': True}]}
# <class 'dict'>

# %%
# for better view
print(json.dumps(data, indent=3, sort_keys=True))
# Out:
# {
#    "persons": [
#       {
#          "address": {
#             "city": "Lahore",
#             "streetAddress": "GT Road"
#          },
#          "age": 19,
#          "firstName": "Ali",
#          "isMarried": false,
#          "lastName": "Hasan",
#          "phoneNumbers": [
#             {
#                "number": "0423-111111",
#                "type": "home"
#             },
#             {
#                "number": "0333-222222",
#                "type": "mobile"
#             }
#          ],
#          "salary": null
#       },
#       {
#          "address": {
#             "city": "Karachi",
#             "streetAddress": "M. A. Jinnah Road"
#          },
#          "age": 28,
#          "firstName": "Ahmad",
#          "isMarried": true,
#          "lastName": "Hamza",
#          "phoneNumbers": [
#             {
#                "number": "021-111111",
#                "type": "home"
#             },
#             {
#                "number": "0333-3232323",
#                "type": "mobile"
#             }
#          ],
#          "salary": 80000
#       }
#    ]
# }

# %%
# parshing
print(data['persons'])# accesing inner information
print(len(data['persons']))
# Out:
# [{'firstName': 'Ali', 'lastName': 'Hasan', 'age': 19, 'address': {'streetAddress': 'GT Road', 'city': 'Lahore'}, 'phoneNumbers': [{'type': 'home', 'number': '0423-111111'}, {'type': 'mobile', 'number': '0333-222222'}], 'salary': None, 'isMarried': False}, {'firstName': 'Ahmad', 'lastName': 'Hamza', 'age': 28, 'address': {'streetAddress': 'M. A. Jinnah Road', 'city': 'Karachi'}, 'phoneNumbers': [{'type': 'home', 'number': '021-111111'}, {'type': 'mobile', 'number': '0333-3232323'}], 'salary': 80000, 'isMarried': True}]
# 2

# %%
print(data['persons'][0]) #accesing  value odf 1st person
print(len(data['persons'][0]))
# Out:
# {'firstName': 'Ali', 'lastName': 'Hasan', 'age': 19, 'address': {'streetAddress': 'GT Road', 'city': 'Lahore'}, 'phoneNumbers': [{'type': 'home', 'number': '0423-111111'}, {'type': 'mobile', 'number': '0333-222222'}], 'salary': None, 'isMarried': False}
# 7

# %%
# for getting key,values pairs for 1st person
for i in data['persons'][0].items():
    print(i)
# Out:
# ('firstName', 'Ali')
# ('lastName', 'Hasan')
# ('age', 19)
# ('address', {'streetAddress': 'GT Road', 'city': 'Lahore'})
# ('phoneNumbers', [{'type': 'home', 'number': '0423-111111'}, {'type': 'mobile', 'number': '0333-222222'}])
# ('salary', None)
# ('isMarried', False)

# %%
print(data['persons'][0]['phoneNumbers'])
print(data['persons'][0]['phoneNumbers'][0])
# Out:
# [{'type': 'home', 'number': '0423-111111'}, {'type': 'mobile', 'number': '0333-222222'}]
# {'type': 'home', 'number': '0423-111111'}

# %%
# writing json files
import json

languages = [
    ['ABC', 1987],
    ['Algol 68', 1968],
    ['APL', 1962],
    ['C', 1973],
    ['Haskell', 1990],
    ['Lisp', 1958],
    ['Modula-2', 1977],
    ['Perl', 1987],
]

with open('test.json', 'w', encoding='utf-8') as testfile:
    json.dump(languages, testfile)

# %%
# writing json
j={"description": {"title": "Global Land and Ocean Temperature Anomalies, January-December", "units": "Degrees Celsius", "base_period": "1901-2000", "missing": -999}, "data": {"1880": "-0.12", "1881": "-0.09", "1882": "-0.10", "1883": "-0.18", "1884": "-0.27", "1885": "-0.25", "1886": "-0.24", "1887": "-0.29", "1888": "-0.13", "1889": "-0.09", "1890": "-0.34", "1891": "-0.26", "1892": "-0.30", "1893": "-0.33", "1894": "-0.31", "1895": "-0.24", "1896": "-0.10", "1897": "-0.10", "1898": "-0.27", "1899": "-0.16", "1900": "-0.07", "1901": "-0.15", "1902": "-0.26", "1903": "-0.37", "1904": "-0.45", "1905": "-0.27", "1906": "-0.21", "1907": "-0.38", "1908": "-0.43", "1909": "-0.44", "1910": "-0.40", "1911": "-0.44", "1912": "-0.33", "1913": "-0.32", "1914": "-0.14", "1915": "-0.09", "1916": "-0.32", "1917": "-0.39", "1918": "-0.30", "1919": "-0.25", "1920": "-0.23", "1921": "-0.16", "1922": "-0.25", "1923": "-0.25", "1924": "-0.24", "1925": "-0.18", "1926": "-0.07", "1927": "-0.17", "1928": "-0.18", "1929": "-0.33", "1930": "-0.11", "1931": "-0.06", "1932": "-0.13", "1933": "-0.26", "1934": "-0.11", "1935": "-0.16", "1936": "-0.12", "1937": "-0.01", "1938": "-0.02", "1939": "0.01", "1940": "0.16", "1941": "0.27", "1942": "0.11", "1943": "0.11", "1944": "0.28", "1945": "0.18", "1946": "-0.01", "1947": "-0.03", "1948": "-0.05", "1949": "-0.07", "1950": "-0.15", "1951": "0.00", "1952": "0.04", "1953": "0.13", "1954": "-0.10", "1955": "-0.13", "1956": "-0.18", "1957": "0.07", "1958": "0.12", "1959": "0.08", "1960": "0.05", "1961": "0.09", "1962": "0.10", "1963": "0.12", "1964": "-0.14", "1965": "-0.07", "1966": "-0.01", "1967": "0.00", "1968": "-0.03", "1969": "0.10", "1970": "0.06", "1971": "-0.07", "1972": "0.04", "1973": "0.19", "1974": "-0.06", "1975": "0.01", "1976": "-0.07", "1977": "0.21", "1978": "0.12", "1979": "0.23", "1980": "0.28", "1981": "0.32", "1982": "0.19", "1983": "0.36", "1984": "0.17", "1985": "0.16", "1986": "0.24", "1987": "0.38", "1988": "0.39", "1989": "0.29", "1990": "0.45", "1991": "0.39", "1992": "0.24", "1993": "0.28", "1994": "0.34", "1995": "0.47", "1996": "0.32", "1997": "0.51", "1998": "0.65", "1999": "0.44", "2000": "0.43", "2001": "0.57", "2002": "0.62", "2003": "0.64", "2004": "0.58", "2005": "0.67", "2006": "0.64", "2007": "0.62", "2008": "0.54", "2009": "0.64", "2010": "0.72", "2011": "0.58", "2012": "0.64", "2013": "0.67", "2014": "0.74", "2015": "0.93", "2016": "0.99", "2017": "0.91", "2018": "0.82", "2019": "0.95", "2020": 0.98}, "citation": "NOAA National Centers for Environmental information, Climate at a Glance: Global Time Series, published August 2021, retrieved on August 19, 2021 from https://www.ncdc.noaa.gov/cag/"}
with open('temp.json', 'w', encoding='utf-8') as tempfile:
    json.dump(j, tempfile)

# %%
with open("temp.json", encoding='utf-8') as temp:
    anomalies = json.load(temp)

print(anomalies['description'])

for year, value in anomalies['data'].items(): # year=key, value=value
    year, value = int(year), float(value)
    print(f'{year} ...{value:6.2f}')
print('*' * 80)

print(anomalies['citation'])
# Out:
# {'title': 'Global Land and Ocean Temperature Anomalies, January-December', 'units': 'Degrees Celsius', 'base_period': '1901-2000', 'missing': -999}
# 1880 ... -0.12
# 1881 ... -0.09
# 1882 ... -0.10
# 1883 ... -0.18
# 1884 ... -0.27
# 1885 ... -0.25
# 1886 ... -0.24
# 1887 ... -0.29
# 1888 ... -0.13
# 1889 ... -0.09
# 1890 ... -0.34
# 1891 ... -0.26
# 1892 ... -0.30
# 1893 ... -0.33
# 1894 ... -0.31
# 1895 ... -0.24
# 1896 ... -0.10
# 1897 ... -0.10
# 1898 ... -0.27
# 1899 ... -0.16
# 1900 ... -0.07
# 1901 ... -0.15
# 1902 ... -0.26
# 1903 ... -0.37
# 1904 ... -0.45
# 1905 ... -0.27
# 1906 ... -0.21
# 1907 ... -0.38
# 1908 ... -0.43
# 1909 ... -0.44
# 1910 ... -0.40
# 1911 ... -0.44
# 1912 ... -0.33
# 1913 ... -0.32
# 1914 ... -0.14
# 1915 ... -0.09
# 1916 ... -0.32
# 1917 ... -0.39
# 1918 ... -0.30
# 1919 ... -0.25
# 1920 ... -0.23
# 1921 ... -0.16
# 1922 ... -0.25
# 1923 ... -0.25
# 1924 ... -0.24
# 1925 ... -0.18
# 1926 ... -0.07
# 1927 ... -0.17
# 1928 ... -0.18
# 1929 ... -0.33
# 1930 ... -0.11
# 1931 ... -0.06
# 1932 ... -0.13
# 1933 ... -0.26
# 1934 ... -0.11
# 1935 ... -0.16
# 1936 ... -0.12
# 1937 ... -0.01
# 1938 ... -0.02
# 1939 ...  0.01
# 1940 ...  0.16
# 1941 ...  0.27
# 1942 ...  0.11
# 1943 ...  0.11
# 1944 ...  0.28
# 1945 ...  0.18
# 1946 ... -0.01
# 1947 ... -0.03
# 1948 ... -0.05
# 1949 ... -0.07
# 1950 ... -0.15
# 1951 ...  0.00
# 1952 ...  0.04
# 1953 ...  0.13
# 1954 ... -0.10
# 1955 ... -0.13
# 1956 ... -0.18
# 1957 ...  0.07
# 1958 ...  0.12
# 1959 ...  0.08
# 1960 ...  0.05
# 1961 ...  0.09
# 1962 ...  0.10
# 1963 ...  0.12
# 1964 ... -0.14
# 1965 ... -0.07
# 1966 ... -0.01
# 1967 ...  0.00
# 1968 ... -0.03
# 1969 ...  0.10
# 1970 ...  0.06
# 1971 ... -0.07
# 1972 ...  0.04
# 1973 ...  0.19
# 1974 ... -0.06
# 1975 ...  0.01
# 1976 ... -0.07
# 1977 ...  0.21
# 1978 ...  0.12
# 1979 ...  0.23
# 1980 ...  0.28
# 1981 ...  0.32
# 1982 ...  0.19
# 1983 ...  0.36
# 1984 ...  0.17
# 1985 ...  0.16
# 1986 ...  0.24
# 1987 ...  0.38
# 1988 ...  0.39
# 1989 ...  0.29
# 1990 ...  0.45
# 1991 ...  0.39
# 1992 ...  0.24
# 1993 ...  0.28
# 1994 ...  0.34
# 1995 ...  0.47
# 1996 ...  0.32
# 1997 ...  0.51
# 1998 ...  0.65
# 1999 ...  0.44
# 2000 ...  0.43
# 2001 ...  0.57
# 2002 ...  0.62
# 2003 ...  0.64
# 2004 ...  0.58
# 2005 ...  0.67
# 2006 ...  0.64
# 2007 ...  0.62
# 2008 ...  0.54
# 2009 ...  0.64
# 2010 ...  0.72
# 2011 ...  0.58
# 2012 ...  0.64
# 2013 ...  0.67
# 2014 ...  0.74
# 2015 ...  0.93
# 2016 ...  0.99
# 2017 ...  0.91
# 2018 ...  0.82
# 2019 ...  0.95
# 2020 ...  0.98
# ********************************************************************************
# NOAA National Centers for Environmental information, Climate at a Glance: Global Time Series, published August 2021, retrieved on August 19, 2021 from https://www.ncdc.noaa.gov/cag/

# %%
import json
import urllib.request
json_data_source=https://www.ncdc.noaa.gov/cag/time-series/global/globe/land_ocean/ytd/12/1880-2021/data.json
with urllib.request.urlopen(json_data_source) as json_stream:
    data=json_stream.read().decode('utf-8')
    anomalies=json.loads(data)
# Out:
#   File "C:\Users\LOKESH~1\AppData\Local\Temp/ipykernel_5220/1669982925.py", line 3
#     json_data_source=https://www.ncdc.noaa.gov/cag/time-series/global/globe/land_ocean/ytd/12/1880-2021/data.json
#                           ^
# SyntaxError: invalid syntax

# %%
 # bytes and byte array data
equation=bytes((207,128,114,194,178))
print(equation) #
print(type(equation))
print(len(equation))
# Out:
# b'\xcf\x80r\xc2\xb2'
# <class 'bytes'>
# 5

# %%
eq=b'\xcf\x80r\xc2\xb2'
for b in eq:
    print(b)
print(eq.decode('utf-8'))
# Out:
# 207
# 128
# 114
# 194
# 178
# πr²
